# %% [markdown]
# ### Prepping General Plan PDFs
#
# Many of the plan PDFs are large enough that I needed to split them up into separate files in order to upload them into my repository (25 MB maximum file size for uploads). These files have been saved in a separate "General Plan Sections" subfolder. I have to (re)merge them before I can include them in the "General Plan" subfolder.

# %%
# libraries
from PyPDF2 import PdfFileReader, PdfFileWriter, PdfFileMerger

# %% [markdown]
# All of the sections for each plan have to be merged in specific order. For whatever reason, my device does not recognize the files unless I include the full absolute path. Moreover, out of caution, I am choosing to initialize and then close and then reinitialize the merger process to merge plan sections for each city.
#
# I am also choosing not the delete the individual section files once they have been merged, because I would like to preserve them for future element-specific analyses (e.g. Land Use elements,  Open Space and Conservation elements).

# %%
# Arcadia

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 2 Land Use.pdf", 
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 3 Economic Development.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 5 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 6 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 7 Recreation Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 8 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Arcadia 9 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Arcadia.pdf")
merger.close()

# %%
# Azusa

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Azusa_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Azusa_Part2.pdf", 
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Azusa_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Azusa_Part4.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Azusa_Part5.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Azusa.pdf")
merger.close()

# %%
# Baldwin Park

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Baldwin Park A.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Baldwin Park B Health and Sustainability_Part1.pdf", 
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Baldwin Park B Health and Sustainability_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Baldwin Park.pdf")
merger.close()

# %%
# Bellflower

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bellflower 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bellflower 2 Land Use.pdf", 
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bellflower 4 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bellflower 6 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bellflower 7 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Bellflower.pdf")
merger.close()

# %%
# Beverly Hills

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hill 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 2 Land Use.pdf", 
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 3 Character.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 4 Economic Development.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 5 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 7 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 8 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 9A Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 9B Hazard.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 10 Public Services.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 11 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Beverly Hills 12 Implementation Programs.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Beverly Hills.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Bradbury

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bradbury_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bradbury_Part2.pdf", 
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bradbury_Part3.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bradbury_Part4.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Bradbury_Part5.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Bradbury.pdf")
merger.close()

# %%
# Calabasas

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Calabasas_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Calabasas_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Calabasas.pdf")
merger.close()

# %%
# Camarillo

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 2 Background.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 2 Character.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 4 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 7 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 8 Recreation.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 9 Open Space Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 10 Character_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 10 Character_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 11 Safety.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Camarillo 12 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Camarillo.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Carson

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Carson_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Carson_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Carson_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Carson_Part4.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Carson_Part5.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Carson_Part6.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Carson_Part7.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Carson.pdf")
merger.close()

# %%
# Cerritos

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 2 Land Use.pdf", 
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 3 Community Design.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 3 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 6 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 7 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 8 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 9 Air Quality.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 10 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cerritos 11 Character.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Cerritos.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Claremont

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Claremont 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Claremont 2 Land Use Character.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Claremont 3 Economic Development.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Claremont 5 Open Space Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Claremont 6 Public Safety Noise.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Claremont 7 Recreation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Claremont 9 Governance.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Claremont.pdf")
merger.close()

# %%
# Cudahy

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cudahy_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cudahy_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cudahy_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Cudahy_Part4.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Cudahy.pdf")
merger.close()

# %%
# Diamond Bar

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part4.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part5.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part6.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part7.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Diamond Bar_Part8.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Diamond Bar.pdf")
merger.close()

# %%
# El Segundo

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 2 Economic Development.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 3 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 5 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 6 Open Space Recreation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 7 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 8 Air Quality.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 9 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 10 Public Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/El Segundo 11 Hazards.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("El Segundo.pdf")
merger.close()
# Out:
# Superfluous whitespace found in object header b'129' b'0'
# Superfluous whitespace found in object header b'11' b'0'
# Superfluous whitespace found in object header b'10' b'0'
# Superfluous whitespace found in object header b'9' b'0'
# Superfluous whitespace found in object header b'7' b'0'
# Superfluous whitespace found in object header b'8' b'0'
# Superfluous whitespace found in object header b'6' b'0'
# Superfluous whitespace found in object header b'5' b'0'
# Superfluous whitespace found in object header b'4' b'0'
# Superfluous whitespace found in object header b'27' b'0'
# Superfluous whitespace found in object header b'26' b'0'
# Superfluous whitespace found in object header b'25' b'0'
# Superfluous whitespace found in object header b'23' b'0'
# Superfluous whitespace found in object header b'24' b'0'
# Superfluous whitespace found in object header b'22' b'0'
# Superfluous whitespace found in object header b'21' b'0'
# Superfluous whitespace found in object header b'20' b'0'
# Superfluous whitespace found in object header b'128' b'0'
# Superfluous whitespace found in object header b'126' b'0'
# Superfluous whitespace found in object header b'125' b'0'
# Superfluous whitespace found in object header b'123' b'0'
# Superfluous whitespace found in object header b'122' b'0'
# Superfluous whitespace found in object header b'120' b'0'
# Superfluous whitespace found in object header b'119' b'0'
# Superfluous whitespace found in object header b'117' b'0'
# Superfluous whitespace found in object header b'116' b'0'
# Superfluous whitespace found in object header b'114' b'0'
# Superfluous whitespace found in object header b'113' b'0'
# Superfluous whitespace found in object header b'111' b'0'
# Superfluous whitespace found in object header b'110' b'0'
# Superfluous whitespace found in object header b'108' b'0'
# Superfluous whitespace found in object header b'97' b'0'
# Superfluous whitespace found in object header b'96' b'0'
# Superfluous whitespace found in object header b'95' b'0'
# Superfluous whitespace found in object header b'93' b'0'
# Superfluous whitespace found in object header b'94' b'0'
# Superfluous whitespace found in object header b'92' b'0'
# Superfluous whitespace found in object header b'91' b'0'
# Superfluous whitespace found in object header b'90' b'0'
# Superfluous whitespace found in object header b'107' b'0'
# Superfluous whitespace found in object header b'105' b'0'
# Superfluous whitespace found in object header b'104' b'0'
# Superfluous whitespace found in object header b'102' b'0'
# Superfluous whitespace found in object header b'101' b'0'
# Superfluous whitespace found in object header b'99' b'0'
# Superfluous whitespace found in object header b'98' b'0'
# Superfluous whitespace found in object header b'88' b'0'
# Superfluous whitespace found in object header b'87' b'0'
# Superfluous whitespace found in object header b'85' b'0'
# Superfluous whitespace found in object header b'84' b'0'
# Superfluous whitespace found in object header b'82' b'0'
# Superfluous whitespace found in object header b'81' b'0'
# Superfluous whitespace found in object header b'79' b'0'
# Superfluous whitespace found in object header b'77' b'0'
# Superfluous whitespace found in object header b'76' b'0'
# Superfluous whitespace found in object header b'75' b'0'
# Superfluous whitespace found in object header b'73' b'0'
# Superfluous whitespace found in object header b'74' b'0'
# Superfluous whitespace found in object header b'72' b'0'
# Superfluous whitespace found in object header b'71' b'0'
# Superfluous whitespace found in object header b'70' b'0'
# Superfluous whitespace found in object header b'78' b'0'
# Superfluous whitespace found in object header b'68' b'0'
# Superfluous whitespace found in object header b'67' b'0'
# Superfluous whitespace found in object header b'65' b'0'
# Superfluous whitespace found in object header b'64' b'0'
# Superfluous whitespace found in object header b'62' b'0'
# Superfluous whitespace found in object header b'61' b'0'
# Superfluous whitespace found in object header b'59' b'0'
# Superfluous whitespace found in object header b'58' b'0'
# Superfluous whitespace found in object header b'56' b'0'
# Superfluous whitespace found in object header b'55' b'0'
# Superfluous whitespace found in object header b'53' b'0'
# Superfluous whitespace found in object header b'52' b'0'
# Superfluous whitespace found in object header b'50' b'0'
# Superfluous whitespace found in object header b'49' b'0'
# Superfluous whitespace found in object header b'47' b'0'
# Superfluous whitespace found in object header b'46' b'0'
# Superfluous whitespace found in object header b'44' b'0'
# Superfluous whitespace found in object header b'43' b'0'
# Superfluous whitespace found in object header b'41' b'0'
# Superfluous whitespace found in object header b'40' b'0'
# Superfluous whitespace found in object header b'38' b'0'
# Superfluous whitespace found in object header b'37' b'0'
# Superfluous whitespace found in object header b'35' b'0'
# Superfluous whitespace found in object header b'34' b'0'
# Superfluous whitespace found in object header b'32' b'0'
# Superfluous whitespace found in object header b'31' b'0'
# Superfluous whitespace found in object header b'29' b'0'
# Superfluous whitespace found in object header b'19' b'0'
# Superfluous whitespace found in object header b'18' b'0'
# Superfluous whitespace found in object header b'17' b'0'
# Superfluous whitespace found in object header b'15' b'0'
# Superfluous whitespace found in object header b'16' b'0'
# Superfluous whitespace found in object header b'14' b'0'
# Superfluous whitespace found in object header b'13' b'0'
# Superfluous whitespace found in object header b'12' b'0'
# Superfluous whitespace found in object header b'28' b'0'

# %%
# Gardena

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 2 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 3 Economic Development.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 4 Community Design.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 5 Housing_trunc.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 6 EJ.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 7 Open Space.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 8 Conservation.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 9 Public Safety.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Gardena 10 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Gardena.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Superfluous whitespace found in object header b'1' b'0'
# Superfluous whitespace found in object header b'2' b'0'
# Superfluous whitespace found in object header b'3' b'0'
# Superfluous whitespace found in object header b'32' b'0'
# Superfluous whitespace found in object header b'46' b'0'
# Superfluous whitespace found in object header b'57' b'0'
# Superfluous whitespace found in object header b'60' b'0'
# Superfluous whitespace found in object header b'63' b'0'
# Superfluous whitespace found in object header b'66' b'0'
# Superfluous whitespace found in object header b'77' b'0'
# Superfluous whitespace found in object header b'83' b'0'
# Superfluous whitespace found in object header b'94' b'0'
# Superfluous whitespace found in object header b'97' b'0'
# Superfluous whitespace found in object header b'101' b'0'
# Superfluous whitespace found in object header b'104' b'0'
# Superfluous whitespace found in object header b'107' b'0'
# Superfluous whitespace found in object header b'121' b'0'
# Superfluous whitespace found in object header b'125' b'0'
# Superfluous whitespace found in object header b'128' b'0'
# Superfluous whitespace found in object header b'141' b'0'
# Superfluous whitespace found in object header b'144' b'0'
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 19
#      16     merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
#      18 # save
# ---> 19 merger.write("Gardena.pdf")
#      20 merger.close()
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\_merger.py:312, in PdfMerger.write(self, fileobj)
#     309 self._write_outline()
#     311 # Write the output to the file
# --> 312 my_file, ret_fileobj = self.output.write(fileobj)
#     314 if my_file:
#     315     ret_fileobj.close()
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\_writer.py:841, in PdfWriter.write(self, stream)
#     838     stream = FileIO(stream, "wb")
#     839     my_file = True
# --> 841 self.write_stream(stream)
#     843 if self.with_as_usage:
#     844     stream.close()
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\_writer.py:814, in PdfWriter.write_stream(self, stream)
#     804     self._root = self._add_object(self._root_object)
#     806 # PDF objects sometimes have circular references to their /Page objects
#     807 # inside their object tree (for example, annotations).  Those will be
#     808 # indirect references to objects that we've recreated in this PDF.  To
#    (...)
#     812 # trees to reference the correct new object location, rather than
#     813 # copying in a new copy of the page object.
# --> 814 self._sweep_indirect_references(self._root)
#     816 object_positions = self._write_header(stream)
#     817 xref_location = self._write_xref_table(stream, object_positions)
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\_writer.py:980, in PdfWriter._sweep_indirect_references(self, root)
#     978 # Data changed and thus the hash value changed
#     979 if parent[key_or_id] != data:
# --> 980     update_hashes = [parent.hash_value()] + [
#     981         grant_parent.hash_value() for grant_parent in grant_parents
#     982     ]
#     983     parent[key_or_id] = data
#     985 # Update old hash value to new hash value
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\_writer.py:981, in <listcomp>(.0)
#     978 # Data changed and thus the hash value changed
#     979 if parent[key_or_id] != data:
#     980     update_hashes = [parent.hash_value()] + [
# --> 981         grant_parent.hash_value() for grant_parent in grant_parents
#     982     ]
#     983     parent[key_or_id] = data
#     985 # Update old hash value to new hash value
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\generic\_base.py:65, in PdfObject.hash_value(self)
#      60 def hash_value(self) -> bytes:
#      61     return (
#      62         "%s:%s"
#      63         % (
#      64             self.__class__.__name__,
# ---> 65             self.hash_func(self.hash_value_data()).hexdigest(),
#      66         )
#      67     ).encode()
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\generic\_base.py:58, in PdfObject.hash_value_data(self)
#      57 def hash_value_data(self) -> bytes:
# ---> 58     return ("%s" % self).encode()
#
# File ~\Programs\envs\uds\lib\site-packages\PyPDF2\generic\_base.py:170, in IndirectObject.__repr__(self)
#     169 def __repr__(self) -> str:
# --> 170     return f"IndirectObject({self.idnum!r}, {self.generation!r}, {id(self.pdf)})"
#
# KeyboardInterrupt:

# %%
# Glendale

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part4.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part5.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part6.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part7.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Glendale_Part8.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Glendale.pdf")
merger.close()

# %%
# Hawthorne

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hawthorne 1 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hawthorne 2 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hawthorne 3 Open Space.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hawthorne 3 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hawthorne 4 Economic Development.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hawthorne 5 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hawthorne 6 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/hawthorne 7 EJ.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Hawthorne.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Hidden Hills

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hidden Hills_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Hidden Hills_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Hidden Hills.pdf")
merger.close()

# %%
# Huntington Park

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Huntington Park_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Huntington Park_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Huntington Park_Part3.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Huntington Park_Part4.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise
    
# save
merger.write("Huntington Park.pdf")
merger.close()

# %%
# Inglewood

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Inglewood 1 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Inglewood 2 Housing.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Inglewood 3 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Inglewood 4 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Inglewood 5 Public Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Inglewood 6 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Inglewood 7 EJ.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Inglewood.pdf")
merger.close()

# %%
# La Canada Flintridge

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 1 Intro.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 2 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 3 Open Space Recreation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 4 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 5 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 7 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 8 Air Quality.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 9 Housing_Part1.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Canada Flintridge 9 Housing_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("La Canada Flintridge.pdf")
merger.close()

# %%
# La Habra Heights

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Habra Heights_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Habra Heights_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("La Habra Heights.pdf")
merger.close()

# %%
# La Puente

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Puente 1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/La Puente 2 Housing.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("La Puente.pdf")
merger.close()

# %%
# Lawndale

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 2 Land Use.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 4 Housing_Part1.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 4 Housing_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 5 Economic Development.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 6 Open Space.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 7 Conservation.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 8 Air Quality.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 9 Public Safety.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lawndale 10 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Lawndale.pdf")
merger.close()

# %%
# Lomita

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lomita 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lomita 2 Land Use.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lomita 4 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lomita 5 Open Space Conservation.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lomita 6 Public Safety.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lomita 7 Noise.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Lomita 8 Economic Development.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Lomita.pdf")
merger.close()

# %%
# Long Beach

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 1 Character.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 2 Land Use_Part1.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 2 Land Use_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 3 Housing.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 4 Conservation.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 5 Open Space Recreation.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 6 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 7 Air Quality_Part1.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 7 Air Quality_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 9 Public Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 10 Design sans maps_Part1.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 10 Design sans maps_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 10 Design sans maps_Part3.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Long Beach 10 Design sans maps_Part4.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Long Beach.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Manhattan Beach

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Manhattan Beach 1 Intro.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Manhattan Beach 2 Land Use.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Manhattan Beach 3 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Manhattan Beach 4 Open Space Conservation 1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Manhattan Beach 4 Open Space Conservation 2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Manhattan Beach 5 Safety.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Manhattan Beach 6 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Manhattan Beach.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Monrovia

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monrovia 1 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monrovia 3 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monrovia 4 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monrovia 5 Noise.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monrovia 6 Open Space.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monrovia 7 Conservation.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monrovia 8 EJ.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Monrovia.pdf")
merger.close()

# %%
# Montebello

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 1 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 2 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 3 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 4 Housing_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 4 Housing_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 4 Housing_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 4 Housing_Part4.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 5 Density.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 6 Character.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 7 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 8 Public Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Montebello 9 Recreation.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Montebello.pdf")
merger.close()

# %%
# Monterey Park

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 1 Land Use_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 1 Land Use_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 4 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 5 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 6 Economic Development.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 7 Sustainable Community.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 8 EJ.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Monterey Park 9 Healthy Community.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Monterey Park.pdf")
merger.close()

# %%
# Moorpark

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Moorpark_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Moorpark_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Moorpark.pdf")
merger.close()

# %%
# Palmdale

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 1 Intro.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 2 Land Use.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 3 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 4 Recreation Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 5 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 6 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 7 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 8 Character.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Palmdale 9 Public Service.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Palmdale.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Pasadena

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 1 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 3 Housing_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 3 Housing_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 3 Housing_Part3.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 4 Open Space Recreation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 5 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 6 Noise 1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 6 Noise 2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pasadena 7 Safety.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Pasadena.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Pomona

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pomona_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pomona_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Pomona_Part3.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Pomona.pdf")
merger.close()

# %%
# Rancho Palos Verdes

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rancho Palos Verdes_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rancho Palos Verdes_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Rancho Palos Verdes.pdf")
merger.close()

# %%
# Rohnert Park

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rohnert Park_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rohnert Park_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Rohnert Park.pdf")
merger.close()

# %%
# Rolling Hills Estates

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rolling Hills Estates_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rolling Hills Estates_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rolling Hills Estates_Part3.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rolling Hills Estates_Part4.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rolling Hills Estates_Part5.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Rolling Hills Estates_Part6.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Rolling Hills Estates.pdf")
merger.close()

# %%
# San Dimas

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 2 Land Use_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 2 Land Use_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 2 Land Use_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 2 Land Use_Part4.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 4 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 5 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 6 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 7 Public Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/San Dimas 8 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("San Dimas.pdf")
merger.close()

# %%
# Santa Fe Springs

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Fe Springs_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Fe Springs_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Fe Springs_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Fe Springs_Part4.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Santa Fe Springs.pdf")
merger.close()

# %%
# Santa Monica

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 1 Land Use_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 1 Land Use_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 1 Land Use_Part3.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 1 Land Use_Part4.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 1 Land Use_Part5.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 1 Land Use_Part6.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 2 Character.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 3 Housing.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 5 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 6 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 7 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Monica 8 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Santa Monica.pdf")
merger.close()

# %%
# Santa Rosa

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Rosa_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Santa Rosa_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Santa Rosa.pdf")
merger.close()

# %%
# South El Monte

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South El Monte 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South El Monte 2 Land Use.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South El Monte 3 Economic Development.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South El Monte 4 Housing_Part1.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South El Monte 4 Housing_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South El Monte 5 Public Safety EJ.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South El Monte 7 Conservation.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("South El Monte.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# South Gate

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 1 Intro.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 2 Land Use_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 2 Land Use_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 5 Economic Development.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 6 Open Space Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 7 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 8 Facilities.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/South Gate 9 Noise.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("South Gate.pdf")
merger.close()

# %%
# Temple City

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Temple City_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Temple City_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Temple City_Part3.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Temple City_Part4.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Temple City_Part5.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Temple City.pdf")
merger.close()

# %%
# Thousand Oaks

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Thousand Oaks 1 Housing.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Thousand Oaks 2 Public Buildings.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Thousand Oaks 3 Forest.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Thousand Oaks 4 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Thousand Oaks 5 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Thousand Oaks 6 Public Safety.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Thousand Oaks.pdf")
merger.close()

# %%
# Torrance

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 1 Intro.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 1 Land Use.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 3 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 4 Safety.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 5 Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 6 Housing_Part1.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 6 Housing_Part2.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Torrance 6 Housing_Part3.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Torrance.pdf")
merger.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# West Covina

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Covina_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Covina_Part2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("West Covina.pdf")
merger.close()

# %%
# West Hollywood

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 1 Introduction.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 3 Land Use.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 4 Character.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 5 Economic Development.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 7 Human Services.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 8 Recreation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 9 Conservation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 10  Safety Noise.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/West Hollywood 11 Housing.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("West Hollywood.pdf")
merger.close()

# %%
# Westlake Village

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Westlake Village 1 Intro.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Westlake Village 2 Land Use.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Westlake Village 3 Housing.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Westlake Village 4 Safety Recreation.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Westlake Village 5 Open Space.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Westlake Village 6 Hazards.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Westlake Village.pdf")
merger.close()
# Out:
# Superfluous whitespace found in object header b'1' b'0'
# Superfluous whitespace found in object header b'2' b'0'
# Superfluous whitespace found in object header b'3' b'0'
# Superfluous whitespace found in object header b'30' b'0'
# Superfluous whitespace found in object header b'52' b'0'
# Superfluous whitespace found in object header b'71' b'0'
# Superfluous whitespace found in object header b'74' b'0'
# Superfluous whitespace found in object header b'102' b'0'
# Superfluous whitespace found in object header b'129' b'0'
# Superfluous whitespace found in object header b'132' b'0'
# Superfluous whitespace found in object header b'163' b'0'
# Superfluous whitespace found in object header b'174' b'0'
# Superfluous whitespace found in object header b'177' b'0'
# Superfluous whitespace found in object header b'208' b'0'
# Superfluous whitespace found in object header b'211' b'0'
# Superfluous whitespace found in object header b'217' b'0'
# Superfluous whitespace found in object header b'220' b'0'
# Superfluous whitespace found in object header b'223' b'0'
# Superfluous whitespace found in object header b'226' b'0'
# Superfluous whitespace found in object header b'229' b'0'
# Superfluous whitespace found in object header b'252' b'0'
# Superfluous whitespace found in object header b'282' b'0'
# Superfluous whitespace found in object header b'304' b'0'
# Superfluous whitespace found in object header b'317' b'0'
# Superfluous whitespace found in object header b'356' b'0'
# Superfluous whitespace found in object header b'359' b'0'
# Superfluous whitespace found in object header b'362' b'0'
# Superfluous whitespace found in object header b'365' b'0'
# Superfluous whitespace found in object header b'368' b'0'
# Superfluous whitespace found in object header b'371' b'0'
# Superfluous whitespace found in object header b'374' b'0'
# Superfluous whitespace found in object header b'377' b'0'
# Superfluous whitespace found in object header b'380' b'0'
# Superfluous whitespace found in object header b'383' b'0'
# Superfluous whitespace found in object header b'386' b'0'
# Superfluous whitespace found in object header b'389' b'0'
# Superfluous whitespace found in object header b'392' b'0'
# Superfluous whitespace found in object header b'395' b'0'
# Superfluous whitespace found in object header b'398' b'0'
# Superfluous whitespace found in object header b'401' b'0'
# Superfluous whitespace found in object header b'404' b'0'
# Superfluous whitespace found in object header b'407' b'0'
# Superfluous whitespace found in object header b'410' b'0'
# Superfluous whitespace found in object header b'413' b'0'
# Superfluous whitespace found in object header b'416' b'0'
# Superfluous whitespace found in object header b'419' b'0'
# Superfluous whitespace found in object header b'422' b'0'
# Superfluous whitespace found in object header b'424' b'0'
# Superfluous whitespace found in object header b'19' b'0'
# Superfluous whitespace found in object header b'18' b'0'
# Superfluous whitespace found in object header b'17' b'0'
# Superfluous whitespace found in object header b'15' b'0'
# Superfluous whitespace found in object header b'16' b'0'
# Superfluous whitespace found in object header b'14' b'0'
# Superfluous whitespace found in object header b'13' b'0'
# Superfluous whitespace found in object header b'12' b'0'
# Superfluous whitespace found in object header b'11' b'0'
# Superfluous whitespace found in object header b'10' b'0'
# Superfluous whitespace found in object header b'9' b'0'
# Superfluous whitespace found in object header b'7' b'0'
# Superfluous whitespace found in object header b'8' b'0'
# Superfluous whitespace found in object header b'6' b'0'
# Superfluous whitespace found in object header b'5' b'0'
# Superfluous whitespace found in object header b'4' b'0'
# Superfluous whitespace found in object header b'423' b'0'
# Superfluous whitespace found in object header b'421' b'0'
# Superfluous whitespace found in object header b'420' b'0'
# Superfluous whitespace found in object header b'418' b'0'
# Superfluous whitespace found in object header b'417' b'0'
# Superfluous whitespace found in object header b'415' b'0'
# Superfluous whitespace found in object header b'27' b'0'
# Superfluous whitespace found in object header b'26' b'0'
# Superfluous whitespace found in object header b'25' b'0'
# Superfluous whitespace found in object header b'23' b'0'
# Superfluous whitespace found in object header b'24' b'0'
# Superfluous whitespace found in object header b'22' b'0'
# Superfluous whitespace found in object header b'21' b'0'
# Superfluous whitespace found in object header b'20' b'0'
# Superfluous whitespace found in object header b'414' b'0'
# Superfluous whitespace found in object header b'412' b'0'
# Superfluous whitespace found in object header b'411' b'0'
# Superfluous whitespace found in object header b'409' b'0'
# Superfluous whitespace found in object header b'408' b'0'
# Superfluous whitespace found in object header b'406' b'0'
# Superfluous whitespace found in object header b'301' b'0'
# Superfluous whitespace found in object header b'300' b'0'
# Superfluous whitespace found in object header b'299' b'0'
# Superfluous whitespace found in object header b'297' b'0'
# Superfluous whitespace found in object header b'298' b'0'
# Superfluous whitespace found in object header b'296' b'0'
# Superfluous whitespace found in object header b'295' b'0'
# Superfluous whitespace found in object header b'294' b'0'
# Superfluous whitespace found in object header b'405' b'0'
# Superfluous whitespace found in object header b'403' b'0'
# Superfluous whitespace found in object header b'402' b'0'
# Superfluous whitespace found in object header b'400' b'0'
# Superfluous whitespace found in object header b'399' b'0'
# Superfluous whitespace found in object header b'397' b'0'
# Superfluous whitespace found in object header b'396' b'0'
# Superfluous whitespace found in object header b'394' b'0'
# Superfluous whitespace found in object header b'393' b'0'
# Superfluous whitespace found in object header b'391' b'0'
# Superfluous whitespace found in object header b'390' b'0'
# Superfluous whitespace found in object header b'388' b'0'
# Superfluous whitespace found in object header b'387' b'0'
# Superfluous whitespace found in object header b'385' b'0'
# Superfluous whitespace found in object header b'384' b'0'
# Superfluous whitespace found in object header b'382' b'0'
# Superfluous whitespace found in object header b'381' b'0'
# Superfluous whitespace found in object header b'379' b'0'
# Superfluous whitespace found in object header b'378' b'0'
# Superfluous whitespace found in object header b'376' b'0'
# Superfluous whitespace found in object header b'375' b'0'
# Superfluous whitespace found in object header b'373' b'0'
# Superfluous whitespace found in object header b'372' b'0'
# Superfluous whitespace found in object header b'370' b'0'
# Superfluous whitespace found in object header b'369' b'0'
# Superfluous whitespace found in object header b'367' b'0'
# Superfluous whitespace found in object header b'366' b'0'
# Superfluous whitespace found in object header b'364' b'0'
# Superfluous whitespace found in object header b'363' b'0'
# Superfluous whitespace found in object header b'361' b'0'
# Superfluous whitespace found in object header b'360' b'0'
# Superfluous whitespace found in object header b'358' b'0'
# Superfluous whitespace found in object header b'357' b'0'
# Superfluous whitespace found in object header b'355' b'0'
# Superfluous whitespace found in object header b'49' b'0'
# Superfluous whitespace found in object header b'48' b'0'
# Superfluous whitespace found in object header b'47' b'0'
# Superfluous whitespace found in object header b'45' b'0'
# Superfluous whitespace found in object header b'46' b'0'
# Superfluous whitespace found in object header b'44' b'0'
# Superfluous whitespace found in object header b'43' b'0'
# Superfluous whitespace found in object header b'42' b'0'
# Superfluous whitespace found in object header b'325' b'0'
# Superfluous whitespace found in object header b'324' b'0'
# Superfluous whitespace found in object header b'323' b'0'
# Superfluous whitespace found in object header b'321' b'0'
# Superfluous whitespace found in object header b'322' b'0'
# Superfluous whitespace found in object header b'320' b'0'
# Superfluous whitespace found in object header b'319' b'0'
# Superfluous whitespace found in object header b'318' b'0'
# Superfluous whitespace found in object header b'354' b'0'
# Superfluous whitespace found in object header b'353' b'0'
# Superfluous whitespace found in object header b'352' b'0'
# Superfluous whitespace found in object header b'351' b'0'
# Superfluous whitespace found in object header b'350' b'0'
# Superfluous whitespace found in object header b'349' b'0'
# Superfluous whitespace found in object header b'348' b'0'
# Superfluous whitespace found in object header b'347' b'0'
# Superfluous whitespace found in object header b'346' b'0'
# Superfluous whitespace found in object header b'345' b'0'
# Superfluous whitespace found in object header b'344' b'0'
# Superfluous whitespace found in object header b'343' b'0'
# Superfluous whitespace found in object header b'342' b'0'
# Superfluous whitespace found in object header b'341' b'0'
# Superfluous whitespace found in object header b'340' b'0'
# Superfluous whitespace found in object header b'339' b'0'
# Superfluous whitespace found in object header b'338' b'0'
# Superfluous whitespace found in object header b'337' b'0'
# Superfluous whitespace found in object header b'336' b'0'
# Superfluous whitespace found in object header b'335' b'0'
# Superfluous whitespace found in object header b'334' b'0'
# Superfluous whitespace found in object header b'333' b'0'
# Superfluous whitespace found in object header b'332' b'0'
# Superfluous whitespace found in object header b'331' b'0'
# Superfluous whitespace found in object header b'330' b'0'
# Superfluous whitespace found in object header b'329' b'0'
# Superfluous whitespace found in object header b'328' b'0'
# Superfluous whitespace found in object header b'327' b'0'
# Superfluous whitespace found in object header b'326' b'0'
# Superfluous whitespace found in object header b'316' b'0'
# Superfluous whitespace found in object header b'313' b'0'
# Superfluous whitespace found in object header b'312' b'0'
# Superfluous whitespace found in object header b'311' b'0'
# Superfluous whitespace found in object header b'310' b'0'
# Superfluous whitespace found in object header b'309' b'0'
# Superfluous whitespace found in object header b'308' b'0'
# Superfluous whitespace found in object header b'307' b'0'
# Superfluous whitespace found in object header b'306' b'0'
# Superfluous whitespace found in object header b'314' b'0'
# Superfluous whitespace found in object header b'305' b'0'
# Superfluous whitespace found in object header b'315' b'0'
# Superfluous whitespace found in object header b'303' b'0'
# Superfluous whitespace found in object header b'291' b'0'
# Superfluous whitespace found in object header b'290' b'0'
# Superfluous whitespace found in object header b'289' b'0'
# Superfluous whitespace found in object header b'288' b'0'
# Superfluous whitespace found in object header b'287' b'0'
# Superfluous whitespace found in object header b'286' b'0'
# Superfluous whitespace found in object header b'285' b'0'
# Superfluous whitespace found in object header b'284' b'0'
# Superfluous whitespace found in object header b'293' b'0'
# Superfluous whitespace found in object header b'292' b'0'
# Superfluous whitespace found in object header b'283' b'0'
# Superfluous whitespace found in object header b'302' b'0'
# Superfluous whitespace found in object header b'281' b'0'
# Superfluous whitespace found in object header b'237' b'0'
# Superfluous whitespace found in object header b'236' b'0'
# Superfluous whitespace found in object header b'235' b'0'
# Superfluous whitespace found in object header b'233' b'0'
# Superfluous whitespace found in object header b'234' b'0'
# Superfluous whitespace found in object header b'232' b'0'
# Superfluous whitespace found in object header b'231' b'0'
# Superfluous whitespace found in object header b'230' b'0'
# Superfluous whitespace found in object header b'280' b'0'
# Superfluous whitespace found in object header b'279' b'0'
# Superfluous whitespace found in object header b'278' b'0'
# Superfluous whitespace found in object header b'277' b'0'
# Superfluous whitespace found in object header b'276' b'0'
# Superfluous whitespace found in object header b'275' b'0'
# Superfluous whitespace found in object header b'274' b'0'
# Superfluous whitespace found in object header b'273' b'0'
# Superfluous whitespace found in object header b'272' b'0'
# Superfluous whitespace found in object header b'271' b'0'
# Superfluous whitespace found in object header b'270' b'0'
# Superfluous whitespace found in object header b'269' b'0'
# Superfluous whitespace found in object header b'268' b'0'
# Superfluous whitespace found in object header b'267' b'0'
# Superfluous whitespace found in object header b'266' b'0'
# Superfluous whitespace found in object header b'265' b'0'
# Superfluous whitespace found in object header b'264' b'0'
# Superfluous whitespace found in object header b'263' b'0'
# Superfluous whitespace found in object header b'262' b'0'
# Superfluous whitespace found in object header b'261' b'0'
# Superfluous whitespace found in object header b'260' b'0'
# Superfluous whitespace found in object header b'259' b'0'
# Superfluous whitespace found in object header b'258' b'0'
# Superfluous whitespace found in object header b'257' b'0'
# Superfluous whitespace found in object header b'256' b'0'
# Superfluous whitespace found in object header b'255' b'0'
# Superfluous whitespace found in object header b'254' b'0'
# Superfluous whitespace found in object header b'253' b'0'
# Superfluous whitespace found in object header b'251' b'0'
# Superfluous whitespace found in object header b'246' b'0'
# Superfluous whitespace found in object header b'245' b'0'
# Superfluous whitespace found in object header b'244' b'0'
# Superfluous whitespace found in object header b'243' b'0'
# Superfluous whitespace found in object header b'242' b'0'
# Superfluous whitespace found in object header b'241' b'0'
# Superfluous whitespace found in object header b'240' b'0'
# Superfluous whitespace found in object header b'239' b'0'
# Superfluous whitespace found in object header b'249' b'0'
# Superfluous whitespace found in object header b'248' b'0'
# Superfluous whitespace found in object header b'247' b'0'
# Superfluous whitespace found in object header b'238' b'0'
# Superfluous whitespace found in object header b'250' b'0'
# Superfluous whitespace found in object header b'228' b'0'
# Superfluous whitespace found in object header b'227' b'0'
# Superfluous whitespace found in object header b'225' b'0'
# Superfluous whitespace found in object header b'224' b'0'
# Superfluous whitespace found in object header b'222' b'0'
# Superfluous whitespace found in object header b'221' b'0'
# Superfluous whitespace found in object header b'219' b'0'
# Superfluous whitespace found in object header b'218' b'0'
# Superfluous whitespace found in object header b'216' b'0'
# Superfluous whitespace found in object header b'214' b'0'
# Superfluous whitespace found in object header b'213' b'0'
# Superfluous whitespace found in object header b'212' b'0'
# Superfluous whitespace found in object header b'215' b'0'
# Superfluous whitespace found in object header b'210' b'0'
# Superfluous whitespace found in object header b'209' b'0'
# Superfluous whitespace found in object header b'207' b'0'
# Superfluous whitespace found in object header b'206' b'0'
# Superfluous whitespace found in object header b'205' b'0'
# Superfluous whitespace found in object header b'204' b'0'
# Superfluous whitespace found in object header b'203' b'0'
# Superfluous whitespace found in object header b'202' b'0'
# Superfluous whitespace found in object header b'201' b'0'
# Superfluous whitespace found in object header b'200' b'0'
# Superfluous whitespace found in object header b'199' b'0'
# Superfluous whitespace found in object header b'198' b'0'
# Superfluous whitespace found in object header b'197' b'0'
# Superfluous whitespace found in object header b'196' b'0'
# Superfluous whitespace found in object header b'195' b'0'
# Superfluous whitespace found in object header b'194' b'0'
# Superfluous whitespace found in object header b'193' b'0'
# Superfluous whitespace found in object header b'192' b'0'
# Superfluous whitespace found in object header b'191' b'0'
# Superfluous whitespace found in object header b'190' b'0'
# Superfluous whitespace found in object header b'189' b'0'
# Superfluous whitespace found in object header b'188' b'0'
# Superfluous whitespace found in object header b'187' b'0'
# Superfluous whitespace found in object header b'186' b'0'
# Superfluous whitespace found in object header b'185' b'0'
# Superfluous whitespace found in object header b'184' b'0'
# Superfluous whitespace found in object header b'183' b'0'
# Superfluous whitespace found in object header b'182' b'0'
# Superfluous whitespace found in object header b'181' b'0'
# Superfluous whitespace found in object header b'180' b'0'
# Superfluous whitespace found in object header b'179' b'0'
# Superfluous whitespace found in object header b'178' b'0'
# Superfluous whitespace found in object header b'176' b'0'
# Superfluous whitespace found in object header b'175' b'0'
# Superfluous whitespace found in object header b'173' b'0'
# Superfluous whitespace found in object header b'171' b'0'
# Superfluous whitespace found in object header b'170' b'0'
# Superfluous whitespace found in object header b'169' b'0'
# Superfluous whitespace found in object header b'167' b'0'
# Superfluous whitespace found in object header b'168' b'0'
# Superfluous whitespace found in object header b'166' b'0'
# Superfluous whitespace found in object header b'165' b'0'
# Superfluous whitespace found in object header b'164' b'0'
# Superfluous whitespace found in object header b'172' b'0'
# Superfluous whitespace found in object header b'162' b'0'
# Superfluous whitespace found in object header b'161' b'0'
# Superfluous whitespace found in object header b'160' b'0'
# Superfluous whitespace found in object header b'159' b'0'
# Superfluous whitespace found in object header b'158' b'0'
# Superfluous whitespace found in object header b'157' b'0'
# Superfluous whitespace found in object header b'156' b'0'
# Superfluous whitespace found in object header b'155' b'0'
# Superfluous whitespace found in object header b'154' b'0'
# Superfluous whitespace found in object header b'153' b'0'
# Superfluous whitespace found in object header b'152' b'0'
# Superfluous whitespace found in object header b'151' b'0'
# Superfluous whitespace found in object header b'150' b'0'
# Superfluous whitespace found in object header b'149' b'0'
# Superfluous whitespace found in object header b'148' b'0'
# Superfluous whitespace found in object header b'147' b'0'
# Superfluous whitespace found in object header b'146' b'0'
# Superfluous whitespace found in object header b'145' b'0'
# Superfluous whitespace found in object header b'144' b'0'
# Superfluous whitespace found in object header b'143' b'0'
# Superfluous whitespace found in object header b'142' b'0'
# Superfluous whitespace found in object header b'141' b'0'
# Superfluous whitespace found in object header b'140' b'0'
# Superfluous whitespace found in object header b'139' b'0'
# Superfluous whitespace found in object header b'138' b'0'
# Superfluous whitespace found in object header b'137' b'0'
# Superfluous whitespace found in object header b'136' b'0'
# Superfluous whitespace found in object header b'135' b'0'
# Superfluous whitespace found in object header b'134' b'0'
# Superfluous whitespace found in object header b'133' b'0'
# Superfluous whitespace found in object header b'131' b'0'
# Superfluous whitespace found in object header b'68' b'0'
# Superfluous whitespace found in object header b'67' b'0'
# Superfluous whitespace found in object header b'66' b'0'
# Superfluous whitespace found in object header b'64' b'0'
# Superfluous whitespace found in object header b'65' b'0'
# Superfluous whitespace found in object header b'63' b'0'
# Superfluous whitespace found in object header b'62' b'0'
# Superfluous whitespace found in object header b'61' b'0'
# Superfluous whitespace found in object header b'130' b'0'
# Superfluous whitespace found in object header b'128' b'0'
# Superfluous whitespace found in object header b'126' b'0'
# Superfluous whitespace found in object header b'125' b'0'
# Superfluous whitespace found in object header b'124' b'0'
# Superfluous whitespace found in object header b'122' b'0'
# Superfluous whitespace found in object header b'123' b'0'
# Superfluous whitespace found in object header b'121' b'0'
# Superfluous whitespace found in object header b'120' b'0'
# Superfluous whitespace found in object header b'119' b'0'
# Superfluous whitespace found in object header b'118' b'0'
# Superfluous whitespace found in object header b'117' b'0'
# Superfluous whitespace found in object header b'116' b'0'
# Superfluous whitespace found in object header b'114' b'0'
# Superfluous whitespace found in object header b'115' b'0'
# Superfluous whitespace found in object header b'113' b'0'
# Superfluous whitespace found in object header b'112' b'0'
# Superfluous whitespace found in object header b'111' b'0'
# Superfluous whitespace found in object header b'110' b'0'
# Superfluous whitespace found in object header b'109' b'0'
# Superfluous whitespace found in object header b'108' b'0'
# Superfluous whitespace found in object header b'106' b'0'
# Superfluous whitespace found in object header b'107' b'0'
# Superfluous whitespace found in object header b'105' b'0'
# Superfluous whitespace found in object header b'104' b'0'
# Superfluous whitespace found in object header b'103' b'0'
# Superfluous whitespace found in object header b'127' b'0'
# Superfluous whitespace found in object header b'101' b'0'
# Superfluous whitespace found in object header b'100' b'0'
# Superfluous whitespace found in object header b'99' b'0'
# Superfluous whitespace found in object header b'98' b'0'
# Superfluous whitespace found in object header b'97' b'0'
# Superfluous whitespace found in object header b'96' b'0'
# Superfluous whitespace found in object header b'95' b'0'
# Superfluous whitespace found in object header b'94' b'0'
# Superfluous whitespace found in object header b'93' b'0'
# Superfluous whitespace found in object header b'92' b'0'
# Superfluous whitespace found in object header b'91' b'0'
# Superfluous whitespace found in object header b'90' b'0'
# Superfluous whitespace found in object header b'89' b'0'
# Superfluous whitespace found in object header b'88' b'0'
# Superfluous whitespace found in object header b'87' b'0'
# Superfluous whitespace found in object header b'86' b'0'
# Superfluous whitespace found in object header b'85' b'0'
# Superfluous whitespace found in object header b'84' b'0'
# Superfluous whitespace found in object header b'83' b'0'
# Superfluous whitespace found in object header b'82' b'0'
# Superfluous whitespace found in object header b'81' b'0'
# Superfluous whitespace found in object header b'80' b'0'
# Superfluous whitespace found in object header b'79' b'0'
# Superfluous whitespace found in object header b'78' b'0'
# Superfluous whitespace found in object header b'77' b'0'
# Superfluous whitespace found in object header b'76' b'0'
# Superfluous whitespace found in object header b'75' b'0'
# Superfluous whitespace found in object header b'73' b'0'
# Superfluous whitespace found in object header b'72' b'0'
# Superfluous whitespace found in object header b'70' b'0'
# Superfluous whitespace found in object header b'60' b'0'
# Superfluous whitespace found in object header b'59' b'0'
# Superfluous whitespace found in object header b'58' b'0'
# Superfluous whitespace found in object header b'56' b'0'
# Superfluous whitespace found in object header b'57' b'0'
# Superfluous whitespace found in object header b'55' b'0'
# Superfluous whitespace found in object header b'54' b'0'
# Superfluous whitespace found in object header b'53' b'0'
# Superfluous whitespace found in object header b'69' b'0'
# Superfluous whitespace found in object header b'51' b'0'
# Superfluous whitespace found in object header b'39' b'0'
# Superfluous whitespace found in object header b'38' b'0'
# Superfluous whitespace found in object header b'37' b'0'
# Superfluous whitespace found in object header b'36' b'0'
# Superfluous whitespace found in object header b'35' b'0'
# Superfluous whitespace found in object header b'34' b'0'
# Superfluous whitespace found in object header b'33' b'0'
# Superfluous whitespace found in object header b'32' b'0'
# Superfluous whitespace found in object header b'41' b'0'
# Superfluous whitespace found in object header b'40' b'0'
# Superfluous whitespace found in object header b'31' b'0'
# Superfluous whitespace found in object header b'50' b'0'
# Superfluous whitespace found in object header b'29' b'0'
# Superfluous whitespace found in object header b'28' b'0'

# %%
# Whittier

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Whittier_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Whittier_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Whittier_Part3.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Whittier.pdf")
merger.close()

# %%
# Windsor

# initializing merge
merger = PdfFileMerger()

for pdf in ["C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Windsor_Part1.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Windsor_Part2.pdf",
            "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Windsor_Part3.pdf",
           "C:/Users/melod/Documents/data science/Food-Systems-Policy-Research/Food Systems and General Plans/General Plan Sections/Windsor_Part4.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("Windsor.pdf")
merger.close()
