# %% [markdown]
# # U.S. Farm Bills (1935 to 2018)
#
# There are 19 total "farm bills", with bills for years 1996 to 2018 available as text online and bills from 1935 to 1990 available only as PDF on this [website](https://nationalaglawcenter.org/farmbills/) hosting an archive of agriculture-related federal legislation.
#
# **Questions of interest**: What are the most important priorities across the different farm bills and how have they changed over time? How has the role of soil conservation in agriculture changed over time in the bills?

# %%
# installing spacy
#!pip install -U pip setuptools wheel
#!pip install -U spacy
#python -m download en_core_web_md #(for word vector models)
#!pip install spacy-transformers
#python -m download en_trf-bertbaseuncased_lg # transformer architectures (large model)

# %%
# libraries
import pandas as pd
import geopandas as gpd
import numpy as np

import requests
import urllib
from urllib.request import urlopen
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options as FirefoxOptions
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from webdriver_manager.firefox import GeckoDriverManager
from bs4 import BeautifulSoup

from pdfminer.high_level import extract_text
from PyPDF2 import PdfFileReader, PdfFileWriter, PdfFileMerger

import re
import os
import os.path
from sklearn import svm
import spacy
import torch
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer
import json

# set display
pd.options.display.max_columns = 150
pd.options.display.max_rows = 300

# %%
# scraping from URL: unable to scrape using urllib and requests, have to use Selenium
URL = 'https://nationalaglawcenter.org/farmbills/'

# %%
# initializing
#service = Service(executable_path = r'C:\Users\melod\Documents\data science\geckodriver-v0.33.0-win64\geckodriver.exe')
options = webdriver.FirefoxOptions()
options.add_argument("--headless")
driver = webdriver.Firefox(options = options, service = Service(GeckoDriverManager().install()))
driver.get(URL)
# Out:
# C:\Users\melod\AppData\Local\Temp\ipykernel_23500\134595942.py:2: DeprecationWarning: Firefox will soon stop logging to geckodriver.log by default; Specify desired logs with log_output
#   service = Service(executable_path = r'C:\Users\melod\Documents\data science\geckodriver-v0.33.0-win64\geckodriver.exe')
# C:\Users\melod\AppData\Local\Temp\ipykernel_23500\134595942.py:5: DeprecationWarning: Firefox will soon stop logging to geckodriver.log by default; Specify desired logs with log_output
#   driver = webdriver.Firefox(options = options, service = Service(GeckoDriverManager().install()))

# %%
# collecting bill text/PDF URLs
headers = driver.find_elements(By.TAG_NAME, 'h3')

sections = []
for header in headers:
    header = header.text
    sections.append(header)

sections
# Out:
# ['GENERAL RESOURCES',
#  'FARM BILL LEGISLATION',
#  'Additional Historical Farm Legislation',
#  'GENERAL RESOURCES',
#  'Congressional Research Service Report Subjects:',
#  'FARM BILL LEGISLATION',
#  'The 2014 Farm Bill: Agricultural Act of 2014',
#  'The 2008 Farm Bill: Food, Conservation, and Energy Act of 2008 (H.R. 6124)',
#  'The 2002 Farm Bill: The Farm Security and Rural Investment Act of 2002',
#  'The 1996 Farm Bill: The Federal Agriculture Improvement and Reform Act of 1996',
#  'Food, Agriculture, Conservation, and Trade Act of 1990',
#  'Food Security Act of 1985',
#  'Agriculture and Food Act of 1981',
#  'Food and Agriculture Act of 1977',
#  'Agricultural and Consumer Protection Act of 1973',
#  'Agricultural Act of 1970',
#  'Food and Agricultural Act of 1965',
#  'Agricultural Act of 1956',
#  'Agricultural Act of 1954',
#  'Agricultural Act of 1949',
#  'Agricultural Act of 1948',
#  'Agricultural Adjustment Act of 1938',
#  'Agricultural Adjustment Act of 1933',
#  'Amendments to the National Wool Act',
#  'Omnibus Budget Reconciliation Act of 1993 (selected provisions)',
#  'Omnibus Budget Reconciliation Act of 1990 (selected provisions)',
#  'Omnibus Budget Reconciliation Act of 1989(selected provisions)',
#  'Omnibus Budget Reconciliation Act of 1987(selected provisions)',
#  'Food Security Improvements Act of 1986',
#  'Technical Corrections to Food Security Act of 1985 Amendments',
#  'Agricultural Programs Adjustment Act of 1984',
#  'Dairy and Tobacco Adjustment Act of 1983',
#  'Extra-Long Staple Cotton Act of 1983',
#  'Omnibus Budget Reconciliation Act of 1982 (selected provisions)',
#  'Agricultural Act of 1964',
#  'Food and Agricultural Act of 1962',
#  'Commodity Credit Corporation Charter Act of 1948',
#  'Steagall Amendment of 1941 (Steagall Commodity Credit Act) of 1941',
#  'Soil Conservation and Domestic Allotment Act of 1936',
#  'Soil Conservation and Domestic Allotment Act of 1935']

# %%
# collecting bill text/PDF URLs
#bills = driver.find_elements(By.XPATH, '//a[@class="toc-item-heading"]')
bills = driver.find_elements(By.TAG_NAME, 'a')
#bills = driver.find_elements(By.PARTIAL_LINK_TEXT, 'congress.gov/bill')

billlist = []
for bill in bills:
    bill = bill.get_attribute('href')
    billlist.append(bill)

billlist
# Out:
# [None,
#  'https://nationalaglawcenter.org/',
#  'http://nationalaglawcenter.org/ag-and-food-law-blog/',
#  'https://nationalaglawcenter.org/about-the-center/',
#  'https://nationalaglawcenter.org/about-the-center/professional-staff/',
#  'https://nationalaglawcenter.org/partners/',
#  'https://nationalaglawcenter.org/research-by-topic/',
#  'https://nationalaglawcenter.org/center-publications/',
#  'https://nationalaglawcenter.org/webinars/',
#  'https://nationalaglawcenter.org/state-compilations/',
#  'https://nationalaglawcenter.org/farmbills/',
#  'https://nationalaglawcenter.org/ag-law-bibliography/',
#  'https://nationalaglawcenter.org/ag-law-glossary/',
#  'https://nationalaglawcenter.org/aglaw-reporter/',
#  'https://nationalaglawcenter.org/general-resources/',
#  'https://nationalaglawcenter.org/website-guide/',
#  'https://nationalaglawcenter.org/disclaimer/',
#  'https://nationalaglawcenter.org/about-the-center/',
#  'https://nationalaglawcenter.org/about-the-center/professional-staff/',
#  'https://www.congress.gov/bill/115th-congress/house-bill/2/text',
#  'https://www.fb.org/files/House_and_Senate_Side-By-Side_(2).docx.pdf',
#  'https://nationalaglawcenter.org/ag-and-food-law-blog/',
#  'https://crsreports.congress.gov/search/#/?termsToSearch=united%20states%20farm%20bills&orderBy=Relevance',
#  'https://fas.org/sgp/crs/misc/R45210.pdf',
#  'https://www.ers.usda.gov/topics/farm-economy/farm-commodity-policy/analysis-of-previous-farm-bills/',
#  'https://www.ers.usda.gov/topics/farm-economy/farm-commodity-policy/',
#  'https://nationalaglawcenter.org/farmbills/#2018',
#  'https://nationalaglawcenter.org/farmbills/#2014',
#  'https://nationalaglawcenter.org/farmbills/#2008',
#  'https://nationalaglawcenter.org/farmbills/#2002',
#  'https://nationalaglawcenter.org/farmbills/#1996',
#  'https://nationalaglawcenter.org/farmbills/#1990',
#  'https://nationalaglawcenter.org/farmbills/#1985',
#  'https://nationalaglawcenter.org/farmbills/#1981',
#  'https://nationalaglawcenter.org/farmbills/#1981',
#  'https://nationalaglawcenter.org/farmbills/#1977',
#  'https://nationalaglawcenter.org/farmbills/#1977',
#  'https://nationalaglawcenter.org/farmbills/#1973',
#  'https://nationalaglawcenter.org/farmbills/#1973',
#  'https://nationalaglawcenter.org/farmbills/#1970',
#  'https://nationalaglawcenter.org/farmbills/#1970',
#  'https://nationalaglawcenter.org/farmbills/#1965',
#  'https://nationalaglawcenter.org/farmbills/#1965',
#  'https://nationalaglawcenter.org/farmbills/#1956',
#  'https://nationalaglawcenter.org/farmbills/#1985',
#  'https://nationalaglawcenter.org/farmbills/#1954',
#  'https://nationalaglawcenter.org/farmbills/#1985',
#  'https://nationalaglawcenter.org/farmbills/#1949',
#  'https://nationalaglawcenter.org/farmbills/#1985',
#  'https://nationalaglawcenter.org/farmbills/#1948',
#  'https://nationalaglawcenter.org/farmbills/#1985',
#  'https://nationalaglawcenter.org/farmbills/#1938',
#  'https://nationalaglawcenter.org/farmbills/#1985',
#  'https://nationalaglawcenter.org/farmbills/#1933',
#  'https://www.usaid.gov/sites/default/files/documents/1866/Food%20For%20Peace%20Act%20Version%20Nov%202014.pdf',
#  'https://nationalaglawcenter.org/farmbills/#wool',
#  'https://nationalaglawcenter.org/farmbills/#omnibus93',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#omnibus90',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#omnibus89',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#omnibus87',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-101/pdf/STATUTE-101-Pg1330.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#foodsecurity',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-99/pdf/STATUTE-99-Pg1354.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#corrections',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-100/pdf/STATUTE-100-Pg36.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#adjustment84',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-98/pdf/STATUTE-98-Pg130.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#adjustment83',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-97/pdf/STATUTE-97-Pg1128.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#cotton',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-97/pdf/STATUTE-97-Pg494.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#omnibus82',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-96/pdf/STATUTE-96-Pg763.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.govinfo.gov/content/pkg/STATUTE-80/pdf/STATUTE-80-Pg1526.pdf',
#  'https://nationalaglawcenter.org/farmbills/#ag64',
#  'https://www.govinfo.gov/content/pkg/STATUTE-78/pdf/STATUTE-78-Pg173-2.pdf',
#  'https://www.govinfo.gov/content/pkg/STATUTE-78/pdf/STATUTE-78-Pg173-2.pdf',
#  'https://www.govinfo.gov/content/pkg/STATUTE-78/pdf/STATUTE-78-Pg703.pdf',
#  'https://www.govinfo.gov/content/pkg/STATUTE-78/pdf/STATUTE-78-Pg173-2.pdf',
#  'https://nationalaglawcenter.org/farmbills/#ag62',
#  'https://www.govinfo.gov/content/pkg/STATUTE-78/pdf/STATUTE-78-Pg173-2.pdf',
#  'https://www.govinfo.gov/content/pkg/STATUTE-76/pdf/STATUTE-76-Pg605-2.pdf',
#  'https://www.govinfo.gov/content/pkg/STATUTE-78/pdf/STATUTE-78-Pg173-2.pdf',
#  'https://www.govinfo.gov/content/pkg/STATUTE-68/pdf/STATUTE-68-Pg454-2.pdf',
#  'https://nationalaglawcenter.org/farmbills/#ccc48',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://www.agriculture.senate.gov/imo/media/doc/Commodity%20Credit%20Corporation%20Charter%20Act.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#steagall',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#soil36',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993',
#  'https://nationalaglawcenter.org/farmbills/#soil35',
#  'https://nationalaglawcenter.org/farmbills/#1935',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/crop-commodity-programs/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/dairy-livestock/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/conservation/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/trade/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/nutrition/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/credit/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/rural-development/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/research-extension-and-related-matters/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/energy/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/crop-insurance/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/specialty-crops/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/organic-agriculture/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/local-and-regional-foods/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/beginning-socially-disadvantaged-and-veteran-farmers-and-ranchers/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/ers-farm-bill-related-research/',
#  'https://www.rd.usda.gov/files/RDFarmBillHighlights.pdf',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/crop-commodity-programs/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/dairy-livestock/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/conservation/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/nutrition/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/rural-development/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/research/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/energy/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/crop-insurance/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/specialty-crops/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/organic-agriculture/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/local-and-regional-foods/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/beginning-farmers-and-ranchers/',
#  'https://www.ers.usda.gov/agricultural-act-of-2014-highlights-and-implications/socially-disadvantaged-and-veteran-farmers-and-ranchers/',
#  'https://crsreports.congress.gov/product/pdf/R/R45525',
#  'https://crsreports.congress.gov/product/pdf/IF/IF11126',
#  'https://nationalaglawcenter.org/wp-content/uploads/2014/02/R43076.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/In%20Focus/IF00014.pdf',
#  'http://webarchives.cdlib.org/sw1vh5dg3r/http:/ers.usda.gov/FarmBill/2008/',
#  'https://www.ers.usda.gov/publications/pub-details/?pubid=42674',
#  'http://webarchives.cdlib.org/sw1vh5dg3r/http:/ers.usda.gov/publications/agoutlook/aosupp.pdf',
#  'http://www.ers.usda.gov/topics/farm-economy/farm-commodity-policy.aspx',
#  'https://nationalaglawcenter.org/ag-and-food-law-blog/',
#  'https://nationalaglawcenter.org/crs/#commodities',
#  'https://nationalaglawcenter.org/crs/#disaster',
#  'https://nationalaglawcenter.org/crs/#energy',
#  'https://nationalaglawcenter.org/crs/#environmental',
#  'https://nationalaglawcenter.org/crs/#farmbills',
#  'https://nationalaglawcenter.org/crs/#finance',
#  'https://nationalaglawcenter.org/crs/#foodsafety',
#  'https://nationalaglawcenter.org/crs/#foodsecurity',
#  'https://nationalaglawcenter.org/crs/#forestry',
#  'https://nationalaglawcenter.org/crs/#internationalag',
#  'https://nationalaglawcenter.org/crs/#rural',
#  'https://nationalaglawcenter.org/crs/#sustainable',
#  'https://nationalaglawcenter.org/crs/#farmbills',
#  None,
#  'https://www.congress.gov/bill/115th-congress/house-bill/2/text?format=txt&q=%7B%22search%22%3A%5B%22hr2%22%5D%7D&r=1',
#  'https://www.congress.gov/115/bills/hr2/BILLS-115hr2enr.pdf',
#  'https://www.agriculture.senate.gov/',
#  'https://agriculture.house.gov/search/?q=2018+Farm+Bill',
#  'https://www.agriculture.senate.gov/2018-farm-bill',
#  'https://www.cbo.gov/system/files/2018-12/hr2conf_0.pdf',
#  'https://www.profarmer.com/system/files/inline-files/Summary.pdf',
#  'https://www.firstdistrict.com/wp-content/uploads/2018/12/HR2-Conference-Report-One-Pager-Dairy.pdf',
#  'https://www.profarmer.com/system/files/inline-files/Highlights.pdf',
#  'https://crsreports.congress.gov/search/#/?termsToSearch=Farm%20Bill%202018&orderBy=Relevance',
#  'https://crsreports.congress.gov/product/pdf/IF/IF11319',
#  'https://www.fsa.usda.gov/programs-and-services/farm-bill/index',
#  'https://www.nrcs.usda.gov/wps/portal/nrcs/main/national/programs/farmbill/',
#  'https://www.farmers.gov/farmbill',
#  'https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/programs/farmbill/?cid=stelprdb1263599',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/ers-farm-bill-related-research/',
#  'https://www.ers.usda.gov/agriculture-improvement-act-of-2018-highlights-and-implications/',
#  'https://www.fsa.usda.gov/Assets/USDA-FSA-Public/usdafiles/FactSheets/2019/arc-plc_farm_bill_comparisons-fact_sheet-aug-2019.pdf',
#  'https://hempsupporter.com/assets/uploads/What-Does-the-Farm-Bill-Do.pdf',
#  'https://frac.org/wp-content/uploads/2018-farm-bill-conference-report-analysis.pdf',
#  'https://ag.purdue.edu/commercialag/home/wp-content/uploads/2020/01/202001_LangemeierMintert_2018FarmBill.pdf',
#  'https://www.fb.org/issues/farm-policy/farm-bureau-farm-bill-resources-in-depth/',
#  'http://old.farmlandinfo.org/2018-farm-bill',
#  'http://old.farmlandinfo.org/2018-farm-bill',
#  'https://www.lsuagcenter.com/articles/page1545166261275',
#  'https://www.fb.org/market-intel/congressional-budget-office-updates-farm-bill-math',
#  'https://www.ocj.com/2020/01/taking-a-look-at-the-2018-farm-bill-a-year-later/',
#  'https://nfu.org/2019/01/16/environmental-sustainability-in-the-2018-farm-bill/',
#  'https://farmdocdaily.illinois.edu/wp-content/uploads/2018/07/fdd190718.pdf',
#  'https://farmdocdaily.illinois.edu/wp-content/uploads/2018/07/fdd190718.pdf',
#  'https://www.congress.gov/115/bills/hr2/BILLS-115hr2eh.pdf',
#  'https://www.agriculture.senate.gov/2018-farm-bill',
#  'https://docs.house.gov/billsthisweek/20181210/CRPT-115hrpt1072.pdf',
#  'https://docs.house.gov/billsthisweek/20181210/Joint%20Explanatory%20Statement.pdf',
#  'https://www.fishwildlife.org/application/files/8515/1207/2446/AFWA_Policy_Priorities_for_the_2018_Farm_Bill_final_10Mar2017.pdf',
#  'https://www.fishwildlife.org/application/files/3915/1870/7876/2-pager_AFWA_Policy_Priorities_for_the_2018_Farm_Bill.pdf',
#  'https://sustainableagriculture.net/blog/2018-farm-bill-drilldown-research/',
#  'https://www.brookings.edu/blog/fixgov/2018/12/14/the-farm-bill-hemp-and-cbd-explainer/',
#  'https://www.wto.org/english/tratop_e/agric_e/johansson_farm_bill_wto_presentation_02252019_final.pdf',
#  'https://www.nasda.org/policy/issues/farm-bill',
#  'https://www.nasda.org/policy/issues/farm-bill',
#  'https://www.arec.umd.edu/extension/2018-farm-bill-guides',
#  'https://www.agecon.msstate.edu/',
#  'https://www.fb.org/news/farm-bureau-details-farm-bill-priorities',
#  'https://www.nasda.org/policy/issues/farm-bill/state-farm-bill-infographics',
#  'https://www.fb.org/files/House_and_Senate_Side-By-Side_(2).docx.pdf',
#  'https://crsreports.congress.gov/product/pdf/R/R45525',
#  None,
#  'https://www.govinfo.gov/content/pkg/PLAW-113publ79/html/PLAW-113publ79.htm',
#  'https://www.govinfo.gov/content/pkg/BILLS-113hr2642enr/pdf/BILLS-113hr2642enr.pdf',
#  'https://fas.org/sgp/crs/misc/R45210.pdf',
#  'https://www.congress.gov/113/crpt/hrpt333/CRPT-113hrpt333.pdf',
#  'http://www.agriculture.senate.gov/',
#  'http://www.ag.senate.gov/issues/farm-bill',
#  'http://agriculture.house.gov/',
#  'https://crsreports.congress.gov/search/#/?termsToSearch=Farm%20Bill%202014&orderBy=Relevance',
#  'https://crsreports.congress.gov/search/#/?termsToSearch=Farm%20Bill%202014&orderBy=Relevance',
#  'http://www.cbo.gov/sites/default/files/cbofiles/attachments/hr2642LucasLtr.pdf',
#  'https://www.fsa.usda.gov/programs-and-services/farm-bill/index',
#  'https://www.fsa.usda.gov/Assets/USDA-FSA-Public/usdafiles/Farm-Bill/pdf/usda-2014-farm-bill-highlights.pdf',
#  'https://www.fsa.usda.gov/Assets/USDA-FSA-Public/usdafiles/Farm-Bill/pdf/usda-2014-farm-bill-highlights.pdf',
#  'http://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/programs/farmbill/?cid=stelprdb1244667',
#  'http://www.fsa.usda.gov/Internet/FSA_File/2014_farm_bill_customers.pdf',
#  'https://farmdocdaily.illinois.edu/?s=2014+farm+bill',
#  'https://www.uaex.uada.edu/farm-ranch/economics-marketing/docs/FarmBill2014Brief_02.26.2014.pdf',
#  'https://farmdocdaily.illinois.edu/2016/07/compare-2014-2008-farm-bill-programs.html',
#  'https://www.farmfoundation.org/projects/2013-14-farm-bill-reading-room-1861-d1/',
#  'http://www.cbpp.org/research/summary-of-the-2014-farm-bill-nutrition-title-includes-bipartisan-improvements-to-snap',
#  'http://sustainableagriculture.net/publications/grassrootsguide/',
#  'https://www.fb.org/issues/farm-policy/farm-bill-resources-background-papers-on-various-farm-bill-topics/',
#  'https://crsreports.congress.gov/product/pdf/R/R43431/3',
#  'http://www.agmanager.info/ag-policy/farm-bill',
#  'https://www.lsuagcenter.com/portals/our_offices/departments/ag-economics-agribusiness/extension_outreach/2014-farm-bill-information',
#  'https://www.fishwildlife.org/application/files/3615/1207/2480/1_Full_Report_2014_Farm_Bill_Guide_1.pdf',
#  'https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/programs/farmbill/?cid=stelprdb1237774',
#  'https://www.youtube.com/watch?time_continue=1&v=Y0LBRDKgMk8',
#  'https://agecoext.tamu.edu/resources/farm-bill/farm-bill-educational-materials/',
#  None,
#  'https://www.congress.gov/bill/110th-congress/house-bill/6124/text',
#  'https://www.congress.gov/110/plaws/publ246/PLAW-110publ246.pdf',
#  'https://www.congress.gov/bill/110th-congress/house-bill/6124/actions',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/articles/obrien_animalid-newfarmbill.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/articles/obrien_wto.pdf',
#  'http://www.agriculture.senate.gov/',
#  'http://www.ag.senate.gov/issues/2008-farm-bill',
#  'https://agriculture.house.gov/',
#  'https://crsreports.congress.gov/search/#/?termsToSearch=Farm%20Bill%202008&orderBy=Relevance',
#  'https://fas.org/sgp/crs/misc/R42442.pdf',
#  'https://www.ers.usda.gov/topics/farm-economy/farm-commodity-policy/analysis-of-previous-farm-bills/',
#  'https://www.cbpp.org/sites/default/files/atoms/files/5-23-08fa.pdf',
#  'https://heinonline.org/HOL/LandingPage?handle=hein.journals/vermenl12&div=20&id=&page=',
#  'https://link.springer.com/content/pdf/10.1007/s10460-009-9247-0.pdf',
#  'https://digitalcommons.unl.edu/cgi/viewcontent.cgi?article=1023&context=ageconworkpap',
#  'https://sustainableagriculture.net/wp-content/uploads/2017/10/Cultivating-the-Next-Generation-Oct-2017.pdf',
#  'https://sustainableagriculture.net/wp-content/uploads/2017/10/Cultivating-the-Next-Generation-Oct-2017.pdf',
#  'https://sustainableagriculture.net/wp-content/uploads/2017/10/Cultivating-the-Next-Generation-Oct-2017.pdf',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://www.congress.gov/bill/107th-congress/house-bill/2646/text',
#  'http://frwebgate.access.gpo.gov/cgi-bin/getdoc.cgi?dbname=107_cong_public_laws&docid=f:publ171.107.pdf',
#  'https://www.congress.gov/bill/107th-congress/house-bill/2646',
#  'https://www.ers.usda.gov/webdocs/publications/42660/13780_ap022_4_.pdf?v=0',
#  'https://www.ers.usda.gov/webdocs/publications/42660/13780_ap022_4_.pdf?v=0',
#  'http://www.ag.senate.gov/issues/farm-bill',
#  'https://web.archive.org/web/20191229060401/https://www.cfra.org/policy/2002',
#  'https://web.archive.org/web/20171208053450/http://agebb.missouri.edu:80/mgt/farmbill/',
#  'https://nationalaglawcenter.org/farmbills/conservation/',
#  'https://nationalaglawcenter.org/farmbills/commodity/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/crs/RL31524.pdf',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/#1996',
#  'https://www.govtrack.us/congress/bills/104/hr2854/text',
#  'https://www.congress.gov/104/plaws/publ127/PLAW-104publ127.pdf',
#  'https://www.congress.gov/bill/104th-congress/house-bill/2854/all-actions?overview=closed#tabs',
#  'https://www.ers.usda.gov/webdocs/publications/42096/32943_aosupp_002.pdf?v=42487',
#  'https://www.ers.usda.gov/webdocs/publications/42073/32953_aib726a_002.pdf?v=42487',
#  'https://www.everycrsreport.com/files/19970106_97-69_17c7d990259c0f54b2349b9c6ac1dcc4deeef3ee.pdf',
#  'http://www.adobe.com/products/reader.html',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-6.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-7.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-8.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-9.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-10.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-11.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/#omni-90',
#  'https://catalog.loc.gov/vwebv/search?searchArg=1990+farm+bill+legislative+history&searchCode=GKEY%5E*&searchType=0&recCount=25&sk=en_US',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-6.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-7.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-8.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-9.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-10.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-11.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-12.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-13.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-14.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-4.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/#1985',
#  'https://www.congress.gov/bill/99th-congress/house-bill/2100/all-actions?overview=closed#tabs',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-6.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981-2.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/#1981',
#  'https://www.congress.gov/bill/97th-congress/senate-bill/884/all-actions?overview=closed#tabs',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981conf-senate290-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981conf-senate290-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981conf-senate290-3.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977-2.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://www.congress.gov/bill/95th-congress/senate-bill/275/all-actions?q=%7B%22search%22%3A%5B%22Pub.+L.+No.+95-113%2C+91+Stat.+913%22%2C%22Pub.%22%2C%22L.%22%2C%22No.%22%2C%2295-113%2C%22%2C%2291%22%2C%22Stat.%22%2C%22913%22%5D%7D&r=1&overview=closed&s=7#tabs',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-6.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-6.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1973.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/#1973',
#  'https://www.congress.gov/bill/93rd-congress/senate-bill/1888/all-actions?q=%7B%22search%22%3A%5B%22Pub.+L.+No.+93-86%2C+87+Stat.+221%22%2C%22Pub.%22%2C%22L.%22%2C%22No.%22%2C%2293-86%2C%22%2C%2287%22%2C%22Stat.%22%2C%22221%22%5D%7D&r=8&overview=closed&s=9#tabs',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1973conf-house427.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1970.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1970conf-house1594.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1965.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1965conf-house1123.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1956.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1956conf-house2197.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1956-senate1966.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1956-senate1484.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1954.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1954conf-house2664.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1954-senate1810.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1949.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1949conf-house1459.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1948.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1948conf-house2448.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1948-house1776.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1938.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1938conf-house1767.pdf',
#  None,
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1933.pdf',
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1933conf-house100.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1933-senate40.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1933-senate40.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1933-senate16.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1933-house6.pdf',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/wool1993.pdf',
#  'https://www.congress.gov/bill/103rd-congress/senate-bill/1548/all-actions?q=%7B%22search%22%3A%5B%22Pub.+L.+103-130%2C+107+Stat.+1368+%281993%29%22%2C%22Pub.%22%2C%22L.%22%2C%22103-130%2C%22%2C%22107%22%2C%22Stat.%22%2C%221368%22%2C%22%281993%29%22%5D%7D&r=1&overview=closed&s=2#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/omnibus1993.pdf',
#  'https://www.congress.gov/bill/103rd-congress/house-bill/2264/all-actions?q=%7B%22search%22%3A%5B%22Omnibus+Budget+Reconciliation+Act+of+1993%22%2C%22Omnibus%22%2C%22Budget%22%2C%22Reconciliation%22%2C%22Act%22%2C%22of%22%2C%221993%22%5D%7D&r=7&overview=closed&s=7#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/omnibus1990.pdf',
#  'https://www.congress.gov/bill/101st-congress/house-bill/5835/all-actions?overview=closed#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/omnibus1989.pdf',
#  'https://www.congress.gov/bill/101st-congress/house-bill/3299/all-actions?q=%7B%22search%22%3A%5B%22Omnibus+Budget+Reconciliation+Act+of+1989%22%2C%22Omnibus%22%2C%22Budget%22%2C%22Reconciliation%22%2C%22Act%22%2C%22of%22%2C%221989%22%5D%7D&r=2&overview=closed&s=3#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/omnibus1987.pdf',
#  'https://www.congress.gov/bill/100th-congress/house-bill/3545/all-actions?q=%7B%22search%22%3A%5B%22Omnibus+Budget+Reconciliation+Act+of+1987%22%2C%22Omnibus%22%2C%22Budget%22%2C%22Reconciliation%22%2C%22Act%22%2C%22of%22%2C%221987%22%5D%7D&r=2&overview=closed&s=5#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/foodsecurity1986.pdf',
#  'https://www.congress.gov/bill/99th-congress/house-bill/1614/all-actions?q=%7B%22search%22%3A%5B%22Food+Security+Improvements+Act+of+1986%22%2C%22Food%22%2C%22Security%22%2C%22Improvements%22%2C%22Act%22%2C%22of%22%2C%221986%22%5D%7D&r=1&overview=closed&s=7#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/technicalcorrections1985.pdf',
#  'https://www.congress.gov/bill/99th-congress/senate-bill/2036/all-actions?q=%7B%22search%22%3A%5B%22Technical+Corrections+to++Food+Security+Act+of+1985+Amendments%22%2C%22Technical%22%2C%22Corrections%22%2C%22to%22%2C%22Food%22%2C%22Security%22%2C%22Act%22%2C%22of%22%2C%221985%22%2C%22Amendments%22%5D%7D&r=1&overview=closed&s=9#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/agprograms1984.pdf',
#  'https://www.congress.gov/bill/98th-congress/house-bill/4072/all-actions?q=%7B%22search%22%3A%5B%22Agricultural+Programs+Adjustment+Act+of++1984%22%2C%22Agricultural%22%2C%22Programs%22%2C%22Adjustment%22%2C%22Act%22%2C%22of%22%2C%221984%22%5D%7D&r=1&overview=closed&s=1#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/dairy1983.pdf',
#  'https://www.congress.gov/bill/98th-congress/house-bill/3385/all-actions?q=%7B%22search%22%3A%5B%22Dairy+and+Tobacco+Adjustment+Act+of+1983%22%2C%22Dairy%22%2C%22and%22%2C%22Tobacco%22%2C%22Adjustment%22%2C%22Act%22%2C%22of%22%2C%221983%22%5D%7D&r=1&overview=closed&s=3#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/cotton1983.pdf',
#  'https://www.congress.gov/bill/98th-congress/house-bill/3190/all-actions?q=%7B%22search%22%3A%5B%22Extra-Long+Staple+Cotton+Act+of+1983%22%2C%22Extra-Long%22%2C%22Staple%22%2C%22Cotton%22%2C%22Act%22%2C%22of%22%2C%221983%22%5D%7D&r=1&overview=closed&s=5#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/omnibus1982.pdf',
#  'https://www.congress.gov/bill/97th-congress/house-bill/6955/all-actions?q=%7B%22search%22%3A%5B%22Omnibus+Budget+Reconciliation+Act+of+1982%22%2C%22Omnibus%22%2C%22Budget%22%2C%22Reconciliation%22%2C%22Act%22%2C%22of%22%2C%221982%22%5D%7D&r=10&overview=closed&s=7#tabs',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/agact1964.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/agact1964.pdf',
#  'https://www.congress.gov/bill/88th-congress/house-bill/6196/actions?q=%7B%22search%22%3A%5B%22Pub.+L.+No.+88-297%2C+78+Stat.+173+%281964%29%22%2C%22Pub.%22%2C%22L.%22%2C%22No.%22%2C%2288-297%2C%22%2C%2278%22%2C%22Stat.%22%2C%22173%22%2C%22%281964%29%22%5D%7D&r=2&s=3',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/#1962',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/foodag1962.pdf',
#  'https://www.congress.gov/bill/87th-congress/house-bill/12391/actions?q=%7B%22search%22%3A%5B%22Pub.+L.+No.+87-703%2C+76+Stat.+605+%281962%29%22%2C%22Pub.%22%2C%22L.%22%2C%22No.%22%2C%2287-703%2C%22%2C%2276%22%2C%22Stat.%22%2C%22605%22%2C%22%281962%29%22%5D%7D&r=3&s=5',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/foodag1962conf-house2385.pdf',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/#1948',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/ccc1948.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/ccc1948conf-house2444.pdf',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/#steagall',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/steagall1941.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/steagall1941conf-house892.pdf',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/#soil-36',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/soilconserv1936.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/soilconserv1936conf-house2079.pdf',
#  None,
#  'https://nationalaglawcenter.org/farmbills/glossary/',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/soilconserv1935.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/soilconserv1935-senate466.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/soilconserv1935-house528.pdf',
#  'https://nationalaglawcenter.org/about-the-center/',
#  'https://nationalaglawcenter.org/about-the-center/professional-staff/',
#  'https://nationalaglawcenter.org/partners/',
#  'https://nationalaglawcenter.org/research-by-topic/',
#  'https://nationalaglawcenter.org/center-publications/',
#  'https://nationalaglawcenter.org/?page_id=26270',
#  'https://nationalaglawcenter.org/state-compilations/',
#  'https://nationalaglawcenter.org/farmbills/',
#  'https://nationalaglawcenter.org/ag-law-bibliography/',
#  'https://nationalaglawcenter.org/ag-law-glossary/',
#  'https://nationalaglawcenter.org/aglaw-reporter/',
#  'https://nationalaglawcenter.org/general-resources/',
#  'https://www.facebook.com/nataglaw/',
#  'https://twitter.com/nataglaw',
#  'https://www.nationalaglawcenter.org/about/',
#  'https://goodwork.io/',
#  'https://nationalaglawcenter.org/farmbills/#top',
#  '',
#  '',
#  None,
#  None]

# %%
# scrape URL for online bill texts for Farm bills 1996 to 2018
bills = driver.find_elements(By.XPATH, '//*[contains(text(), "Text")]')

list1 = []
for bill in bills[11:16]:
    bill = bill.get_attribute('href')
    list1.append(bill)
    
list1
# Out:
# ['https://www.congress.gov/bill/115th-congress/house-bill/2/text?format=txt&q=%7B%22search%22%3A%5B%22hr2%22%5D%7D&r=1',
#  'https://www.govinfo.gov/content/pkg/PLAW-113publ79/html/PLAW-113publ79.htm',
#  'https://www.congress.gov/bill/110th-congress/house-bill/6124/text',
#  'https://www.congress.gov/bill/107th-congress/house-bill/2646/text',
#  'https://www.govtrack.us/congress/bills/104/hr2854/text']

# %% [markdown]
# ### Scraping links to PDFs
#
# Each bill has been uploaded as a PDF, though some of the earlier bills were uploaded in parts, while the most recent bills are also publicly archived online through the Congress.gov website.
#
# For consistency, all bills will be collected as PDFs before being analyzed.

# %%
# scrape PDFs for Farm bills 1996 to 2018
PDFS = driver.find_elements(By.XPATH, '//*[text()="PDF"]')

list1 = []
for PDF in PDFS:
    PDF = PDF.get_attribute('href')
    list1.append(PDF)
    
list1
# Out:
# ['https://www.congress.gov/115/bills/hr2/BILLS-115hr2enr.pdf',
#  'https://www.govinfo.gov/content/pkg/BILLS-113hr2642enr/pdf/BILLS-113hr2642enr.pdf',
#  'https://www.congress.gov/110/plaws/publ246/PLAW-110publ246.pdf',
#  'http://frwebgate.access.gpo.gov/cgi-bin/getdoc.cgi?dbname=107_cong_public_laws&docid=f:publ171.107.pdf',
#  'https://www.congress.gov/104/plaws/publ127/PLAW-104publ127.pdf']

# %%
# scrape PDFs for Farm bills 1977 to 1990
PDFS = driver.find_elements(By.XPATH, '//*[contains(text(), "Part ")]')

list1 = []
for PDF in PDFS:
    PDF = PDF.get_attribute('href')
    list1.append(PDF)
    
list1
# Out:
# ['https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-6.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-7.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-8.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-9.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-10.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990-11.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-6.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-7.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-8.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-9.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-10.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-11.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-12.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-13.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1990conf-house916-14.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1985conf-house447-6.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981conf-senate290-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981conf-senate290-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1981conf-senate290-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-1.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-2.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-3.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-4.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-5.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1977conf-senate418-6.pdf']

# %%
# scrape PDFs for Farm bills before 1977: only first 9
PDFS = driver.find_elements(By.XPATH, '//*[text()="Full Text"]')

list1 = []
for PDF in PDFS[:9]:
    PDF = PDF.get_attribute('href')
    list1.append(PDF)
    
list1
# Out:
# ['https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1973.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1970.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1965.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1956.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1954.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1949.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1948.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1938.pdf',
#  'https://nationalaglawcenter.org/wp-content/uploads/assets/farmbills/1933.pdf']

# %% [markdown]
# ### Prepping plans from 1977 to 1990
#
# Each of the 4 bills from this period were scanned, separated, and uploaded as multiple documents. Each bill will need to have its parts remerged into single PDFs before they can be analyzed.
#
# However, the "title" pages for each of these parts documents will need to be removed before they are merged to avoid artificially inflating the presence of specific keywords in each of the bills (e.g. "agricultural").

# %%
# 1977

# initializing merge
merger = PdfFileMerger()

# merging
for pdf in [r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1977-1.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1977-2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save to folder
merger.write("1977.pdf")
merger.close()
#path = 'C://Users//melod//Documents//data science//Food-Systems-Policy-Research//Food and Ag CA Legislation//Data'
#saved = os.path.join(path, "1977.pdf") 
#PDF = open(saved, "w")
#toFile = input("1977")
#PDF.write(toFile)
#PDF.close()

# %%
# 1981

# initializing merge
merger = PdfFileMerger()

# merging
for pdf in [r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1981-1.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1981-2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("1981.pdf")
merger.close()

# %%
# 1985

# initializing merge
merger = PdfFileMerger()

# merging
for pdf in [r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1985-1.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1985-2.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("1985.pdf")
merger.close()

# %%
# 1990

# initializing merge
merger = PdfFileMerger()

# merging
for pdf in [r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-1.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-2.pdf",
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-3.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-4.pdf",
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-5.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-6.pdf",
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-7.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-8.pdf",
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-9.pdf", 
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-10.pdf",
           r"C:\Users\melod\Documents\data science\data\Farm Bills\Parts\1990-11.pdf"]:
    merger.append(pdf, import_bookmarks=False) # kept getting an error otherwise

# save
merger.write("1990.pdf")
merger.close()

# %% [markdown]
# ### Pre-processing Bill Texts

# %%
# installing wordninja
#!pip install wordninja

# %%
# libraries
from textblob import TextBlob # spellcorrecting
# python -m textblob.download_corpora
import wordninja # separating misjoined words

# %%
# loading bill PDFs from data folder in directory
bills = os.listdir(r"C:\Users\melod\Documents\data science\data\Farm Bills")

# inspect
print(type(bills))
print(len(bills))
print(bills)
# Out:
# <class 'list'>
# 19
# ['1933.pdf', '1938.pdf', '1948.pdf', '1949.pdf', '1954.pdf', '1956.pdf', '1965.pdf', '1970.pdf', '1973.pdf', '1977.pdf', '1981.pdf', '1985.pdf', '1990.pdf', '1996.pdf', '2002.pdf', '2008.pdf', '2014.pdf', '2018.pdf', 'Parts']

# %%
# extracting text from bill PDFs
def readPDF(bills):
    txt = extract_text("C:/Users/melod/Documents/data science/data/Farm Bills/"+bills)
    
    # strip quotation marks
    text = re.sub(r'"', '', string)
    # remove punctuation, numbers, etc.
    txt = re.sub(r'[^A-z\s]', '', txt)
    # remove any extra whitepace
    txt = re.sub(r'\s+', ' ', txt) 
    
    # Add year identifier to the beginning of each bill
    
    # clean up bill name
    bill = bills.split(".")[0]
    
    # insert year ID to start of bill string: indexable bill ID w/i each bill txt string
    txt = bill+', '+txt
    
    # confirm
    print('Finished {}'.format(bill))
    return txt

# read in all pdf files
suffixes = ('.pdf', '.PDF')
farmbills = [readPDF(bill) for bill in bills if bill.endswith(suffixes)]
# Out:
# Finished 1933
# Finished 1938
# Finished 1948
# Finished 1949
# Finished 1954
# Finished 1956
# Finished 1965
# Finished 1970
# Finished 1973
# Finished 1977
# Finished 1981
# Finished 1985
# Finished 1990
# Finished 1996
# Finished 2002
# Finished 2008
# Finished 2014
# Finished 2018

# %%
# inspect
print(type(farmbills))
print(len(farmbills))
# Out:
# <class 'list'>
# 18

# %%
# save list of bills to hardrive so that it called be reloaded/called directly instead of
#  having to rerun time and resource intensive scraping function
#import pickle

#with open('farmbills.pickle', 'wb') as f:
 #   pickle.dump(farmbills, f)

# %%
# list of words to exclude
swords = stopwords.words('english')

# %% [markdown]
# ### TEST CODE AREA

# %%
#TEST
string = '(7) PARTICIPATION AGREEMENTS.-"(A) IN GENERAL.-Producers on a farm desiring toparticipate in the program conducted under this subsectionshall execute an agreement with the Secretary providingfor the participation not later than such date as the Sec-retary may prescribe."(B) MODIFICATION OR TERMINATION.-The Secretary may,by mutual agreement with producers on a farm, modify orterminate any such agreement if the Secretary determinesthe action necessary because of an emergency created bydrought or other disaster or to prevent or alleviate a short-age in the supply of agricultural commodities. The Sec-retary may modify the agreement under this subparagraphfor the purpose of alleviating a shortage in the supply ofagricultural commodities only if there has been a signifi-cant change in the estimated stocks of the commodity sincethe Secretary announced the final terms and conditions ofthe program for the crop of rice.'

# %%
# separating misjoined words
for word in string:
    print(''.join(wordninja.split(word)))
# Out:
# 7
#
#
# P
# A
# R
# T
# I
# C
# I
# P
# A
# T
# I
# O
# N
#
# A
# G
# R
# E
# E
# M
# E
# N
# T
# S
#
#
#
#
# A
#
#
# I
# N
#
# G
# E
# N
# E
# R
# A
# L
#
#
# P
# r
# o
# d
# u
# c
# e
# r
# s
#
# o
# n
#
# a
#
# f
# a
# r
# m
#
# d
# e
# s
# i
# r
# i
# n
# g
#
# t
# o
# p
# a
# r
# t
# i
# c
# i
# p
# a
# t
# e
#
# i
# n
#
# t
# h
# e
#
# p
# r
# o
# g
# r
# a
# m
#
# c
# o
# n
# d
# u
# c
# t
# e
# d
#
# u
# n
# d
# e
# r
#
# t
# h
# i
# s
#
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# s
# h
# a
# l
# l
#
# e
# x
# e
# c
# u
# t
# e
#
# a
# n
#
# a
# g
# r
# e
# e
# m
# e
# n
# t
#
# w
# i
# t
# h
#
# t
# h
# e
#
# S
# e
# c
# r
# e
# t
# a
# r
# y
#
# p
# r
# o
# v
# i
# d
# i
# n
# g
# f
# o
# r
#
# t
# h
# e
#
# p
# a
# r
# t
# i
# c
# i
# p
# a
# t
# i
# o
# n
#
# n
# o
# t
#
# l
# a
# t
# e
# r
#
# t
# h
# a
# n
#
# s
# u
# c
# h
#
# d
# a
# t
# e
#
# a
# s
#
# t
# h
# e
#
# S
# e
# c
#
# r
# e
# t
# a
# r
# y
#
# m
# a
# y
#
# p
# r
# e
# s
# c
# r
# i
# b
# e
#
#
#
# B
#
#
# M
# O
# D
# I
# F
# I
# C
# A
# T
# I
# O
# N
#
# O
# R
#
# T
# E
# R
# M
# I
# N
# A
# T
# I
# O
# N
#
#
# T
# h
# e
#
# S
# e
# c
# r
# e
# t
# a
# r
# y
#
# m
# a
# y
#
# b
# y
#
# m
# u
# t
# u
# a
# l
#
# a
# g
# r
# e
# e
# m
# e
# n
# t
#
# w
# i
# t
# h
#
# p
# r
# o
# d
# u
# c
# e
# r
# s
#
# o
# n
#
# a
#
# f
# a
# r
# m
#
#
# m
# o
# d
# i
# f
# y
#
# o
# r
# t
# e
# r
# m
# i
# n
# a
# t
# e
#
# a
# n
# y
#
# s
# u
# c
# h
#
# a
# g
# r
# e
# e
# m
# e
# n
# t
#
# i
# f
#
# t
# h
# e
#
# S
# e
# c
# r
# e
# t
# a
# r
# y
#
# d
# e
# t
# e
# r
# m
# i
# n
# e
# s
# t
# h
# e
#
# a
# c
# t
# i
# o
# n
#
# n
# e
# c
# e
# s
# s
# a
# r
# y
#
# b
# e
# c
# a
# u
# s
# e
#
# o
# f
#
# a
# n
#
# e
# m
# e
# r
# g
# e
# n
# c
# y
#
# c
# r
# e
# a
# t
# e
# d
#
# b
# y
# d
# r
# o
# u
# g
# h
# t
#
# o
# r
#
# o
# t
# h
# e
# r
#
# d
# i
# s
# a
# s
# t
# e
# r
#
# o
# r
#
# t
# o
#
# p
# r
# e
# v
# e
# n
# t
#
# o
# r
#
# a
# l
# l
# e
# v
# i
# a
# t
# e
#
# a
#
# s
# h
# o
# r
# t
#
# a
# g
# e
#
# i
# n
#
# t
# h
# e
#
# s
# u
# p
# p
# l
# y
#
# o
# f
#
# a
# g
# r
# i
# c
# u
# l
# t
# u
# r
# a
# l
#
# c
# o
# m
# m
# o
# d
# i
# t
# i
# e
# s
#
#
# T
# h
# e
#
# S
# e
# c
#
# r
# e
# t
# a
# r
# y
#
# m
# a
# y
#
# m
# o
# d
# i
# f
# y
#
# t
# h
# e
#
# a
# g
# r
# e
# e
# m
# e
# n
# t
#
# u
# n
# d
# e
# r
#
# t
# h
# i
# s
#
# s
# u
# b
# p
# a
# r
# a
# g
# r
# a
# p
# h
# f
# o
# r
#
# t
# h
# e
#
# p
# u
# r
# p
# o
# s
# e
#
# o
# f
#
# a
# l
# l
# e
# v
# i
# a
# t
# i
# n
# g
#
# a
#
# s
# h
# o
# r
# t
# a
# g
# e
#
# i
# n
#
# t
# h
# e
#
# s
# u
# p
# p
# l
# y
#
# o
# f
# a
# g
# r
# i
# c
# u
# l
# t
# u
# r
# a
# l
#
# c
# o
# m
# m
# o
# d
# i
# t
# i
# e
# s
#
# o
# n
# l
# y
#
# i
# f
#
# t
# h
# e
# r
# e
#
# h
# a
# s
#
# b
# e
# e
# n
#
# a
#
# s
# i
# g
# n
# i
# f
# i
#
# c
# a
# n
# t
#
# c
# h
# a
# n
# g
# e
#
# i
# n
#
# t
# h
# e
#
# e
# s
# t
# i
# m
# a
# t
# e
# d
#
# s
# t
# o
# c
# k
# s
#
# o
# f
#
# t
# h
# e
#
# c
# o
# m
# m
# o
# d
# i
# t
# y
#
# s
# i
# n
# c
# e
# t
# h
# e
#
# S
# e
# c
# r
# e
# t
# a
# r
# y
#
# a
# n
# n
# o
# u
# n
# c
# e
# d
#
# t
# h
# e
#
# f
# i
# n
# a
# l
#
# t
# e
# r
# m
# s
#
# a
# n
# d
#
# c
# o
# n
# d
# i
# t
# i
# o
# n
# s
#
# o
# f
# t
# h
# e
#
# p
# r
# o
# g
# r
# a
# m
#
# f
# o
# r
#
# t
# h
# e
#
# c
# r
# o
# p
#
# o
# f
#
# r
# i
# c
# e

# %%
# POS tagging
tb_string.tags

# %%
# TEST

# strip quotation marks
text = re.sub(r'(")+', '', string)

# remove parentheses and characters w/i where <2 characters w/i parentheses
text = re.sub(r'(\([A-z0-9]{,2}\))+', '', text)

# remove hyphens only when followed by a newline or preceded by a period
text = re.sub(r'\-(\n|\s)+', '', text)
text = re.sub(r'\.\-+', r' ', text)
text = re.sub(r'(?<=[A-z])\-(?=[A-z])+', '', text)

# add space after commas preceded by a complete word
text = re.sub(r'(,)(?=[A-z])+', r'\1 ', text)

# correct spelling errors (created when removing hyphens or spaces)
tb_string = TextBlob(text)
tb_string.correct()

# separating misjoined words
#for word in string:
 #   ' '.join(wordninja.split(word))

# remove any extra whitepace
text = re.sub(r'\s+', ' ', text) 

# separate into sentences: replace periods w/ commas when not preceded/followed by digits
#text = re.sub(r'(?<![/d{1,20}])(\.)(?![/d{1,20}])', r', ', text) # using regex
text = sent_tokenize(text, language = "english") # using nltk
        
# inspect
text
# Out:
# [' PARTICIPATION AGREEMENTS.IN GENERAL Producers on a farm desiring toparticipate in the program conducted under this subsectionshall execute an agreement with the Secretary providingfor the participation not later than such date as the Secretary may prescribe.',
#  'MODIFICATION OR TERMINATION The Secretary may, by mutual agreement with producers on a farm, modify orterminate any such agreement if the Secretary determinesthe action necessary because of an emergency created bydrought or other disaster or to prevent or alleviate a shortage in the supply of agricultural commodities.',
#  'The Secretary may modify the agreement under this subparagraphfor the purpose of alleviating a shortage in the supply ofagricultural commodities only if there has been a significant change in the estimated stocks of the commodity sincethe Secretary announced the final terms and conditions ofthe program for the crop of rice.']

# %%
# testing search
comp = re.compile(r'(,)[A-z]+')
find = re.search(comp, string)
find
# Out:
# <re.Match object; span=(321, 324), match=',by'>

# %% [markdown]
# ### NLP Analysis: Identifying Interests, Policy Goals, and Mechanisms
#
# 1. Basic keyword search
# 2. Keyword proximities: Do specific keywords appear near to each other in the bill language? (e.g. soil and food)
#        (create word list per bill document; each document is a list of words)
# 3. Text classification using word vector representation: Search bill text for terms under the following categories -- "INTERESTS", "OBJECTIVES", and "INCENTIVES" to identify what stakeholder interests are being addressed in each bill, the policy goals that are being prioritized or ignored, and the kinds of monetary and punitive tools used to facilitate both stated and inferred policy outcomes. Comparison of (1,2) and (3) to ascertain the extent to which community-scale food production and land and environmental health as a prerequisite for healthy food systems is either aligned with or contrary to the stated and inferred policy goals in farm bills, and how if at all this changes over time.
#     (create sentence list per bill document; each document is a list of sentences)
# 4. Text summarization: Summarizing the bill contents
#
# Using pretrained sentence BERT (SBERT)

# %% [markdown]
# ### Keywords: How Are Farm Bills Talking About Food and Environment?

# %%
# descriptive statistics: document word count
count =

# %%
# list of keywords of interest
keywords = ['food', 'agriculture', 'producer', 'soil', 'conservation', 'regenerative']

# %%
# keyword counts

# turning cleaned bill text into list of words
wordlist = [word for word in word_tokenize(textonly.lower()) 
                 if word not in swords]

# %% [markdown]
# ### Identifying Stakeholders, Policy Goals, and Tools/Incentives: (A) Stakeholders

# %%
# libraries
from sklearn.feature_extraction.text import CountVectorizer

# %%
# creating classifer categories of stakeholder interests represented
class Category:
    GOVERNMENT = "Government"
    BUSINESS = "Business"
    CIVIC = "Civic"
train_xstakeholder = billsentence # sample of cleaned sentences from sentence list
train_ystakeholder = [Category.GOVERNMENT, Category.GOVERNMENT, 
                      Category.BUSINESS, Category.BUSINESS, Category.CIVIC,
                     Category.CIVIC]

# %%
# initializing
vectorizer = CountVectorizer(binary = True) # binary: unique counts 
vectorizer = CountVectorizer(binary = True, ngram_range = (1,2)) # ngram spec
#vectorizer = CountVectorizer() # absolute counts of words (captures multiple instances)

# fit dictionary of unique words pulled from corpus
train_xvectors = vectorizer.fit_transform(train_xstakeholder)

# inspect sample
print(vectorizer.get_feature_names())
print(train_xvectors.toarray())

# %%
# load pre-trained spacy model (size = medium)
nlp = spacy.load('en_core_web_md')

# %%
# vectorize each word in the bill documents used to train model
docs = [nlp(text) for text in train_xstakeholders]

# inspect sample
#print(docs[0].vector)

# creating train x for vectorized corpus
train_xstakeholder_v = [word.vector for word in docs]

# %%
# fitting
clf_svm_wv = svm.SVC(kernel = 'linear') # linear is a good classification model for text?
clf_svm_wv_fit(train_xstakeholder_v, train_ystakeholder)

# %%
# predicting: testing model 
# insert into loop for each sentence in sentence list for each bill corpus
test_txt = [] # insert leftover bills corpus (minus text from train_xstakeholder)
test_corp = [nlp(text) for text in test_txt]
text_txt_wv = [x.vector for x in test_corp]

clf_svm_wv_predict(text_txt_wv)

# %% [markdown]
# Using open-source BERT model: when not training model from scratch

# %%
nlp = spacy.load('en_trf-bertbaseuncased_lg')
doc = nlp('Here is some text to encode.')

# %%
# rerun vector model code
