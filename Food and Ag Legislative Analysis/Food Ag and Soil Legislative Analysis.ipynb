# %% [markdown]
# # Food, Agriculture, and Soils: California Legislation
#
# This notebook explores state level legislation from the Legiscan API. It conducts text analysis of all available California Legislation that mentions food and agriculture from years 20XX to 2023, with special attention to mentions of land, soil, and environmental management.
#
# LegiScan API documentation [here](https://legiscan.com/gaits/documentation/legiscan) and [here](https://api.legiscan.com/dl/).

# %%
# libraries
import pandas as pd
import geopandas as gpd
import numpy as np

import requests
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup

import re
import os
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer
import json

# set display
pd.options.display.max_columns = 150
pd.options.display.max_rows = 300

# %% [markdown]
# First, I will pull the bill ID, year/session, and full texts for all CA legisation that passed mentioning "food" and "agriculture".
#
# Then I will narrow my search to all bills mentioning "food", "agriculture", "environment", and "soil".
#
# I will store relevant information into a dictionary that can be transformed into a pandas dataframe.
#
# Pull API template: "https://api.legiscan.com/?key=APIKEY&op=OPERATION&PARAMS"
# APIKey = '7e00040f1f7618af234e7415484d2494'
#
# **OPERATIONS**
# getBill, getBillText, getSearch, getSearchRaw
#
# **PARAMETERS**
# state, year, query (URL encoded), page
#
# **IDENTIFIERS**
# bill_id, doc_id

# %%
# request: CA, food and ag, results for current year
requeststring = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=2&query=food%20and%20agriculture"

# %%
# request: CA, food and ag, results for recent years
requeststring1 = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=3&query=food%20and%20agriculture"

# %%
# request: CA, food and ag, results for all available years
requeststring2 = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=1&query=food%20and%20agriculture"

# %%
# pull request: getting results as JSON object
r = requests.get(requeststring1)

# %%
# examining results
#print(r.text)

# %%
# turning JSON object into a dict
dict1 = json.loads(r.text)

# %%
# examining structure of dictionary and identifying relevant keys
print(dict1.keys())
print(dict1['searchresult'].keys())
print(dict1['searchresult']['summary'].keys())
print(dict1['searchresult']['results'])
# Out:
# dict_keys(['status', 'searchresult'])
# dict_keys(['summary', 'results'])
# dict_keys(['page', 'range', 'relevancy', 'count', 'page_current', 'page_total', 'query'])
# [{'relevance': 100, 'bill_id': 1453447, 'change_hash': 'c4cbd2bf405a5c9f9d8db0604c01ee91'}, {'relevance': 99, 'bill_id': 1693920, 'change_hash': '2cc2c16e46855bab164790df5a2dc955'}, {'relevance': 99, 'bill_id': 1456707, 'change_hash': '0f15fc913ea7989404f0e73f48c7b1de'}, {'relevance': 99, 'bill_id': 1388510, 'change_hash': '75ed87f9287e2be9b2670e33d0fb03c5'}, {'relevance': 99, 'bill_id': 1711942, 'change_hash': 'cd9d825f6d643ff19d5d789db7760174'}, {'relevance': 99, 'bill_id': 1454994, 'change_hash': '41e3c3667fa12d949ffa64b377696f0e'}, {'relevance': 99, 'bill_id': 1594832, 'change_hash': '9fce132981f80e04c7d4e45c8b4c4a04'}, {'relevance': 99, 'bill_id': 1614129, 'change_hash': '47b91c807bf15b8e60c9a568bbf154b3'}, {'relevance': 99, 'bill_id': 1592497, 'change_hash': '53adde10972d4112d157cbd0edb0f15f'}, {'relevance': 99, 'bill_id': 1453388, 'change_hash': 'a44403752c7fefacc4b03702e9d8926e'}, {'relevance': 99, 'bill_id': 1593665, 'change_hash': '6c5752cf4ea9407fc3a183afd07b1071'}, {'relevance': 99, 'bill_id': 1702780, 'change_hash': '266b25df310d9ebd3e42bb97fdec3adf'}, {'relevance': 99, 'bill_id': 1458834, 'change_hash': '0de529de94a7da01422a45210355d0d5'}, {'relevance': 99, 'bill_id': 1433188, 'change_hash': '5990051e9159b808f2a8652d9512266f'}, {'relevance': 99, 'bill_id': 1451034, 'change_hash': '57e66b2cbaa8fce69e916de5368f1f97'}, {'relevance': 99, 'bill_id': 1578060, 'change_hash': '185a7cb5bd1fe4a119fa37ac4d5ae2e3'}, {'relevance': 99, 'bill_id': 1438442, 'change_hash': '40dc84015d58fd1d1b97538b31a4a518'}, {'relevance': 99, 'bill_id': 1588122, 'change_hash': '6c130e730b20b38140215b9c1a6758d1'}, {'relevance': 99, 'bill_id': 1417874, 'change_hash': '1d99613fd81c036a9ea41d10329e5396'}, {'relevance': 99, 'bill_id': 1398281, 'change_hash': 'f7b7d80200dbe1910cb9b9512b21715c'}, {'relevance': 99, 'bill_id': 1712167, 'change_hash': '37ed87e95a3bc0627706e74408a2a63a'}, {'relevance': 99, 'bill_id': 1581321, 'change_hash': '58175dd3ba4ecbf857521ab80ab6ff9f'}, {'relevance': 99, 'bill_id': 1707639, 'change_hash': '6bddb0f6f615ed90a9bafc8ec369b181'}, {'relevance': 99, 'bill_id': 1592396, 'change_hash': '590060c7e1959a4d454c296b56e9c187'}, {'relevance': 99, 'bill_id': 1456801, 'change_hash': '013cb11ef858535051bdb2c147f7dd53'}, {'relevance': 99, 'bill_id': 1593664, 'change_hash': 'f6fb716c9dfed18420966a1310ef35a7'}, {'relevance': 99, 'bill_id': 1453516, 'change_hash': '63e85528f837770c8e3e7bdf213a0ec0'}, {'relevance': 99, 'bill_id': 1671132, 'change_hash': '3f4199a2ffe1d27113d5607be727e6db'}, {'relevance': 99, 'bill_id': 1454889, 'change_hash': 'c61cbca98f626b6483a05c1dc3e14d9c'}, {'relevance': 99, 'bill_id': 1592492, 'change_hash': '1e6870128b914f8155b222b3b10cd21d'}, {'relevance': 99, 'bill_id': 1453379, 'change_hash': '2c7c9b674125398a711d8cf507646b2e'}, {'relevance': 99, 'bill_id': 1459192, 'change_hash': '5cff7bdaae27e6672c78d876d9303cfd'}, {'relevance': 99, 'bill_id': 1712103, 'change_hash': 'ce1242ff43bcfe48ae2d9a3325bd5959'}, {'relevance': 99, 'bill_id': 1447168, 'change_hash': '76c0d43ef021df2d8ae04c721736a2d4'}, {'relevance': 99, 'bill_id': 1441536, 'change_hash': '19540487684ce15c93624ee0bc217db0'}, {'relevance': 99, 'bill_id': 1429103, 'change_hash': '6f0e425e74de3d7e13daddbd3752d334'}, {'relevance': 99, 'bill_id': 1458841, 'change_hash': '91789ada427e6dea20020479b4e523fc'}, {'relevance': 99, 'bill_id': 1588179, 'change_hash': 'c717757ee5e798f9084b6224e71e298f'}, {'relevance': 99, 'bill_id': 1456723, 'change_hash': '643e8d6573df77bf7a5128f535d9c059'}, {'relevance': 99, 'bill_id': 1471518, 'change_hash': 'ea0c9554cb70a1b768f14bf2d5b93ade'}, {'relevance': 99, 'bill_id': 1385467, 'change_hash': 'c3bf9de9f93eec67c29c594510e6abf6'}, {'relevance': 99, 'bill_id': 1592403, 'change_hash': 'c7f2ea816067a81cae377c0ccd9bb028'}, {'relevance': 99, 'bill_id': 1701021, 'change_hash': '39ac916c6a0c97e9fe5dda5ca2568434'}, {'relevance': 99, 'bill_id': 1398228, 'change_hash': '5571aac711fc853a361fcacdab6ac201'}, {'relevance': 99, 'bill_id': 1594480,  ...

# %%
# creating subset dict with only keys of interest
list1 = dict1['searchresult']['results']
list1[:5]
# Out:
# [{'relevance': 100,
#   'bill_id': 1453447,
#   'change_hash': 'c4cbd2bf405a5c9f9d8db0604c01ee91'},
#  {'relevance': 99,
#   'bill_id': 1693920,
#   'change_hash': '2cc2c16e46855bab164790df5a2dc955'},
#  {'relevance': 99,
#   'bill_id': 1456707,
#   'change_hash': '0f15fc913ea7989404f0e73f48c7b1de'},
#  {'relevance': 99,
#   'bill_id': 1388510,
#   'change_hash': '75ed87f9287e2be9b2670e33d0fb03c5'},
#  {'relevance': 99,
#   'bill_id': 1711942,
#   'change_hash': 'cd9d825f6d643ff19d5d789db7760174'}]

# %%
# generating list of bill_ids
# https://www.geeksforgeeks.org/python-get-values-of-particular-key-in-list-of-dictionaries/
bills = [value['bill_id'] for value in list1]
bills[:5]
# Out:
# [1453447, 1693920, 1456707, 1388510, 1711942]

# %%
# turning list of bill_ids for each relevant result from query into a df
#df = pd.DataFrame(bills, columns = ['bill_id'])
#df.head()

# %%
# sampling bill pull
bill = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id=1456707'
billa = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id=1592779'
b = requests.get(bill)
ba = requests.get(billa)
binfo = json.loads(b.text)
binfoa = json.loads(ba.text)
print(binfo.keys()) 
print(binfoa.keys()) 
#print(binfo)
print(binfoa)
# Out:
# dict_keys(['status', 'bill'])
# dict_keys(['status', 'alert'])
# {'status': 'ERROR', 'alert': {'message': 'Unknown bill id'}}

# %%
# exploring structure and extracting doc_ids from bill: BILL
print(binfo.keys())
print(binfo['bill'].keys())
print(binfo['bill']['texts'])
# Out:
# dict_keys(['status', 'bill'])
# dict_keys(['bill_id', 'change_hash', 'session_id', 'session', 'url', 'state_link', 'completed', 'status', 'status_date', 'progress', 'state', 'state_id', 'bill_number', 'bill_type', 'bill_type_id', 'body', 'body_id', 'current_body', 'current_body_id', 'title', 'description', 'pending_committee_id', 'committee', 'referrals', 'history', 'sponsors', 'sasts', 'subjects', 'texts', 'votes', 'amendments', 'supplements', 'calendar'])
# [{'doc_id': 2704856, 'date': '2023-02-16', 'type': 'Introduced', 'type_id': 1, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2704856', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#99INT', 'text_size': 7488, 'text_hash': 'b048ef4ee2d51bcb0266641e75d77798', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2743399, 'date': '2023-03-13', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2743399', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#98AMD', 'text_size': 16765, 'text_hash': '6c6473e25573a816224c51042f38df4c', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2814717, 'date': '2023-05-18', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2814717', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#97AMD', 'text_size': 15111, 'text_hash': '75d49ee492b6398604544bb921295627', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2826589, 'date': '2023-06-12', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2826589', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#96AMD', 'text_size': 15450, 'text_hash': 'e9f9e9a599422bc4e8dc0913f2f02a8a', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2830807, 'date': '2023-06-26', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2830807', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#95AMD', 'text_size': 16144, 'text_hash': 'ad35b5cac4cbc4fc4fb154c8f1ed301b', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}]

# %%
# exploring structure and extracting doc_ids from bill: ALERT
print(binfoa.keys())
print(binfoa['alert'].keys())
print(binfoa['status'])
print(binfoa['alert']['message'])
# Out:
# dict_keys(['status', 'alert'])
# dict_keys(['message'])
# ERROR
# Unknown bill id

# %%
# isolating list of dictionaries
doclist = binfo['bill']['texts']

# %%
# generating list of bill_ids
docs = [sub['doc_id'] for sub in doclist]
docs
# Out:
# [2299860, 2352258, 2430109, 2431702, 2432952, 2436333]

# %%
# indexing last element (most recently amended version of bill text)
docs[-1]
# Out:
# 2436333

# %%
# sampling bill text pull
btext1 = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBillText&id=2436333'
b = requests.get(btext1)
btext = json.loads(b.text)
print(btext.keys()) 
print(btext)
# Out:
# dict_keys(['status', 'text'])
# {'status': 'OK', 'text': {'doc_id': 2436333, 'bill_id': 1456707, 'date': '2021-10-07', 'type': 'Chaptered', 'type_id': 6, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1009/id/2436333', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202120220AB1009#94CHP', 'text_size': 16842, 'text_hash': '210a902acf5cad5b828a388d0c45a676', 'doc': '...', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': '', 'alt_doc': ''}}

# %%
# exploring structure
print(btext.keys())
print(btext['text'].keys())
print(btext['text']['url'])
print(btext['text']['state_link']) # this URL less likely to turn up errors
# Out:
# dict_keys(['status', 'text'])
# dict_keys(['doc_id', 'bill_id', 'date', 'type', 'type_id', 'mime', 'mime_id', 'url', 'state_link', 'text_size', 'text_hash', 'doc', 'alt_bill_text', 'alt_mime', 'alt_mime_id', 'alt_state_link', 'alt_text_size', 'alt_text_hash', 'alt_doc'])
# https://legiscan.com/CA/text/AB1009/id/2436333
# https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202120220AB1009#94CHP

# %%
# extracting status info from leginfo
statusURL = btext['text']['state_link'].replace('Text', 'Status')
statusURL1 = btext['text']['url'].split("/id")[0].replace('text', 'bill')
print(statusURL)
print(statusURL1)
# Out:
# https://leginfo.legislature.ca.gov/faces/billStatusClient.xhtml?bill_id=202120220AB1009#94CHP
# https://legiscan.com/CA/bill/AB1009

# %%
# extracting bill info and text from bill text url
URL = btext['text']['state_link']
URLa = btext['text']['url']
#r = urlopen(URLa)
#html_bytes = r.read()
#html = html_bytes.decode("utf-8")
#soup = BeautifulSoup(html, features='html.parser')

# extracting status from state bill link
URL1 = statusURL
r1 = urlopen(URL1)
html_bytes1 = r1.read()
html1 = html_bytes1.decode("utf-8")
soup1 = BeautifulSoup(html1, features='html.parser')

# extracting status from LegiScan link
URL2 = statusURL1
#r2 = urlopen(URL2)
#html_bytes2 = r2.read()
#html2 = html_bytes2.decode("utf-8")
#soup2 = BeautifulSoup(html2, features='html.parser')

# %%
# inspecting structure to locate text bloc
print(soup.prettify())
# Out:
# <?xml version='1.0' encoding='UTF-8' ?>
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head id="j_idt5">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!--&lt;meta http-equiv="refresh" content=";url=faces/home.xhtml"/&gt;-->
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_master.css" media="screen   ,print" rel="stylesheet" type="text/css"/>
#   <!--&lt;link rel="stylesheet" type="text/css" href="./resources/css/leginfo_mobile.css" media="screen and (-webkit-min-device-pixel-ratio: 1.1) and (max-device-width: 990px)" /&gt;
#     &lt;link rel="stylesheet" type="text/css" href="./resources/css/leginfo_mobile.css" media="screen and (min-device-width: 481px)and (max-device-width: 640px)and (-webkit-max-device-pixel-ratio: 1)" /&gt;-->
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_mobile.css" media="screen and (orientation: portrait) and (max-device-width: 767px),screen and (orientation: landscape)  and (-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" rel="stylesheet" type="text/css"/>
#   <!--&lt;link rel="stylesheet" type="text/css" href="./resources/css/leginfo_mobile_low_res.css" media="screen and (max-device-width: 480px)and (-webkit-max-device-pixel-ratio: 1)" /&gt;-->
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_print.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_codes.css" media="screen,print" rel="stylesheet" type="text/css"/>
#   <title>
#    Bill Text  - SB-485 Elections: election worker protections.
#   </title>
#   <link href="favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <style>
#    /* Hide page by default*/
#       html { display : none; }
#   </style>
#   <script type="text/javascript">
#    //<![CDATA[
#
#       if (self===top) {
#         // Show the page
#         document.documentElement.style.display='block';
#       } else {
#         // Inside a frame. Replace the frame.
#         var parentUrl=document.referrer;
#         var num=-1;
#         if (parentUrl!=='') {
#
#           num=parseInt(parentUrl.indexOf('calchannel.granicus.com'));
#
#           if (!(num>=0)) {
#             window.top.location.replace(window.location);
#             top.location=self.location;
#           }
#         }
#       }
#       // ]]>
#   </script>
#   <style>
#    /* Hide page by default*/
#       html { display : inline; }
#   </style>
#  </head>
#  <body>
#   <span id="j_idt12">
#    <script language="javascript" type="text/javascript">
#     //<![CDATA[
# function faceletsDebug(URL) {day = new Date();id = day.getTime();eval("page" + id + " = window.open(URL, '" + id + "', 'toolbar=0,scrollbars=1,location=0,statusbar=0,menubar=0,resizable=1,width=800,height=600,left = 240,top = 212');"); };(function() { if (typeof jsfFaceletsDebug === 'undefined') { var jsfFaceletsDebug = false; } if (!jsfFaceletsDebug) {var faceletsOrigKeyup = document.onkeyup;document.onkeyup = function(e) { if (window.event) e = window.event; if (String.fromCharCode(e.keyCode) == 'D' & e.shiftKey & e.ctrlKey) faceletsDebug('/faces/billTextClient.xhtml?facelets.ui.DebugOutput=1691847820863'); jsfFaceletsDebug = true; if (faceletsOrigKeyup) faceletsOrigKeyup(e); };
# }})();//]]>
#    </script>
#   </span>
#   <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#    <script language="JavaScript">
#     function changePlaceHolder() {
#             var x = document.getElementById("billheaderinit_form:quick_search_select_id");
#             var input = document.getElementById("billheaderinit_form:searchall");
#
#             if (x !== null) {
#                 for (i = 0; i < x.options.length; i++) {
#                     if (x.options[i].selected) {
#                         if (x.options[i].value === 'billKeyword') {
#                             input.placeholder = "Search phrase";
#                         } else {
#                             input.placeholder = "AB1 or ab 1 or ABX1-1";
#                         }
#                     }
#                 }
#             }
#         }
#    </script>
#    <body onload="changePlaceHolder()">
#     <form action="/faces/billTextClient.xhtml" enctype="application/x-www-form-urlencoded" id="billheaderinit_form" method="post" name="billheaderinit_form">
#      <input name="billheaderinit_form" type="hidden" value="billheaderinit_form"/>
#      <!--&lt;div class="skip textright"&gt;&lt;/div&gt;-->
#      <!-- END: skip textright div -->
#      <div id="banner">
#       <div class="horznavigation textright" id="system">
#        <ul>
#         <li>
#          <a href="#content_anchor">
#           skip to content
#          </a>
#         </li>
#         <li>
#          <script src="/faces/javax.faces.resource/jsf.js?ln=javax.faces" type="text/javascript">
#          </script>
#          <a href="#" id="billheaderinit_form:nav_bar_link_home" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_home':'billheaderinit_form:nav_bar_link_home'},'');return false">
#           home
#          </a>
#         </li>
#         <li>
#          <a href="#" id="billheaderinit_form:nav_bar_link_accessibility" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_accessibility':'billheaderinit_form:nav_bar_link_accessibility'},'');return false">
#           accessibility
#          </a>
#         </li>
#         <li>
#          <a href="#" id="billheaderinit_form:nav_bar_link_faq" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_faq':'billheaderinit_form:nav_bar_link_faq'},'');return false">
#           FAQ
#          </a>
#         </li>
#         <li>
#          <a href="#" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:j_idt27':'billheaderinit_form:j_idt27','destPage':'feedbackNewidea.xhtml'},'');return false">
#           feedback
#          </a>
#         </li>
#         <li>
#          <a href="#" id="billheaderinit_form:nav_bar_link_sitemap" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_sitemap':'billheaderinit_form:nav_bar_link_sitemap'},'');return false">
#           sitemap
#          </a>
#         </li>
#         <!--  &lt;li&gt; &lt;h:link outcome="loginClient" rendered="true"&gt;
#                                   &lt;h:outputText value="login"/&gt;
#                                   &lt;f:param name="destPage" value="home.xhtml"&gt;&lt;/f:param&gt;
#                               &lt;/h:link&gt;
#                         &lt;/li&gt;-->
#         <li>
#          <a href="#" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:j_idt33':'billheaderinit_form:j_idt33','destPage':'home.xhtml'},'');return false">
#           login
#          </a>
#         </li>
#         <li>
#          <span style="visibility:hidden;">
#           x
#          </span>
#         </li>
#         <!-- invisible span removes IE horiz window scroll bar -->
#         <!--&lt;li&gt;&lt;h:commandLink id="nav_bar_link_espanol" action="{profile_Backing.changeLocaleToES}"&gt;&lt;h:outputText value="{profile_Backing.language}"/&gt;&lt;/h:commandLink&gt;&lt;/li&gt;-->
#        </ul>
#       </div>
#       <!-- END: system div -->
#       <!-- BEGIN quick search -->
#       <div id="logo">
#        <a href="#" id="billheaderinit_form:header_img" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:header_img':'billheaderinit_form:header_img'},'');return false">
#         <img alt="Legislative Information header image: click to go to the home page" id="capitol" src="/resources/images/header_img.png"/>
#        </a>
#       </div>
#       <!-- END: logo div -->
#       <div id="logo_mobile">
#        <img alt="Legislative Information header image" id="capitol_mobile1" src="/resources/images/header_img_mobile_01.png"/>
#        <a href="#" id="billheaderinit_form:header_img_mobile2" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:header_img_mobile2':'billheaderinit_form:header_img_mobile2'},'');return false">
#         <img alt="home image: click to go to the home page" id="capitol_mobile2" src="/resources/images/header_img_mobile_02.png"/>
#        </a>
#        <a href="#" id="billheaderinit_form:header_img_mobile25" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:header_img_mobile25':'billheaderinit_form:header_img_mobile25'},'');return false">
#         <img alt="Bill Search image: click to go to the bill search page" id="capitol_mobile25" src="/resources/images/header_img_mobile_025.png"/>
#        </a>
#        <a href="" onclick="history.back();                             return false;">
#         <img alt="back button image: click to go to previous page" id="capitol_mobile3" src="/resources/images/header_img_mobile_03.png"/>
#        </a>
#        <br/>
#        <img alt="Legislative Information text image" id="capitol_mobile4" src="/resources/images/header_img_mobile_04.png"/>
#       </div>
#       <div id="billheaderinit_form:quick_search_div">
#        <div id="quick_search">
#         <div id="quick_search_text">
#          <img alt="magnifying glass image" id="quick_search_mag_glass" src="/resources/images/mag_glass.png"/>
#          <label for="billheaderinit_form:quick_search_select_id">
#           Quick Search:
#          </label>
#         </div>
#         <div id="quick_search_form">
#          <select id="billheaderinit_form:quick_search_select_id" name="billheaderinit_form:quick_search_select_id" onchange="changePlaceHolder()" size="1" style="background-color: #fff ; color:#0D0D0D;">
#           <option value="billNumber">
#            Bill Number
#           </option>
#           <option value="billKeyword">
#            Bill Keyword
#           </option>
#          </select>
#          <!-- &lt;select id="quick_search_select_id" &gt;
#                              &lt;option value="billNumber"&gt;Bill Number&lt;/option&gt;
#                              &lt;option value="billKeyword"&gt;Bill Keyword&lt;/option&gt;
#                              &lt;option value="billCode"&gt;Code&lt;/option&gt;
#                              &lt;/select&gt;-->
#          <input aria-label="Bill number / Keyword" id="billheaderinit_form:searchall" maxlength="2048" name="billheaderinit_form:searchall" onkeypress="if (event.keyCode == 13) {                                                      document.getElementById('billheaderinit_form:quick_search_submit').click();                                                      return false;                                                  }                                                  ;                                                  return true;" placeholder="AB1 or ab 1 or ABX1-1" size="13" type="text"/>
#          <input class="quick_search_submit" id="billheaderinit_form:quick_search_submit" name="billheaderinit_form:quick_search_submit" onmouseout="this.className = 'quick_search_submit'" onmouseover="this.className = 'quick_search_submit_hover'" type="submit" value="go"/>
#         </div>
#        </div>
#        <!-- END  quick search -->
#       </div>
#      </div>
#      <!-- END: banner div -->
#      <!-- End Header -->
#      <!-- End Header -->
#      <!-- Begin Navigation -->
#      <html xmlns="http://www.w3.org/1999/xhtml">
#       <link href="https://leginfo.legislature.ca.gov/resources/css/navigation.css" media="screen,print" rel="stylesheet" type="text/css"/>
#       <!--  &lt;link rel="stylesheet" type="text/css" href="/resources/css/leginfo_mobile.css"
#         media="screen and (orientation: portrait) and (max-device-width: 767px),
#         screen and (orientation: landscape) and (max-device-height: 750px)" /&gt;-->
#       <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_mobile.css" media="screen and (orientation: portrait) and (max-device-width: 767px),screen and (orientation: landscape)             and (-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" rel="stylesheet" type="text/css"/>
#       <!-- Start Navigation -->
#       <div id="tabs">
#        <ul>
#         <!-- CSS Tabs -->
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:home_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:home_link':'billheaderinit_form:home_link'},'');return false">
#           <span class="nav_text">
#            Home
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_selected" href="#" id="billheaderinit_form:bill_info_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:bill_info_link':'billheaderinit_form:bill_info_link'},'');return false">
#           <span class="nav_text">
#            Bill Information
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:codes_info_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:codes_info_link':'billheaderinit_form:codes_info_link'},'');return false">
#           <span class="nav_text">
#            California Law
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:pubs_info_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:pubs_info_link':'billheaderinit_form:pubs_info_link'},'');return false">
#           <span class="nav_text">
#            Publications
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:resources_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:resources_link':'billheaderinit_form:resources_link'},'');return false">
#           <span class="nav_text">
#            Other Resources
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:my_bills_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:my_bills_link':'billheaderinit_form:my_bills_link'},'');return false">
#           <span class="nav_text">
#            My Subscriptions
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:my_favs_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:my_favs_link':'billheaderinit_form:my_favs_link'},'');return false">
#           <span class="nav_text">
#            My Favorites
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <!-- End Navigation -->
#      </html>
#      <input autocomplete="off" id="j_id1:javax.faces.ViewState:0" name="javax.faces.ViewState" type="hidden" value="..."/>
#     </form>
#     <a id="content_anchor" name="content_anchor">
#     </a>
#    </body>
#   </html>
#   <div id="content_main">
#    <!-- Main content -->
#    <div class="column centercolumntwo" id="centercolumn">
#     <!-- BEGIN: breadcrumb -->
#     <!--
# To change this license header, choose License Headers in Project Properties.
# To change this template file, choose Tools | Templates
# and open the template in the editor.
# -->
#     <html xmlns="http://www.w3.org/1999/xhtml">
#      <body>
#       <div class="horznavigation" id="breadcrumbs">
#        <ul>
#         <li>
#          <a href="/faces/billSearchClient.xhtml">
#           Bill Information
#          </a>
#          &gt;&gt;
#         </li>
#         <li>
#          <a href="/faces/billSearchClient.xhtml">
#           Bill Search
#          </a>
#          &gt;&gt;
#         </li>
#         <li>
#          Text
#         </li>
#        </ul>
#       </div>
#      </body>
#     </html>
#     <!-- END: breadcrumb -->
#     <h1>
#      Bill Text
#     </h1>
#     <div id="bill_text_navigation">
#      <html xmlns="http://www.w3.org/1999/xhtml">
#       <!--&lt;script type="text/javascript"&gt;-->
#       <script language="javascript" type="text/javascript">
#        function asAmendsPopup() {
#             window.open("asAmendsInfo.xhtml", "Information", "width=330, height=220, toolbar=no, location=no, directories=no, menubar=no, scrollbars=no, top=270, left=150")
#         }
#
#         function selectVersion() {
#
#             var versionObj = document.getElementById("version");
#             var selectedVersionId = '20230SB48593AMD';
#             var len = versionObj.options.length;
#             //alert('selectedVersionId='+selectedVersionId);
#             for (i = 0; i < len; i++) {
#                 if (versionObj.options[i].value == selectedVersionId) {
#                     versionObj.options[i].selected = true;
#                 }
#             }
#         }
#
#         function  downLoadPDF() {
#             document.getElementById("pdf_link2").click();
#         }
#       </script>
#       <body>
#        <form action="/faces/billTextClient.xhtml" enctype="application/x-www-form-urlencoded" id="billDetailTopNavBarId" method="post" name="billDetailTopNavBarId">
#         <input name="billDetailTopNavBarId" type="hidden" value="billDetailTopNavBarId"/>
#         <input id="bid" name="bid" type="hidden" value="202320240SB485"/>
#         <input id="vid" name="vid" type="hidden" value="20230SB48593AMD"/>
#         <div id="bill_header">
#          <br/>
#          <div id="bill_version" style="margin-top: 1em;">
#           <a aria-hidden="true" class="bill_nav_sub_mobile" hidden="true" href="#" id="pdf_link2" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'pdf_link2':'pdf_link2','bill_id':'202320240SB485','version':''},'');return false" style="display:none" type="hidden">
#            PDF2
#           </a>
#           <a href="/faces/billPdf.xhtml?bill_id=202320240SB485&amp;version=20230SB48593AMD" onclick="downLoadPDF();                                 return false;">
#            Bill PDF
#           </a>
#           <!--TODO:: Add rendered condition above-->
#           <!--rendered="{billDetail_Backing.billDetailBean.isCurrentSession}"-->
#           <!--                &lt;h:link outcome="billTextClient"  includeViewParams="true" target="_blank" &gt;
#                                         &lt;h:outputText value="click"/&gt;
#                                         &lt;f:viewParam name="bill_id" value="{billDetailText.billId}"/&gt;
#                                         &lt;f:viewParam name="version" value="{billDetailText.version}"/&gt;
#
#                                     &lt;/h:link&gt;-->
#           <span class="bill_nav_sub_mobile">
#            |
#           </span>
#           <a class="bill_nav_sub_mobile" href="#" id="myfavs_link" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'myfavs_link':'myfavs_link','bill_id':'202320240SB485'},'');return false" style="margin-left: .8em;">
#            Add To My Favorites
#           </a>
#           <span class="bill_nav_sub_mobile">
#            |
#           </span>
#           <a class="bill_nav_sub_mobile" href="#" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'j_idt119':'j_idt119','bill_id':'202320240SB485'},'');return false" style="margin-left: .8em;">
#            Track Bill
#           </a>
#           <span class="bill_nav_sub_mobile" style="margin:0 .5em 0 .5em;">
#            |
#           </span>
#           <label for="version">
#            Version:
#           </label>
#           <select class="bill_version_select" id="version" name="version" size="1">
#            <option value="20230SB48593AMD">
#             07/06/23 - Amended Assembly
#            </option>
#            <option value="20230SB48594AMD">
#             06/22/23 - Amended Assembly
#            </option>
#            <option value="20230SB48595AMD">
#             05/01/23 - Amended Senate
#            </option>
#            <option value="20230SB48596AMD">
#             04/19/23 - Amended Senate
#            </option>
#            <option value="20230SB48597AMD">
#             03/30/23 - Amended Senate
#            </option>
#            <option value="20230SB48598AMD">
#             03/20/23 - Amended Senate
#            </option>
#            <option value="20230SB48599INT">
#             02/14/23 - Introduced
#            </option>
#           </select>
#           <input class="bill_version_go" id="ddbill_version" name="ddbill_version" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'ddbill_version':'ddbill_version','bill_id':'202320240SB485','version':''},'');return false" type="submit" value="Go"/>
#           <!--{billDetail_Backing.reloadPageForNewVersion}-->
#           <span class="bill_nav_sub_mobile" style="margin:0 .5em 0 .5em;">
#           </span>
#           <a class="bill_nav_sub_mobile" href="#" onclick="jsf.util.chain(this,event,'javascript:window.print();                             return false;','mojarra.jsfcljs(document.getElementById(\'billDetailTopNavBarId\'),{\'j_idt133\':\'j_idt133\'},\'\')');return false" title="Print Bills1">
#            <img alt="print page" src="/resources/images/print_24.gif"/>
#           </a>
#          </div>
#          <div>
#           <h1 style="display:block; text-align: left; font-size: 18px; font-weight: bold;border-bottom: none; white-space: nowrap; font-family:  Verdana, Arial, helvetica, sans-serif; text-transform: none; padding-top:  .2em;">
#            SB-485 Elections: election worker protections.
#            <span class="bill_title_yr">
#             (2023-2024)
#            </span>
#           </h1>
#          </div>
#         </div>
#         <div id="tab_panel">
#          <span class="tab_simple_start tab_selected">
#           <a class="tab_link" href="/faces/billTextClient.xhtml?bill_id=202320240SB485" id="nav_bar_top_text" name="nav_bar_top_text">
#            <span class="float_left" title="Bill Text">
#             Text
#            </span>
#            <!--&lt;f:param name="bill_id" value="{billDetail_Backing.billId}"&gt;&lt;/f:param&gt;-->
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billVotesClient.xhtml?bill_id=202320240SB485" id="nav_bar_top_votes" name="nav_bar_top_votes">
#            <span class="float_left" title="Bill Votes">
#             Votes
#            </span>
#            <!--&lt;f:param name="bill_id" value="{billDetail_Backing.billId}"&gt;&lt;/f:param&gt;-->
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billHistoryClient.xhtml?bill_id=202320240SB485" id="nav_bar_top_history" name="nav_bar_top_history">
#            <span class="float_left" title="Bill History">
#             History
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billAnalysisClient.xhtml?bill_id=202320240SB485" id="nav_bar_top_analysis" name="nav_bar_top_analysis" title="Bill Analysis">
#            <span class="float_left">
#             Bill Analysis
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billCompareClient.xhtml?bill_id=202320240SB485&amp;showamends=false" id="nav_bar_top_compare" name="nav_bar_top_compare" onclick="document.body.style.cursor = 'wait';" title="As Amends the Law">
#            <span class="float_left">
#             Today's Law As Amended
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#           <a href="/faces/billTextClient.xhtml?bill_id=202320240SB485" id="billInfoLink" name="billInfoLink" onclick="asAmendsPopup();">
#            <img alt="information" src="/resources/images/info_popup.gif" style="padding-left: 2px; height: 12px;"/>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billVersionsCompareClient.xhtml?bill_id=202320240SB485" id="nav_bar_top_version_compare" name="nav_bar_top_version_compare">
#            <span class="float_left" title="Compare two versions of the same bill">
#             Compare Versions
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected" id="nav_bar_status">
#           <a class="tab_link" href="/faces/billStatusClient.xhtml?bill_id=202320240SB485" id="nav_bar_top_status" name="nav_bar_top_status" title="Bill Status">
#            <span class="float_left">
#             Status
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected" id="nav_bar_commment">
#           <a class="tab_link" href="#" id="nav_bar_top_comment" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'nav_bar_top_comment':'nav_bar_top_comment','bill_id':'202320240SB485'},'');return false">
#            <span class="float_left" title="Send comments to Members">
#             Comments To Author
#            </span>
#            <!--          &lt;f:param name="version" value="20230SB48593AMD"/&gt;-->
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span id="track_bill_span">
#           <span class="tab_simple tab_not_selected" id="nav_bar_track_bill">
#            <a class="tab_link" href="/faces/billTrackingEdit.xhtml?bill_id=202320240SB485" id="nav_bar_top_track_bill" name="nav_bar_top_track_bill">
#             <span class="float_left" title="Track Bills">
#              Track Bill
#             </span>
#             <div class="arrow_right">
#              &gt;&gt;
#             </div>
#            </a>
#           </span>
#          </span>
#          <span id="my_favorites_span">
#           <span class="tab_simple tab_not_selected" id="nav_bar_my_favorites">
#            <a class="tab_link" href="#" id="nav_bar_top_my_favorites" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'nav_bar_top_my_favorites':'nav_bar_top_my_favorites','bill_id':'202320240SB485'},'');return false">
#             <span class="float_left" title="Add Bill to my favorites">
#              Add To My Favorites
#             </span>
#             <div class="arrow_right">
#              &gt;&gt;
#             </div>
#            </a>
#           </span>
#          </span>
#         </div>
#         <script>
#          selectVersion();
#         </script>
#         <input autocomplete="off" id="j_id1:javax.faces.ViewState:1" name="javax.faces.ViewState" type="hidden" value="..."/>
#        </form>
#       </body>
#      </html>
#     </div>
#     <div class="tab_content" id="billtext">
#      <form action="/faces/billTextClient.xhtml" enctype="application/x-www-form-urlencoded" id="j_idt197" method="post" name="j_idt197">
#       <input name="j_idt197" type="hidden" value="j_idt197"/>
#       <div style="float: left; width:15em; font-weight: bold; padding-top: 1.2em;">
#        <span style="font-weight:bold">
#         SHARE THIS:
#        </span>
#        <a href="https://www.facebook.com/sharer/sharer.php?u=https%3A//leginfo.legislature.ca.gov%3A443/faces/billNavClient.xhtml%3Fbill_id=202320240SB485&amp;t=20232024SB-485&amp;" id="j_idt197:facebook_link" name="j_idt197:facebook_link" style="margin-left: .8em;" target="_blank">
#         <img alt="share this bill in Facebook" border="0" src="./resources/images/facebook_32.png"/>
#        </a>
#        <a href="https://twitter.com/home?status=20232024SB-485 https://leginfo.legislature.ca.gov:443/faces/billNavClient.xhtml?bill_id=202320240SB485&amp;" id="twitter_link" style="margin-left: .8em;" target="_blank">
#         <img alt="share this bill in Twitter" border="0" src="./resources/images/twitter_32.png"/>
#        </a>
#       </div>
#       <div style="float:right; width:25em; padding-top: 2.7em;">
#        <span style="font-weight:bold; size:12;">
#         Date Published: 07/06/2023 09:00 PM
#        </span>
#       </div>
#       <input autocomplete="off" id="j_id1:javax.faces.ViewState:2" name="javax.faces.ViewState" type="hidden" value="..."/>
#      </form>
#      <html xmlns="http://www.w3.org/1999/xhtml" xmlns:caml="http://lc.ca.gov/legalservices/schemas/caml.1#" xmlns:fn="http://www.w3.org/2005/02/xpath-functions" xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:math="java.lang.Math" xmlns:xdt="http://www.w3.org/2005/02/xpath-datatypes" xmlns:xhtml="http://www.w3.org/1999/xhtml" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xs="http://www.w3.org/2001/XMLSchema">
#       <head>
#        <title>
#         SB485:v93#DOCUMENT
#        </title>
#        <meta content="SB485" name="dc:identifier"/>
#        <meta content="SB
#               485-
#                 AMENDED
#               " name="dc:title"/>
#        <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#       </head>
#       <body>
#        <span class="hidden">
#         <h2>
#          Bill Start
#         </h2>
#        </span>
#        <div align="justify" id="bill_all">
#         <div id="about">
#          <br clear="all"/>
#          <div align="center">
#           <table align="center" cellspacing="0" role="presentation" style="border-collapse: collapse">
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Assembly
#               </span>
#               <span style="text-transform: uppercase">
#                July 06, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Assembly
#               </span>
#               <span style="text-transform: uppercase">
#                June 22, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Senate
#               </span>
#               <span style="text-transform: uppercase">
#                May 01, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Senate
#               </span>
#               <span style="text-transform: uppercase">
#                April 19, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Senate
#               </span>
#               <span style="text-transform: uppercase">
#                March 30, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Senate
#               </span>
#               <span style="text-transform: uppercase">
#                March 20, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <br clear="all"/>
#          <div align="center">
#           <font size="3" style="FONT-FAMILY: MinionPC, Arial Unicode MS">
#            CALIFORNIA LEGISLATURE—
#                     2023–2024 REGULAR SESSION
#           </font>
#          </div>
#          <br clear="all"/>
#          <span id="bill_house_num">
#           <div style="float: left; width:50%; font-weight: bold; ">
#            <span style="text-transform: uppercase; text-align:left;width:50%;">
#             <b>
#              Senate Bill
#             </b>
#            </span>
#           </div>
#           <div style="float:right; width:50%; text-align:right;">
#            <span style="text-transform: uppercase;">
#             <b>
#              No. 485
#             </b>
#            </span>
#           </div>
#          </span>
#          <hr/>
#          <br clear="all"/>
#          <div align="center">
#           <table align="center" cellspacing="0" role="presentation" style="border-collapse: collapse">
#            <tbody>
#             <tr>
#              <td align="center" id="bill_authors">
#               <span style="font-weight:bold;">
#                Introduced by Senator Becker
#                <br/>
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td align="center" class="textcenter" id="bill_intro_date">
#               <br/>
#               February 14, 2023
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <hr/>
#          <br clear="all"/>
#          <div id="title">
#           <span style="font-weight:normal;font-size:0.9em;">
#            An act to amend Sections 18502 and 18540
#            <font color="#B30000">
#             <strike>
#              of, and to add Section 18502.5 to,
#             </strike>
#            </font>
#            <font class="blue_text" color="blue">
#             <i>
#              of
#             </i>
#            </font>
#            the Elections Code, relating to elections.
#           </span>
#          </div>
#          <br clear="all"/>
#          <br clear="all"/>
#          <div align="center">
#           <h2>
#            LEGISLATIVE COUNSEL'S DIGEST
#           </h2>
#          </div>
#          <br/>
#          <div style="margin:0 0 1em 0">
#           <span id="subject">
#            SB 485, as amended, Becker.
#                           Elections: election worker protections.
#           </span>
#          </div>
#          <div>
#           <span id="digesttext">
#            <div style="margin:0 0 1em 0;">
#             Existing law makes interfering in any manner with the officers holding an election or conducting a canvass or with a voter lawfully exercising their right of voting at an election, in order to prevent the election or canvass from being fairly held and lawfully conducted, a crime punishable by imprisonment for 16 months or 2 or 3 years.
#            </div>
#            <div style="margin:0 0 1em 0;">
#             This bill would expand
#             <font color="#B30000">
#              <strike>
#               that
#              </strike>
#             </font>
#             <font class="blue_text" color="blue">
#              <i>
#               this
#              </i>
#             </font>
#             crime to include interference with an elections official or their staff, including temporary workers and volunteers, or a member of a precinct board, in their performance of any duty related to conducting an election or canvass in order to prevent the election or canvass from being fairly
# 			 held and lawfully conducted.
#             <font class="blue_text" color="blue">
#              <i>
#               The bill would clarify that “conducting an election or canvass” for purposes of this crime includes the election observation process.
#              </i>
#             </font>
#            </div>
#            <font color="#B30000">
#             <strike>
#              <p style="display:inline;">
#               <strike>
#                The bill would also make it a crime punishable
# 		by imprisonment for 16 months or 2 or 3 years to use or threaten to use force, violence, or coercion or intimidation, or to hire or arrange for any other person to do so, to prevent or attempt to prevent an elections official, their staff, or a member of a precinct board from performing any duty related to conducting an election or canvass, or to prevent or attempt to prevent the Secretary of State or their staff from performing any of their election-related duties.
#               </strike>
#              </p>
#              <div style="margin:0 0 1em 0;">
#              </div>
#              <p style="display:inline;">
#               <strike>
#                The bill would clarify that these and related penal provisions in the Elections Code apply to the election observation process.
#               </strike>
#              </p>
#              <div style="margin:0 0 1em 0;">
#              </div>
#             </strike>
#            </font>
#            <div style="margin:0 0 1em 0;">
#             By
#             <font color="#B30000">
#              <strike>
#               creating a new crime and
#              </strike>
#             </font>
#             expanding the scope of an existing crime, this bill would impose a state-mandated local program.
#            </div>
#            <div style="margin:0 0 1em 0;">
#             The California
# 			 Constitution requires the state to reimburse local agencies and school districts for certain costs mandated by the state. Statutory provisions establish procedures for making that reimbursement.
#            </div>
#            <div style="margin:0 0 1em 0;">
#             This bill would provide that no reimbursement is required by this act for a specified reason.
#            </div>
#           </span>
#          </div>
#          <span class="hidden">
#           <h2>
#            Digest Key
#           </h2>
#          </span>
#          <span id="vote">
#           Vote:
#           <span style=" text-transform: lowercase">
#            MAJORITY
#           </span>
#          </span>
#          <span id="appropriation">
#           Appropriation:
#           <span style=" text-transform: lowercase">
#            NO
#           </span>
#          </span>
#          <span id="fiscalcommittee">
#           Fiscal Committee:
#           <span style=" text-transform: lowercase">
#            YES
#           </span>
#          </span>
#          <span id="localprogram">
#           Local Program:
#           <span style=" text-transform: lowercase">
#            YES
#           </span>
#          </span>
#         </div>
#         <hr/>
#         <span class="hidden">
#          <h2>
#           Bill Text
#          </h2>
#         </span>
#         <div id="bill">
#          <div style=" text-transform: uppercase">
#           <h2 style=" text-align: left;">
#            The people of the State of California do enact as follows:
#           </h2>
#           <br/>
#          </div>
#          <div id="s10.23068386874573998">
#           <div class="ActionLine" style="margin:0 0 1em 0">
#            <h3 style="font-weight:bold; display:inline;">
#             SECTION 1.
#            </h3>
#            Section 18502 of the Elections Code is amended to read:
#           </div>
#           <div>
#            <div id="id_E6B74811-B71C-490B-94F7-6042E3CFBCAC">
#             <div>
#              <p>
#               <div style="margin:0 0 1em 0;">
#                <h6 style="display:inline;">
#                 18502.
#                </h6>
#                (a) Any person who in any manner interferes with any of the following as to prevent the election or canvass from being fairly held and lawfully conducted, is punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years:
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (1) An elections official or their staff, including temporary workers and volunteers, in their performance of any duty related to conducting an election or canvass.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (2) A member of a precinct board, in their performance of any duty related to assisting with conducting an election or canvass.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (3) A voter lawfully exercising their rights of voting at an election.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (b) For purposes of this section, “conducting an election or canvass” includes the election observation process governed by this code and applicable regulations adopted by the Secretary of State.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (c) For purposes of this section, “voting at an election” includes voting in person at a polling place or at the office of the elections official, including satellite locations pursuant to Section 3018, and voting by mail and returning a voted ballot pursuant to subdivision (a) of Section 3017.
#               </div>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#          <font color="#B30000">
#           <strike>
#            <caml:billsection id="id_F03CA4DA-3031-4992-A0AF-3E8E05510C60">
#             <div style="margin:0 0 0.5em 0;">
#             </div>
#             <caml:num>
#              SEC. 2.
#             </caml:num>
#             <caml:actionline action="IS_ADDED" xlink:href="urn:caml:codes:ELEC:caml#xpointer(%2Fcaml%3ALawDoc%2Fcaml%3ACode%2F%2Fcaml%3ALawSection%5Bcaml%3ANum%3D'18502.5'%5D)" xlink:label="fractionType: LAW_SECTION" xlink:type="locator">
#              Section 18502.5 is added to the
#              <caml:docname>
#               Elections Code
#              </caml:docname>
#              , to read:
#             </caml:actionline>
#             <caml:fragment>
#              <caml:lawsection id="id_145350F1-6011-4B88-AEB8-DCE012E0CCBE">
#               <div style="margin:0 0 0.5em 0;">
#               </div>
#               <caml:num>
#                18502.5.
#               </caml:num>
#               <caml:lawsectionversion id="id_6A5959ED-E4A4-432F-835D-BDC7B4A762C6">
#                <caml:content>
#                 <p style="display:inline;">
#                  <strike>
#                   (a)
#                   <span class="EnSpace">
#                   </span>
#                   Every person who makes or hires or arranges for any other person to make use of or threatens to make use of any force, violence, or tactic of coercion or intimidation to prevent or attempt to prevent any of the following is guilty of a felony punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years:
#                  </strike>
#                 </p>
#                 <div style="margin:0 0 1em 0;">
#                 </div>
#                 <strike>
#                  <p style="margin-left: 1em;">
#                   (1)
#                   <span class="EnSpace">
#                   </span>
#                   An elections official or their staff, including temporary workers and volunteers, from performing any duty related to conducting an election or canvass.
#                  </p>
#                 </strike>
#                 <div style="margin:0 0 1em 0;">
#                 </div>
#                 <strike>
#                  <p style="margin-left: 1em;">
#                   (2)
#                   <span class="EnSpace">
#                   </span>
#                   A member of the precinct board from performing any duty related to assisting with conducting an election or canvass.
#                  </p>
#                 </strike>
#                 <div style="margin:0 0 1em 0;">
#                 </div>
#                 <strike>
#                  <p style="margin-left: 1em;">
#                   (3)
#                   <span class="EnSpace">
#                   </span>
#                   The Secretary of State as the chief elections officer, or their staff, from performing any duties related to administering the provisions of this code.
#                  </p>
#                 </strike>
#                 <div style="margin:0 0 1em 0;">
#                 </div>
#                 <p style="display:inline;">
#                  <strike>
#                   (b)
#                   <span class="EnSpace">
#                   </span>
#                   For purposes of this section, “conducting an election or canvass” includes the election observation process governed by this code and applicable regulations adopted by the Secretary of State.
#                  </strike>
#                 </p>
#                 <div style="margin:0 0 1em 0;">
#                 </div>
#                </caml:content>
#               </caml:lawsectionversion>
#              </caml:lawsection>
#             </caml:fragment>
#            </caml:billsection>
#           </strike>
#          </font>
#          <div id="s30.45507708185684426">
#           <div class="ActionLine" style="margin:0 0 1em 0">
#            <h3 style="font-weight:bold; display:inline;">
#             <font color="#B30000">
#              <strike>
#               SEC. 3.
#              </strike>
#             </font>
#             <font class="blue_text" color="blue">
#              <i>
#               SEC. 2.
#              </i>
#             </font>
#            </h3>
#            Section 18540 of the Elections Code is amended to read:
#           </div>
#           <div>
#            <div id="id_37C579E3-F3DA-4A4B-84B8-CC5D44995EA0">
#             <div>
#              <p>
#               <div style="margin:0 0 1em 0;">
#                <h6 style="display:inline;">
#                 18540.
#                </h6>
#                (a) Every person who makes use of or threatens to make use of any force, violence, or tactic of coercion or intimidation, to induce or compel any other person to vote or refrain from voting at any election or to vote or refrain from voting for any particular person or measure at any election, or because any person voted or refrained from voting at any election or voted or refrained from voting for any particular person or measure at any election is guilty of a felony punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (b) Every person who hires or arranges for any other person to make use of or threaten to
# 						make use of any force, violence, or tactic of coercion or intimidation, to induce or compel any other person to vote or refrain from voting at any election or to vote or refrain from voting for any particular person or measure at any election, or because any person voted or refrained from voting at any election or voted or refrained from voting for any particular person or measure at any election is guilty of a felony punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (c) For purposes of this section, “voting at any election” includes voting in person at a polling place or at the office of the elections official, including satellite locations pursuant to Section 3018, and voting by mail and returning a voted ballot pursuant to subdivision (a) of Section
# 						3017.
#               </div>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div id="s40.2983070376521697">
#           <div>
#            <div style="margin:0 0 1em 0;">
#             <h3 style="font-weight:bold; display:inline;">
#              <font color="#B30000">
#               <strike>
#                SEC. 4.
#               </strike>
#              </font>
#              <font class="blue_text" color="blue">
#               <i>
#                SEC. 3.
#               </i>
#              </font>
#             </h3>
#             No reimbursement is required by this act pursuant to Section 6 of Article XIII B of the California Constitution because the only costs that may be incurred by a local agency or school district will be incurred because this act creates a new crime or infraction, eliminates a crime or infraction, or changes the penalty for a crime or infraction, within the meaning of Section 17556 of the Government Code, or changes the definition of a crime within the meaning of Section 6 of Article XIII B of the California Constitution.
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </body>
#      </html>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# main page: locating title in html
t = soup.find_all('title')
print(len(t))
print(t[0])
# Out:
# 2
# <title>Bill Text  - AB-1197 Agricultural Protection Planning Grant Program: local food producers.</title>

# %%
# main page: locating bill year introduced in html
#y = soup.find_all(id = 'bill_intro_date')
y = soup.find_all(class_ = 'bill_title_yr')
print(len(y))
#print(y[0])
print(y)
# Out:
# 1
# [<span class="bill_title_yr">(2023-2024)</span>]

# %%
# main page: locating bill year amended in html
#y1 = soup.find_all('tbody')
#print(len(y1))
#print(type(y1))
#print(y1[0])

# %%
# main page: locating bill text bloc in html
ti = soup.find_all('div', id = 'bill')
print(len(ti))
print(type(ti))
print(ti)
# Out:
# 1
# <class 'bs4.element.ResultSet'>
# [<div id="bill"><div style=" text-transform: uppercase"><h2 style=" text-align: left;">The people of the State of California do enact as follows:</h2><br/></div><div id="s10.8987986890852493"><div><div style="margin:0 0 1em 0;"><h3 style="font-weight:bold; display:inline;">SECTION 1.</h3> The Legislature finds and declares all of the following:</div><div style="margin:0 0 1em 0;">(a) Over one-third of the country’s vegetables and two-thirds of the country’s fruits and nuts are grown in California. California’s agricultural abundance includes more than 400 commodities. California is the leading state in the nation for cash farm receipts, accounting for over 13 percent of the nation’s total agricultural value.</div><div style="margin:0 0 1em 0;">(b) California is the sole producer (99 percent or more) in the nation of the following crops: almonds, artichokes, dates, figs, garlic, grapes, raisins, kiwi, melons, olives, clingstone peaches, pistachios,
# 				rice, and walnuts, and a lead producer in many more agricultural products.</div><div style="margin:0 0 1em 0;">(c) Farmers in this state produce fruits, vegetables, nuts, and meat from animal livestock in accordance with the state’s pesticide, labor, environmental, and minimum wage laws.</div><div style="margin:0 0 1em 0;">(d) Complying with these state laws increases costs but provides real benefits to the health of consumers, to the environment, and to the workers who produce these goods.</div><div style="margin:0 0 1em 0;">(e) On January 25, 2021, President Biden issued an Executive Order on “Ensuring the Future Is Made in All of America by All of America’s Workers” that stated that “It is the policy of my Administration that the United States Government should, consistent with applicable law, use terms and conditions of
# 				Federal financial assistance awards and Federal procurements to maximize the use of goods, products, and materials produced in, and services offered in, the United States. The United States Government should, whenever possible, procure goods, products, materials, and services from sources that will help American businesses compete in strategic industries and help America’s workers thrive.”</div><div style="margin:0 0 1em 0;">(f) The Buy American Provision requiring the purchase of domestic commodities by participants in the National School Lunch Program has been in place for 30 years. However, the law allows waivers where the domestic product is priced significantly higher than a nondomestic product. This loophole has resulted in widespread noncompliance with Buy America requirements.</div><div style="margin:0 0 1em 0;">(g) According to figures from
# 				the National Council of Farmer Cooperatives, 81 percent of the apple juice served in the school lunch program is imported, and 50 to 60 percent of the fish served in schools is “caught by Russian ships and processed in China.”</div><div style="margin:0 0 1em 0;">(h) Competition from nondomestic producers hurts California agriculture and threatens to eliminate the jobs that workers depend on to feed their own families.</div><div style="margin:0 0 1em 0;">(i) Those who rely on publicly purchased nutrition programs, including school nutrition programs, are often among the most vulnerable children and families. They should have access to high-quality, healthy meals, such as those grown, packed, and produced in California.</div><div style="margin:0 0 1em 0;">(j) Purchasing domestic products reduces the carbon footprint and
# 				results in lower greenhouse gas emissions. California companies are subject to more rigorous environmental standards, resulting in enhanced food safety and public safety.</div></div></div><div id="s20.47325582563753055"><div class="ActionLine" style="margin:0 0 1em 0"><h3 style="font-weight:bold; display:inline;">SEC. 2.</h3> Section 58595 of the Food and Agricultural Code is amended to read:</div><div><div id="id_34139C02-FFF7-47F4-91A2-69D7818F1A63"><div><p><div style="margin:0 0 1em 0;"><h6 style="display:inline;">58595.</h6> (a) A California state-owned or state-run institution that purchases agricultural food products shall implement necessary practices to achieve a goal of ensuring that at least 60 percent of the agricultural food products that it purchases in a calendar year are grown or produced in the state by December 31, 2025.</div><div style="margin:0 0 1em 0;">(b) Subdivision (a) does not apply to segments of public postsecondary education or local educational agencies.</div><div style="margin:0 0 1em 0;">(c) A local educational agency that solicits bids for the purchase of an agricultural food product shall accept a bid or price for that agricultural food product when it is grown in California before accepting a
# 						bid or price for a domestic agricultural food product that is grown outside the state, when both of the following are met:</div><div style="margin:0 0 1em 0;margin-left: 1em;">(1) The bid or price of the California-grown agricultural food product does not exceed the lowest bid or price for a domestic agricultural food product produced outside the state.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(2) The quality of the California-grown agricultural food product is comparable to that domestic agricultural food product produced outside the state.</div><div style="margin:0 0 1em 0;">(d) This section shall
# 						neither limit nor expand California’s obligations under the Agreement on Government Procurement of the World Trade Organization.</div><div style="margin:0 0 1em 0;">(e) For purposes of this section, the following definitions apply:</div><div style="margin:0 0 1em 0;margin-left: 1em;">(1) “Agricultural food product” means any fresh or processed
# 						food product including, but not limited to, fruits, nuts, vegetables, herbs, mushrooms, dairy, shell eggs, honey, pollen, grains, livestock meats, poultry meats, rabbit meats, and fish, including shellfish.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(2) “Local educational agency” has the same meaning as defined in Section 49557.5 of the Education Code.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(3) “Segment of public postsecondary education” means a segment of public higher education described in Section 66010 of the Education Code.</div></p></div></div></div></div><div id="s30.6165256272131688"><div><div style="margin:0 0 1em 0;"><h3 style="font-weight:bold; display:inline;">SEC. 3.</h3> If the Commission on State Mandates determines that this act contains costs mandated by the state, reimbursement to local agencies and school districts for those costs shall be made pursuant to Part 7 (commencing with Section 17500) of Division 4 of Title 2 of the Government Code.</div></div></div></div>]

# %%
# status page: locating bill status: STATE link
#status = soup.find_all('tr')
#status = soup.find_all('td')
#status = soup1.find_all('td', class_= "statusLabelData")
#status = soup1.find_all('td', scope = "row")
status = soup1.find_all(id = "billhistory")
print(len(status))
print(type(status))
print(status)
#print(status.pop(0))
# Out:
# 1
# <class 'bs4.element.ResultSet'>
# [<table cellspacing="0" id="billhistory" width="100%">
# <thead>
# <tr>
# <th colspan="2" scope="colgroup">Last 5 History Actions</th>
# </tr>
# <tr>
# <th class="status_col_width" scope="col">Date</th>
# <th scope="col">Action</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td scope="row">07/05/23</td>
# <td>From committee: Do pass and re-refer to Com. on  APPR. (Ayes  3. Noes  0.) (July  3). Re-referred to Com. on  APPR.</td>
# </tr>
# <tr>
# <td scope="row">06/26/23</td>
# <td>Read second time and amended.  Re-referred to Com. on  AGRI.</td>
# </tr>
# <tr>
# <td scope="row">06/22/23</td>
# <td>From committee: Amend, and do pass as amended and re-refer to Com. on  AGRI. (Ayes  9. Noes  0.) (June  22).</td>
# </tr>
# <tr>
# <td scope="row">06/12/23</td>
# <td>From committee chair, with author's amendments:  Amend, and re-refer to committee.  Read second time, amended, and re-referred to Com. on  N.R. &amp; W.</td>
# </tr>
# <tr>
# <td scope="row">06/07/23</td>
# <td>Referred to Coms. on  N.R. &amp; W. and  AGRI.</td>
# </tr>
# </tbody>
# </table>]

# %%
# status page: locating bill status: LEGISCAN main link
status = soup.find_all('b')
status = soup.find_all('hr')
status = soup.find_all(id = "gaits-social")
status = soup.find_all('span', class_ = 'tab')
print(len(status))
print(type(status))
print(status)
#print(status[-1])
#print(status.pop())
# Out:
# 1
# <class 'bs4.element.ResultSet'>
# [<div id="bill-last-action" style="margin: 0 1em">Spectrum: Partisan Bill (Democrat 1-0)<br/>Status: Engrossed on May 30 2023 - 50% progression<br/>Action: 2023-07-13 - From committee: Do pass as amended and re-refer to Com. on APPR. (Ayes 6. Noes 1.) (July 11).<br/>Pending: <a href="/CA/pending/assembly-appropriations-committee/id/449" title="View other bills referred to CA Assembly Appropriations Committee">Assembly Appropriations Committee</a><br/>Text: <a href="/CA/text/SB485/2023" title="View latest bill text for California SB485">Latest bill text (Amended) [HTML]</a></div>]

# %%
# status page: locating bill status: LEGISCAN bill page link
#status = soup.find_all('tr')
#status = soup.find_all('td')
status = soup2.find_all(id = "bill-last-action")
print(len(status))
print(type(status))
print(status)
#print(status[-1])
#print(status.pop())
# Out:
# 1
# <class 'bs4.element.ResultSet'>
# [<div id="bill-last-action" style="margin: 0 1em">Spectrum: Partisan Bill (Democrat 1-0)<br/>Status: Engrossed on May 30 2023 - 50% progression<br/>Action: 2023-07-13 - From committee: Do pass as amended and re-refer to Com. on APPR. (Ayes 6. Noes 1.) (July 11).<br/>Pending: <a href="/CA/pending/assembly-appropriations-committee/id/449" title="View other bills referred to CA Assembly Appropriations Committee">Assembly Appropriations Committee</a><br/>Text: <a href="/CA/text/SB485/2023" title="View latest bill text for California SB485">Latest bill text (Amended) [HTML]</a></div>]

# %%
# remove html style and tags from title
for text in t[0]:
    title = text.text.strip()
    title = title.split("- ")[-1]
title
# Out:
# 'SB-485 Elections: election worker protections.'

# %%
# remove html style and tags from year int
for text in y:
    year = text.text.strip()
    #yeari = yeari[-4:]
year
# Out:
# '(2021-2022)'

# %%
# remove html style and tags from year amended
#for text in y1[0]:
 #   yeara = text.text.strip()
 #   yeara = yeara[-4:]
#yeara

# %%
# remove html style and tags from bill text
for text in ti:
    
    billtxt = text.text.strip()#.encode("ascii", "ignore")
    #billtxt = str(billtxt)
    
    # remove non ASCII chars
    # https://stackoverflow.com/questions/20078816/replace-non-ascii-characters-with-a-single-space
    billtxt = re.sub(r'[^\x00-\x7F]+', ' ', billtxt)#.replace('\n\t\t\t\t\t\t', ' ')
    
    # remove tabs and new lines
    billtxt = re.sub(r'(\s)', ' ', billtxt)

    # add space after colons and semicolons
    billtxt = re.sub(r'(\:|\;)+', r'\1 ', billtxt)
    
    # add space after periods only if preceded by words
    billtxt = re.sub(r'([A-z]{4,}\.)+', r'\1 ', billtxt)
    
    # remove any extra white spaces
    billtxt = re.sub(r'\s+', ' ', billtxt)
    
    # testing search
    #comp = re.compile(r'([A-z]{4,}\.)+')
   # find = re.search(comp, billtxt)

#find
print(type(billtxt))
billtxt
# Out:
# <class 'str'>
# 'The people of the State of California do enact as follows: SECTION 1. Section 18502 of the Elections Code is amended to read: 18502. (a) Any person who in any manner interferes with any of the following as to prevent the election or canvass from being fairly held and lawfully conducted, is punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years: (1) An elections official or their staff, including temporary workers and volunteers, in their performance of any duty related to conducting an election or canvass. (2) A member of a precinct board, in their performance of any duty related to assisting with conducting an election or canvass. (3) A voter lawfully exercising their rights of voting at an election. (b) For purposes of this section, conducting an election or canvass includes the election observation process governed by this code and applicable regulations adopted by the Secretary of State. (c) For purposes of this section, voting at an election includes voting in person at a polling place or at the office of the elections official, including satellite locations pursuant to Section 3018, and voting by mail and returning a voted ballot pursuant to subdivision (a) of Section 3017.SEC. 2.Section 18502.5 is added to the Elections Code, to read: 18502.5.(a)Every person who makes or hires or arranges for any other person to make use of or threatens to make use of any force, violence, or tactic of coercion or intimidation to prevent or attempt to prevent any of the following is guilty of a felony punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years: (1)An elections official or their staff, including temporary workers and volunteers, from performing any duty related to conducting an election or canvass. (2)A member of the precinct board from performing any duty related to assisting with conducting an election or canvass. (3)The Secretary of State as the chief elections officer, or their staff, from performing any duties related to administering the provisions of this code. (b)For purposes of this section, conducting an election or canvass includes the election observation process governed by this code and applicable regulations adopted by the Secretary of State. SEC. 3.SEC. 2. Section 18540 of the Elections Code is amended to read: 18540. (a) Every person who makes use of or threatens to make use of any force, violence, or tactic of coercion or intimidation, to induce or compel any other person to vote or refrain from voting at any election or to vote or refrain from voting for any particular person or measure at any election, or because any person voted or refrained from voting at any election or voted or refrained from voting for any particular person or measure at any election is guilty of a felony punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years. (b) Every person who hires or arranges for any other person to make use of or threaten to make use of any force, violence, or tactic of coercion or intimidation, to induce or compel any other person to vote or refrain from voting at any election or to vote or refrain from voting for any particular person or measure at any election, or because any person voted or refrained from voting at any election or voted or refrained from voting for any particular person or measure at any election is guilty of a felony punishable by imprisonment pursuant to subdivision (h) of Section 1170 of the Penal Code for 16 months or two or three years. (c) For purposes of this section, voting at any election includes voting in person at a polling place or at the office of the elections official, including satellite locations pursuant to Section 3018, and voting by mail and returning a voted ballot pursuant to subdivision (a) of Section 3017.SEC. 4.SEC. 3. No reimbursement is required by this act ...

# %%
# remove html style and tags from bill status: State link
for text in status:
    status = text.text
    status = status.split("Action")[-1]
    status = re.sub(r'(\s)', ' ', status)
    status = re.sub(r'\s+', ' ', status)
    
status
# Out:
# " 07/05/23 From committee: Do pass and re-refer to Com. on APPR. (Ayes 3. Noes 0.) (July 3). Re-referred to Com. on APPR. 06/26/23 Read second time and amended. Re-referred to Com. on AGRI. 06/22/23 From committee: Amend, and do pass as amended and re-refer to Com. on AGRI. (Ayes 9. Noes 0.) (June 22). 06/12/23 From committee chair, with author's amendments: Amend, and re-refer to committee. Read second time, amended, and re-referred to Com. on N.R. & W. 06/07/23 Referred to Coms. on N.R. & W. and AGRI. "

# %%
# remove html style and tags from bill status: LegiScan link
for text in status:
    status = text.text.strip()
    status = status.split("Action: ")[-1].split("Pending")[0]

status
# Out:
# '2023-07-13 - From committee: Do pass as amended and re-refer to Com. on APPR. (Ayes 6. Noes 1.) (July 11).'

# %%
# stripping lingering unicode characters
billtxt1 = billtxt.astype('str')
billtxt1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 2
#       1 # stripping lingering unicode characters
# ----> 2 billtxt1 = billtxt.astype('str')
#       3 billtxt1
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
# creating bill_id
bill_id = title.split("- ")[-1][:7]

# concatenating into one list
infotxt1 = [bill_id, title, yeari, status, billtxt]
infotxt1
# Out:
# ['SB-118 ',
#  'SB-118 Budget Act of 2023: health.',
#  '2023',
#  'Referred to Coms. on  N.R. & W. and  AGRI.',
#  'The people of the State of California do enact as follows:SECTION 1.\xa0Section 1295 of the Code of Civil Procedure is amended to read:1295.\xa0(a)\xa0Any contract for medical services which contains a provision for arbitration of any dispute as to professional negligence of a health care provider shall have such provision as the first article of the contract and shall be expressed in the following language: “It is understood that any dispute as to medical malpractice, that is as to whether any medical services rendered under this contract were unnecessary or unauthorized or were improperly, negligently or incompetently rendered, will be determined by submission to arbitration as provided by California law, and not by a lawsuit or resort to court process except as California law provides for judicial review of arbitration proceedings. Both parties to this contract, by entering into it, are giving up their constitutional right to\n\t\t\t\t\t\thave any such dispute decided in a court of law before a jury, and instead are accepting the use of arbitration.”(b)\xa0Immediately before the signature line provided for the individual contracting for the medical services must appear the following in at least 10-point bold red type:“NOTICE: BY SIGNING THIS CONTRACT YOU ARE AGREEING TO HAVE ANY ISSUE OF MEDICAL MALPRACTICE DECIDED BY NEUTRAL ARBITRATION AND YOU ARE GIVING UP YOUR RIGHT TO A JURY OR COURT TRIAL. SEE ARTICLE 1 OF THIS CONTRACT.”(c)\xa0Once signed, such a contract governs all subsequent open-book account transactions for medical services for which the contract was signed until or unless rescinded by written notice within 30 days of signature. Written notice of such rescission may be given by a guardian or conservator of the patient if the patient is incapacitated or a\n\t\t\t\t\t\tminor.(d)\xa0Where the contract is one for medical services to a minor, it shall not be subject to disaffirmance if signed by the minor’s parent or legal guardian.(e)\xa0Such a contract is not a contract of adhesion, nor unconscionable nor otherwise improper, where it complies with subdivisions (a), (b), and (c) of this section.(f)\xa0Subdivisions (a), (b), and (c) shall not apply to any health care service plan contract offered by an organization registered pursuant to Article 2.5 (commencing with Section 12530) of Division 3 of Title 2 of the Government Code, or licensed pursuant to Chapter 2.2 (commencing with Section 1340) of Division 2 of the Health and Safety Code, which contains an arbitration agreement if the plan complies with paragraph (10) of subdivision (a)\n\t\t\t\t\t\t(b) of Section 1363 of the Health and Safety Code, or otherwise has a procedure for notifying prospective subscribers of the fact that the plan has an arbitration provision, and the plan contracts conform to subdivision (h) of Section 1373 of the Health and Safety Code.(g)\xa0For the purposes of this section:(1)\xa0“Health care provider” means any person licensed or certified pursuant to Division 2 (commencing with Section 500) of the Business and Professions Code, or licensed pursuant to the Osteopathic Initiative Act, or the Chiropractic Initiative Act, or licensed pursuant to Chapter 2.5 (commencing with Section 1440) of Division 2 of the Health and Safety Code; and any clinic, health dispensary, or health facility, licensed pursuant to Division 2 (commencing with Section 1200) of the Health and Safety Code. “Health care provider” includes\n\t\t\t\t\t\tthe legal representatives of a health care provider;(2)\xa0“Professional negligence” means a negligent act or omission to act by a health care provider in the rendering of professional services, which act or omission is the proximate cause of a personal injury or wrongful death, provided that such services are within the scope of services for which the provider is licensed and which are not within any restriction imposed by the licensing agency or licensed hospital.SEC. 2.\xa0Section 12534 of the Government Code is ame ...

# %%
# remove html style and tags from all bill info (B)

# list of all bill elements
billinfo = [t[0], y, y1[0], ti]

# remove html style and tags from bill text
infotxt = []

for info in billinfo:
    for text in info:
        row = text.text.strip()
        infotxt.append(row)
        
    # create bill id from bill title
    bill_id = infotxt[0].split("- ")[-1][:7]
    
# add an item to the list that will serve as the bill id later
infotxt.insert(0, bill_id)
        
print(len(infotxt))
infotxt
# Out:
# 5
# ['AB-1197',
#  'Bill Text  - AB-1197 Agricultural Protection Planning Grant Program: local food producers.',
#  'February\xa016,\xa02023',
#  'Amended\n              \xa0IN\xa0\n                Senate\n              \xa0June\xa026,\xa02023',
#  'The people of the State of California do enact as follows:SECTION 1.\xa0Section 10280 of the Public Resources Code is amended to read:10280.\xa0The Agricultural Protection Planning Grant Program is hereby established within the Department of Conservation, to provide planning grants to do all of the following:(a)\xa0Conserve California’s most productive farmlands and ecologically important rangelands.(b)\xa0Advance California’s climate change goals through carbon sequestration and greenhouse gas emissions reductions resulting from the implementation of local plans.(c)\xa0Maintain local food supplies, local food producers, and agricultural economies through the protection of agricultural lands.SEC. 2.\xa0Section 10280.5 of the Public Resources Code is amended to read:10280.5.\xa0The following terms have the following meanings as used in this division, unless the context clearly requires otherwise:(a)\xa0“Authority” means an entity established by the state that requires its members, including, but not limited to, local government entities, to adopt a resolution stating their intent to participate.(b)\xa0“Department” means the Department of Conservation.(c)\xa0“Grant program” means the program established pursuant to Section 10280.(d)\xa0“Joint powers authority”\n\t\t\t\t\t\tmeans a joint powers authority established pursuant to Chapter 5 (commencing with Section 6500) of Division 7 of Title 1 of the Government Code that is formed in part to protect agricultural land.(e)\xa0“Local food producer” means a food producer or an agricultural producer that self-certifies that it satisfies either of the following conditions:(1)\xa0Is an agricultural producer that does all of the following:(A)\xa0Farms on 500 acres or less of farmland across all properties or grazes livestock on rangelands and has gross meat sales of less than two million dollars ($2,000,000) per year, as adjusted for annual changes to the California Consumer Price Index, as calculated by the Department of Finance.(B)\xa0Sells more than 75 percent of its products within the state.(C)\xa0Does at least one of the following:(i)\xa0Operates a farm stand that meets the requirements of Section 47050 of the Food and Agricultural Code or a field retail stand that meets the requirements of Section 47030 of the Food and Agricultural Code on its property that makes its agricultural products available to the community.(ii)\xa0Has a certified producer certificate and regularly sells in a California certified farmers’ market that meets the requirements of Section 47020 of the Food and Agricultural Code.(iii)\xa0Operates a subscription-based\n\t\t\t\t\t\tcommunity-supported agriculture program that meets the requirements of subdivision (a) of Section 47060 of the Food and Agricultural Code.(iv)\xa0Operates an agritourism business, including, but not limited to, by providing educational opportunities for schoolchildren on its property to learn about how food is grown and farm conservation practices. (v)\xa0Sells agricultural products directly to a restaurant or retail food establishment that is purchasing the food for sale directly to consumers at the restaurant or retail food establishment and the restaurant or retail food establishment meets the requirements of a food facility pursuant to Section 113789 of the Health and Safety Code.(vi)\xa0Provides food products to a\n\t\t\t\t\t\tfarm to community food hub that meets the requirements of Section 592 of the Food and Agricultural Code.(2)\xa0Processes, aggregates, distributes, or otherwise facilitates the sale of agricultural products from an agricultural producer that meets the requirements of paragraph (1) and 75 percent of those sales occur within the state.(f)\xa0“Local government entity” means any city, county, city and county, or district, including, but not limited to, park and open-space districts, resource conservation districts, and other special districts.(g)\xa0“Nonprofit organization” means any nonprofit public benefit corp ...

# %%
# storing bill info in df    
itxtdf = pd.DataFrame(infotxt1).transpose()

# rename columns
#itxtdf.rename(columns = {'0':'title', '1':'y_intro', '2': 'y_recent', '3':'text'}, inplace = True)
itxtdf.columns = ['bill_id', 'title', 'y_intro', 'y_recent', 'text']

# optional: create column to serve as new index ID?
#itxtdf.set_index('bill_id', inplace = True)

itxtdf
# Out:
#    bill_id                                              title y_intro  \
# 0  AB-1197  AB-1197 Agricultural Protection Planning Grant...    2023
#
#   y_recent                                               text
# 0     2023  The people of the State of California do enact...

# %%
# further processing bill text for NLP

# list of stopwords to exclude
swords = stopwords.words('english')

# stripping nonessential characters
textonly = re.sub(r"[^A-z\s]", "", billtxt)

# turning cleaned bill text into list of words
wordlist = [word for word in word_tokenize(textonly.lower()) 
                 if word not in swords]
print(len(wordlist))
wordlist
# Out:
# 641
# ['people',
#  'state',
#  'california',
#  'enact',
#  'followssection',
#  'section',
#  'public',
#  'resources',
#  'code',
#  'amended',
#  'read',
#  'agricultural',
#  'protection',
#  'planning',
#  'grant',
#  'program',
#  'hereby',
#  'established',
#  'within',
#  'department',
#  'conservation',
#  'provide',
#  'planning',
#  'grants',
#  'followinga',
#  'conserve',
#  'californias',
#  'productive',
#  'farmlands',
#  'ecologically',
#  'important',
#  'rangelandsb',
#  'advance',
#  'californias',
#  'climate',
#  'change',
#  'goals',
#  'carbon',
#  'sequestration',
#  'greenhouse',
#  'gas',
#  'emissions',
#  'reductions',
#  'resulting',
#  'implementation',
#  'local',
#  'plansc',
#  'maintain',
#  'local',
#  'food',
#  'supplies',
#  'local',
#  'food',
#  'producers',
#  'agricultural',
#  'economies',
#  'protection',
#  'agricultural',
#  'landssec',
#  'section',
#  'public',
#  'resources',
#  'code',
#  'amended',
#  'read',
#  'following',
#  'terms',
#  'following',
#  'meanings',
#  'used',
#  'division',
#  'unless',
#  'context',
#  'clearly',
#  'requires',
#  'otherwisea',
#  'authority',
#  'means',
#  'entity',
#  'established',
#  'state',
#  'requires',
#  'members',
#  'including',
#  'limited',
#  'local',
#  'government',
#  'entities',
#  'adopt',
#  'resolution',
#  'stating',
#  'intent',
#  'participateb',
#  'department',
#  'means',
#  'department',
#  'conservationc',
#  'grant',
#  'program',
#  'means',
#  'program',
#  'established',
#  'pursuant',
#  'section',
#  'joint',
#  'powers',
#  'authority',
#  'means',
#  'joint',
#  'powers',
#  'authority',
#  'established',
#  'pursuant',
#  'chapter',
#  'commencing',
#  'section',
#  'division',
#  'title',
#  'government',
#  'code',
#  'formed',
#  'part',
#  'protect',
#  'agricultural',
#  'lande',
#  'local',
#  'food',
#  'producer',
#  'means',
#  'food',
#  'producer',
#  'agricultural',
#  'producer',
#  'selfcertifies',
#  'satisfies',
#  'either',
#  'following',
#  'conditions',
#  'agricultural',
#  'producer',
#  'followinga',
#  'farms',
#  'acres',
#  'less',
#  'farmland',
#  'across',
#  'properties',
#  'grazes',
#  'livestock',
#  'rangelands',
#  'gross',
#  'meat',
#  'sales',
#  'less',
#  'two',
#  'million',
#  'dollars',
#  'per',
#  'year',
#  'adjusted',
#  'annual',
#  'changes',
#  'california',
#  'consumer',
#  'price',
#  'index',
#  'calculated',
#  'department',
#  'financeb',
#  'sells',
#  'percent',
#  'products',
#  'within',
#  'statec',
#  'least',
#  'one',
#  'followingi',
#  'operates',
#  'farm',
#  'stand',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'code',
#  'field',
#  'retail',
#  'stand',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'code',
#  'property',
#  'makes',
#  'agricultural',
#  'products',
#  'available',
#  'communityii',
#  'certified',
#  'producer',
#  'certificate',
#  'regularly',
#  'sells',
#  'california',
#  'certified',
#  'farmers',
#  'market',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'codeiii',
#  'operates',
#  'subscriptionbased',
#  'communitysupported',
#  'agriculture',
#  'program',
#  'meets',
#  'requirements',
#  'subdivision',
#  'section',
#  'food',
#  'agricultural',
#  'codeiv',
#  'operates',
#  'agritourism',
#  'business',
#  'including',
#  'limited',
#  'providing',
#  'educational',
#  'opportunities',
#  'schoolchildren',
#  'property',
#  'learn',
#  'food',
#  'grown',
#  'farm',
#  'conservation',
#  'practices',
#  'v',
#  'sells',
#  'agricultural',
#  'products',
#  'directly',
#  'restaurant',
#  'retail',
#  'food',
#  'establishment',
#  'purchasing',
#  'food',
#  'sale',
#  'directly',
#  'consumers',
#  'restaurant',
#  'retail',
#  'food',
#  'establishment',
#  'restaurant',
#  'retail',
#  'food',
#  'establishment',
#  'meets',
#  'requirements',
#  'food',
#  'facility',
#  'pursuant',
#  'section',
#  'health',
#  'safety',
#  'codevi',
#  'provides',
#  'food',
#  'products',
#  'farm',
#  'community',
#  'food',
#  'hub',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'code',
#  'processes',
#  'aggregates',
#  'distributes',
#  'otherwise',
#  'facilitates',
#  'sale',
#  'agricultural',
#  'products',
#  'agricultural',
#  'producer',
#  'meets',
#  'requirements',
#  'paragraph',
#  'percent',
#  'sales',
#  'occur',
#  'within',
#  'statef',
#  'local',
#  'government',
#  'entity',
#  'means',
#  'city',
#  'county',
#  'city',
#  'county',
#  'district',
#  'including',
#  'limited',
#  'park',
#  'openspace',
#  'districts',
#  'resource',
#  'conservation',
#  'districts',
#  'special',
#  'districtsg',
#  'nonprofit',
#  'organization',
#  'means',
#  'nonprofit',
#  'public',
#  'benefit',
#  'corporation',
#  'among',
#  'purposes',
#  'conservation',
#  'agricultural',
#  'lands',
#  'holds',
#  'tax',
#  'exemption',
#  'defined',
#  'section',
#  'c',
#  'internal',
#  'revenue',
#  'code',
#  'qualifies',
#  'organization',
#  'section',
#  'baiv',
#  'h',
#  'internal',
#  'revenue',
#  'codesec',
#  'section',
#  'public',
#  'resources',
#  'code',
#  'amended',
#  'read',
#  'grant',
#  'program',
#  'local',
#  'government',
#  'entity',
#  'nonprofit',
#  'organization',
#  'authority',
#  'joint',
#  'powers',
#  'authority',
#  'may',
#  'apply',
#  'department',
#  'planning',
#  'grant',
#  'used',
#  'protection',
#  'agricultural',
#  'lands',
#  'grazing',
#  'lands',
#  'including',
#  'oak',
#  'woodlands',
#  'grasslands',
#  'addition',
#  'requirements',
#  'established',
#  'department',
#  'eligible',
#  'grant',
#  'grant',
#  'program',
#  'applicant',
#  'shall',
#  'following',
#  'identify',
#  'map',
#  'utilizing',
#  'designations',
#  'farmlands',
#  'mapping',
#  'monitoring',
#  'program',
#  'department',
#  'pursuant',
#  'section',
#  'government',
#  'code',
#  'existing',
#  'potential',
#  'agricultural',
#  'lands',
#  'jurisdiction',
#  'specify',
#  'existing',
#  'goals',
#  'objectives',
#  'policies',
#  'programs',
#  'support',
#  'longterm',
#  'protection',
#  'agricultural',
#  'land',
#  'specify',
#  'proposed',
#  'changes',
#  'existing',
#  'goals',
#  'objectives',
#  'policies',
#  'programs',
#  'support',
#  'longterm',
#  'protection',
#  'agricultural',
#  'land',
#  'specify',
#  'planning',
#  'grant',
#  'would',
#  'used',
#  'improve',
#  'longterm',
#  'protection',
#  'agricultural',
#  'land',
#  'within',
#  'jurisdictionb',
#  'grant',
#  'program',
#  'addition',
#  'subdivision',
#  'nonprofit',
#  'organization',
#  'may',
#  'apply',
#  'department',
#  'planning',
#  'grant',
#  'assist',
#  'identifying',
#  'mapping',
#  'local',
#  'food',
#  'producers',
#  'department',
#  'receives',
#  'appropriation',
#  'legislature',
#  'purposesc',
#  'grant',
#  'awarded',
#  'department',
#  'grant',
#  'program',
#  'shall',
#  'exceed',
#  'one',
#  'million',
#  'dollars',
#  'five',
#  'hundred',
#  'thousand',
#  'dollars',
#  'applicant',
#  'one',
#  'million',
#  'five',
#  'hundred',
#  'thousand',
#  'dollars',
#  'seven',
#  'hundred',
#  'fifty',
#  'thousand',
#  'dollars',
#  'department',
#  'determines',
#  'grant',
#  'application',
#  'collaborative',
#  'planning',
#  'activities',
#  'proposed',
#  'include',
#  'two',
#  'adjacent',
#  'counties',
#  'cities',
#  'city',
#  'countyd',
#  'granting',
#  'funds',
#  'pursuant',
#  'division',
#  'department',
#  'shall',
#  'give',
#  'priority',
#  'proposals',
#  'include',
#  'matching',
#  'funds',
#  'local',
#  'sourcese',
#  'grant',
#  'proposal',
#  'park',
#  'openspace',
#  'district',
#  'resource',
#  'conservation',
#  'district',
#  'special',
#  'district',
#  'authority',
#  'joint',
#  'powers',
#  'authority',
#  'shall',
#  'approved',
#  'resolution',
#  'city',
#  'county',
#  'city',
#  'county',
#  'multiple',
#  'cities',
#  'counties',
#  'whose',
#  'jurisdiction',
#  'proposal',
#  'intended',
#  'benefit',
#  'city',
#  'county',
#  'city',
#  'county',
#  'shall',
#  'provide',
#  'evidence',
#  'willing',
#  'implement',
#  'planning',
#  'process',
#  'funded',
#  'grantf',
#  'purposes',
#  'grant',
#  'may',
#  'made',
#  'pursuant',
#  'division',
#  'agricultural',
#  'protection',
#  'may',
#  'include',
#  'need',
#  'limited',
#  'following',
#  'update',
#  'general',
#  'plan',
#  'city',
#  'county',
#  'city',
#  'county',
#  'improve',
#  'protection',
#  'agricultural',
#  'land',
#  'zoning',
#  'ordinance',
#  'designed',
#  'improve',
#  'protection',
#  'agricultural',
#  'land',
#  'develop',
#  'multicounty',
#  'strategies',
#  'protect',
#  'agricultural',
#  'land',
#  'develop',
#  'citycounty',
#  'agreements',
#  'protect',
#  'agricultural',
#  'land',
#  'develop',
#  'strategies',
#  'implement',
#  'existing',
#  'general',
#  'plan',
#  'provisions',
#  'citycounty',
#  'agreements',
#  'multicounty',
#  'agreements',
#  'protect',
#  'agricultural',
#  'land',
#  'including',
#  'technical',
#  'assistance',
#  'develop',
#  'publicprivate',
#  'partnerships',
#  'longterm',
#  'protection',
#  'stewardship',
#  'agricultural',
#  'lands',
#  'local',
#  'food',
#  'producers']

# %% [markdown]
# ## Putting All the Pieces Together
#
# This code aims to:
#
# 1. Extract the individual *bill_id* for each bill in the search results for a query of "food and agriculture" bills in California for the most recent legislative session;
# 2. extract the *doc_id* for the most recently amended version of each bill;
# 3. extract (A) the bill title and (B) the bill text for each document;
# 4. and finally, clean the bill text (prepare into either (A) a relatively clean string text block or (B) a cleaned wordlist).

# %%
## SCRAPE SEARCH RESULTS for bill_ids

# scrape LegiScan search results for CA bills RE: food and ag for current year
requeststring = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=2&query=food%20and%20agriculture"
# request: CA, food and ag, results for recent years
requeststring1 = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=3&query=food%20and%20agriculture"
# request: CA, food and ag, results for all available years
requeststring2 = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=1&query=food%20and%20agriculture"

# pull request: ge\tting results as JSON object
r = requests.get(requeststring1)
# turning JSON object into a dict
dict1 = json.loads(r.text)

# creating subset dict with only keys of interest
list1 = dict1['searchresult']['results']
# generating list of bill_ids
bills = [value['bill_id'] for value in list1]

# each bill in bills is stored as an integer; convert to list of str
bills1 = [str(bill) for bill in bills]

#inspect/show results
print(len(bills1))
bills1[:5]
# Out:
# 565
# ['1453447', '1693920', '1456707', '1388510', '1711942']

# %%
# TEST
docs = []
docs1 = {}

for bill in bills1:
    
    # extract bill info
    bill_id = bill
    requestbill = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id="+bill_id
    b = requests.get(requestbill)
    binfo = json.loads(b.text)
    
    # FIND doc_id for most recent bill version
    docs1[bill] = binfo.keys()
    
docs1
# Out:
# {'1453447': dict_keys(['status', 'bill']),
#  '1693920': dict_keys(['status', 'bill']),
#  '1456707': dict_keys(['status', 'bill']),
#  '1388510': dict_keys(['status', 'bill']),
#  '1711942': dict_keys(['status', 'bill']),
#  '1454994': dict_keys(['status', 'bill']),
#  '1594832': dict_keys(['status', 'bill']),
#  '1614129': dict_keys(['status', 'bill']),
#  '1592497': dict_keys(['status', 'bill']),
#  '1453388': dict_keys(['status', 'bill']),
#  '1593665': dict_keys(['status', 'bill']),
#  '1702780': dict_keys(['status', 'bill']),
#  '1458834': dict_keys(['status', 'bill']),
#  '1433188': dict_keys(['status', 'bill']),
#  '1451034': dict_keys(['status', 'bill']),
#  '1578060': dict_keys(['status', 'bill']),
#  '1438442': dict_keys(['status', 'bill']),
#  '1588122': dict_keys(['status', 'bill']),
#  '1417874': dict_keys(['status', 'bill']),
#  '1398281': dict_keys(['status', 'bill']),
#  '1712167': dict_keys(['status', 'bill']),
#  '1581321': dict_keys(['status', 'bill']),
#  '1707639': dict_keys(['status', 'bill']),
#  '1592396': dict_keys(['status', 'bill']),
#  '1456801': dict_keys(['status', 'bill']),
#  '1593664': dict_keys(['status', 'bill']),
#  '1453516': dict_keys(['status', 'bill']),
#  '1671132': dict_keys(['status', 'bill']),
#  '1454889': dict_keys(['status', 'bill']),
#  '1592492': dict_keys(['status', 'bill']),
#  '1453379': dict_keys(['status', 'bill']),
#  '1459192': dict_keys(['status', 'bill']),
#  '1712103': dict_keys(['status', 'bill']),
#  '1447168': dict_keys(['status', 'bill']),
#  '1441536': dict_keys(['status', 'bill']),
#  '1429103': dict_keys(['status', 'bill']),
#  '1458841': dict_keys(['status', 'bill']),
#  '1588179': dict_keys(['status', 'bill']),
#  '1456723': dict_keys(['status', 'bill']),
#  '1471518': dict_keys(['status', 'bill']),
#  '1385467': dict_keys(['status', 'bill']),
#  '1592403': dict_keys(['status', 'bill']),
#  '1701021': dict_keys(['status', 'bill']),
#  '1398228': dict_keys(['status', 'bill']),
#  '1594480': dict_keys(['status', 'bill']),
#  '1659520': dict_keys(['status', 'bill']),
#  '1709841': dict_keys(['status', 'bill']),
#  '1605378': dict_keys(['status', 'bill']),
#  '1714546': dict_keys(['status', 'bill']),
#  '1702725': dict_keys(['status', 'bill']),
#  '1398158': dict_keys(['status', 'bill']),
#  '1398220': dict_keys(['status', 'bill']),
#  '1707512': dict_keys(['status', 'bill']),
#  '1411987': dict_keys(['status', 'bill']),
#  '1649742': dict_keys(['status', 'bill']),
#  '1714501': dict_keys(['status', 'bill']),
#  '1447180': dict_keys(['status', 'bill']),
#  '1738922': dict_keys(['status', 'bill']),
#  '1593707': dict_keys(['status', 'bill']),
#  '1398241': dict_keys(['status', 'bill']),
#  '1394329': dict_keys(['status', 'bill']),
#  '1472781': dict_keys(['status', 'bill']),
#  '1458850': dict_keys(['status', 'bill']),
#  '1714731': dict_keys(['status', 'bill']),
#  '1456899': dict_keys(['status', 'bill']),
#  '1447141': dict_keys(['status', 'bill']),
#  '1693914': dict_keys(['status', 'bill']),
#  '1712067': dict_keys(['status', 'bill']),
#  '1585831': dict_keys(['status', 'bill']),
#  '1714651': dict_keys(['status', 'bill']),
#  '1398262': dict_keys(['status', 'bill']),
#  '1697043': dict_keys(['status', 'bill']),
#  '1456784': dict_keys(['status', 'bill']),
#  '1434863': dict_keys(['status', 'bill']),
#  '1398167': dict_keys(['status', 'bill']),
#  '1458914': dict_keys(['status', 'bill']),
#  '1454993': dict_keys(['status', 'bill']),
#  '1714813': dict_keys(['status', 'bill']),
#  '1385447': dict_keys(['status', 'bill']),
#  '1717506': dict_keys(['status', 'bill']),
#  '1700993': dict_keys(['status', 'bill']),
#  '1585846': dict_keys(['status', 'bill']),
#  '1592516': dict_keys(['status', 'bill']),
#  '1697060': dict_keys(['status', 'bill']),
#  '1729722': dict_keys(['status', 'bill']),
#  '1712107': dict_keys(['status', 'bill']),
#  '1709716': dict_keys(['status', 'bill']),
#  '1398271': dict_keys(['status', 'bill']),
#  '1689320': dict_keys(['status', 'bill']),
#  '1594675': dict_keys(['status', 'bill']),
#  '1693918': dict_keys(['status', 'bill']),
#  '1456942': dict_keys(['status', 'bill']),
#  '1702715': dict_keys(['status', 'bill']),
#  '1693916': dict_keys(['status', 'bill']),
#  '1711952': dict_keys(['status', 'bill']),
#  '1693952': dict_keys(['status', 'bill']),
#  '1474176': dict_keys(['status', 'bill']),
#  '1585842': dict_keys(['status', 'bill']),
#  '1709742': dict_keys(['status', 'bill']),
#  '1714485': dict_keys(['status', 'bill']),
#  '1434856': dict_keys(['status', 'bill']),
#  '1604715': dict_keys(['status', 'bill']),
#  '1450056': dict_keys(['status', 'bill']),
#  '1570768': dict_keys(['status', 'bill']),
#  '1693932': dict_keys(['status', 'bill']),
#  '1456953': dict_keys(['status', 'bill']),
#  '1581302': dict_keys(['status', 'bill']),
#  '1593554': dict_keys(['status', 'bill']),
#  '1478617': dict_keys(['status', 'bill']),
#  '1417854': dict_keys(['status', 'bill']),
#  '1407540': dict_keys(['status', 'bill']),
#  '1422155': dict_keys(['status', 'bill']),
#  '1585818': dict_keys(['status', 'bill']),
#  '1594554': dict_keys(['status', 'bill']),
#  '1459051': dict_keys(['status', 'bill']),
#  '1454867': dict_keys(['status', 'bill']),
#  '1595005': dict_keys(['status', 'bill']),
#  '1424575': dict_keys(['status', 'bill']),
#  '1593680': dict_keys(['status', 'bill']),
#  '1584607': dict_keys(['status', 'bill']),
#  '1693917': dict_keys(['status', 'bill']),
#  '1707654': dict_keys(['status', 'bill']),
#  '1594815': dict_keys(['status', 'bill']),
#  '1592405': dict_keys(['status', 'bill']),
#  '1593523': dict_keys(['status', 'bill']),
#  '1482845': dict_keys(['status', 'bill']),
#  '1709744': dict_keys(['status', 'bill']),
#  '1450052': dict_keys(['status', 'bill']),
#  '1424571': dict_keys(['status', 'bill']),
#  '1711977': dict_keys(['status', 'bill']),
#  '1602323': dict_keys(['status', 'bill']),
#  '1616338': dict_keys(['status', 'bill']),
#  '1454942': dict_keys(['status', 'bill']),
#  '1454843': dict_keys(['status', 'bill']),
#  '1593611': dict_keys(['status', 'bill']),
#  '1594718': dict_keys(['status', 'bill']),
#  '1714818': dict_keys(['status', 'bill']),
#  '1521964': dict_keys(['status', 'bill']),
#  '1594902': dict_keys(['status', 'bill']),
#  '1564469': dict_keys(['status', 'bill']),
#  '1709872': dict_keys(['status', 'bill']),
#  '1521873': dict_keys(['status', 'bill']),
#  '1388506': dict_keys(['status', 'bill']),
#  '1429105': dict_keys(['status', 'bill']),
#  '1594615': dict_keys(['status', 'bill']),
#  '1453527': dict_keys(['status', 'bill']),
#  '1592779': dict_keys(['status', 'alert']),
#  '1714521': dict_keys(['status', 'bill']),
#  '1667855': dict_keys(['status', 'bill']),
#  '1454832': dict_keys(['status', 'bill']),
#  '1594512': dict_keys(['status', 'bill']),
#  '1458842': dict_keys(['status', 'bill']),
#  '1702767': dict_keys(['status', 'bill']),
#  '1441546': dict_keys(['status', 'bill']),
#  '1551314': dict_keys(['status', 'bill']),
#  '1659519': dict_keys(['status', 'bill']),
#  '1594595': dict_keys(['status', 'bill']),
#  '1567065': dict_keys(['status', 'bill']),
#  '1731372': dict_keys(['status', 'bill']),
#  '1712049': dict_keys(['status', 'bill']),
#  '1711904': dict_keys(['status', 'bill']),
#  '1594677': dict_keys(['status', 'bill']),
#  '1724789': dict_keys(['status', 'bill']),
#  '1691346': dict_keys(['status', 'bill']),
#  '1714317': dict_keys(['status', 'bill']),
#  '1453384': dict_keys(['status', 'bill']),
#  '1712204': dict_keys(['status', 'bill']),
#  '1398177': dict_keys(['status', 'bill']),
#  '1398276': dict_keys(['status', 'bill']),
#  '1649739': dict_keys(['status', 'bill']),
#  '1456732': dict_keys(['status', 'bill']),
#  '1388071': dict_keys(['status', 'bill']),
#  '1422169': dict_keys(['status', 'bill']),
#  '1398240': dict_keys(['status', 'bill']),
#  '1398165': dict_keys(['status', 'bill']),
#  '1649612': dict_keys(['status', 'bill']),
#  '1433151': dict_keys(['status', 'bill']),
#  '1701039': dict_keys(['status', 'bill']),
#  '1456842': dict_keys(['status', 'bill']),
#  '1459086': dict_keys(['status', 'bill']),
#  '1712180': dict_keys(['status', 'bill']),
#  '1422147': dict_keys(['status', 'bill']),
#  '1447125': dict_keys(['status', 'bill']),
#  '1594937': dict_keys(['status', 'bill']),
#  '1707500': dict_keys(['status', 'bill']),
#  '1398291': dict_keys(['status', 'bill']),
#  '1385404': dict_keys(['status', 'bill']),
#  '1459210': dict_keys(['status', 'bill']),
#  '1594456': dict_keys(['status', 'bill']),
#  '1398226': dict_keys(['status', 'bill']),
#  '1458774': dict_keys(['status', 'bill']),
#  '1714491': dict_keys(['status', 'bill']),
#  '1616339': dict_keys(['status', 'bill']),
#  '1709864': dict_keys(['status', 'bill']),
#  '1594986': dict_keys(['status', 'bill']),
#  '1649634': dict_keys(['status', 'bill']),
#  '1456769': dict_keys(['status', 'bill']),
#  '1649639': dict_keys(['status', 'bill']),
#  '1592715': dict_keys(['status', 'alert']),
#  '1459177': dict_keys(['status', 'bill']),
#  '1398269': dict_keys(['status', 'bill']),
#  '1398197': dict_keys(['status', 'bill']),
#  '1712004': dict_keys(['status', 'bill']),
#  '1398172': dict_keys(['status', 'bill']),
#  '1398187': dict_keys(['status', 'bill']),
#  '1454844': dict_keys(['status', 'bill']),
#  '1385449': dict_keys(['status', 'bill']),
#  '1588169': dict_keys(['status', 'bill']),
#  '1714422': dict_keys(['status', 'bill']),
#  '1398301': dict_keys(['status', 'bill']),
#  '1590298': dict_keys(['status', 'bill']),
#  '1590444': dict_keys(['status', 'bill']),
#  '1702772': dict_keys(['status', 'bill']),
#  '1667833': dict_keys(['status', 'bill']),
#  '1453363': dict_keys(['status', 'bill']),
#  '1441549': dict_keys(['status', 'bill']),
#  '1588128': dict_keys(['status', 'bill']),
#  '1385433': dict_keys(['status', 'bill']),
#  '1592472': dict_keys(['status', 'bill']),
#  '1636426': dict_keys(['status', 'bill']),
#  '1398249': dict_keys(['status', 'bill']),
#  '1441541': dict_keys(['status', 'bill']),
#  '1582925': dict_keys(['status', 'bill']),
#  '1714407': dict_keys(['status', 'bill']),
#  '1588097': dict_keys(['status', 'bill']),
#  '1385430': dict_keys(['status', 'bill']),
#  '1691357': dict_keys(['status', 'bill']),
#  '1772423': dict_keys(['status', 'bill']),
#  '1667860': dict_keys(['status', 'bill']),
#  '1456710': dict_keys(['status', 'bill']),
#  '1593806': dict_keys(['status', 'bill']),
#  '1454921': dict_keys(['status', 'bill']),
#  '1709708': dict_keys(['status', 'bill']),
#  '1450112': dict_keys(['status', 'bill']),
#  '1459270': dict_keys(['status', 'bill']),
#  '1398247': dict_keys(['status', 'bill']),
#  '1385409': dict_keys(['status', 'bill']),
#  '1438433': dict_keys(['status', 'bill']),
#  '1385425': dict_keys(['status', 'bill']),
#  '1714547': dict_keys(['status', 'bill']),
#  '1385436': dict_keys(['status', 'bill']),
#  '1398196': dict_keys(['status', 'bill']),
#  '1417857': dict_keys(['status', 'bill']),
#  '1593839': dict_keys(['status', 'bill']),
#  '1594487': dict_keys(['status', 'bill']),
#  '1459036': dict_keys(['status', 'bill']),
#  '1441570': dict_keys(['status', 'bill']),
#  '1398178': dict_keys(['status', 'bill']),
#  '1714633': dict_keys(['status', 'bill']),
#  '1457004': dict_keys(['status', 'bill']),
#  '1426683': dict_keys(['status', 'bill']),
#  '1398231': dict_keys(['status', 'bill']),
#  '1581314': dict_keys(['status', 'bill']),
#  '1559216': dict_keys(['status', 'bill']),
#  '1705874': dict_keys(['status', 'bill']),
#  '1714551': dict_keys(['status', 'bill']),
#  '1458962': dict_keys(['status', 'bill']),
#  '1702786': dict_keys(['status', 'bill']),
#  '1592784': dict_keys(['status', 'bill']),
#  '1594741': dict_keys(['status', 'bill']),
#  '1459297': dict_keys(['status', 'bill']),
#  '1759484': dict_keys(['status', 'bill']),
#  '1458837': dict_keys(['status', 'bill']),
#  '1398233': dict_keys(['status', 'bill']),
#  '1398300': dict_keys(['status', 'bill']),
#  '1590264': dict_keys(['status', 'bill']),
#  '1385557': dict_keys(['status', 'bill']),
#  '1545618': dict_keys(['status', 'bill']),
#  '1705803': dict_keys(['status', 'bill']),
#  '1398145': dict_keys(['status', 'bill']),
#  '1594476': dict_keys(['status', 'bill']),
#  '1579404': dict_keys(['status', 'bill']),
#  '1458971': dict_keys(['status', 'bill']),
#  '1590411': dict_keys(['status', 'bill']),
#  '1398174': dict_keys(['status', 'bill']),
#  '1714533': dict_keys(['status', 'bill']),
#  '1594437': dict_keys(['status', 'bill']),
#  '1698897': dict_keys(['status', 'bill']),
#  '1649614': dict_keys(['status', 'bill']),
#  '1726105': dict_keys(['status', 'bill']),
#  '1398275': dict_keys(['status', 'bill']),
#  '1551318': dict_keys(['status', 'bill']),
#  '1551330': dict_keys(['status', 'bill']),
#  '1594904': dict_keys(['status', 'bill']),
#  '1398236': dict_keys(['status', 'bill']),
#  '1592680': dict_keys(['status', 'bill']),
#  '1593821': dict_keys(['status', 'bill']),
#  '1398282': dict_keys(['status', 'bill']),
#  '1385403': dict_keys(['status', 'bill']),
#  '1451072': dict_keys(['status', 'bill']),
#  '1667835': dict_keys(['status', 'bill']),
#  '1590352': dict_keys(['status', 'bill']),
#  '1592579': dict_keys(['status', 'bill']),
#  '1450073': dict_keys(['status', 'bill']),
#  '1398171': dict_keys(['status', 'bill']),
#  '1588168': dict_keys(['status', 'bill']),
#  '1458874': dict_keys(['status', 'bill']),
#  '1594814': dict_keys(['status', 'bill']),
#  '1521874': dict_keys(['status', 'bill']),
#  '1454852': dict_keys(['status', 'bill']),
#  '1693927': dict_keys(['status', 'bill']),
#  '1714704': dict_keys(['status', 'bill']),
#  '1593819': dict_keys(['status', 'bill']),
#  '1667828': dict_keys(['status', 'bill']),
#  '1456836': dict_keys(['status', 'bill']),
#  '1575742': dict_keys(['status', 'bill']),
#  '1707538': dict_keys(['status', 'bill']),
#  '1667847': dict_keys(['status', 'bill']),
#  '1584633': dict_keys(['status', 'bill']),
#  '1593686': dict_keys(['status', 'bill']),
#  '1712034': dict_keys(['status', 'bill']),
#  '1705903': dict_keys(['status', 'bill']),
#  '1458946': dict_keys(['status', 'bill']),
#  '1438467': dict_keys(['status', 'bill']),
#  '1454890': dict_keys(['status', 'bill']),
#  '1398181': dict_keys(['status', 'bill']),
#  '1714773': dict_keys(['status', 'bill']),
#  '1385434': dict_keys(['status', 'bill']),
#  '1459037': dict_keys(['status', 'bill']),
#  '1702745': dict_keys(['status', 'bill']),
#  '1667834': dict_keys(['status', 'bill']),
#  '1649738': dict_keys(['status', 'bill']),
#  '1649626': dict_keys(['status', 'bill']),
#  '1398198': dict_keys(['status', 'bill']),
#  '1458863': dict_keys(['status', 'bill']),
#  '1652083': dict_keys(['status', 'bill']),
#  '1652088': dict_keys(['status', 'bill']),
#  '1731369': dict_keys(['status', 'bill']),
#  '1593778': dict_keys(['status', 'bill']),
#  '1593649': dict_keys(['status', 'bill']),
#  '1590380': dict_keys(['status', 'bill']),
#  '1707490': dict_keys(['status', 'bill']),
#  '1714634': dict_keys(['status', 'bill']),
#  '1459132': dict_keys(['status', 'bill']),
#  '1649613': dict_keys(['status', 'bill']),
#  '1453432': dict_keys(['status', 'bill']),
#  '1593826': dict_keys(['status', 'bill']),
#  '1593557': dict_keys(['status', 'bill']),
#  '1714412': dict_keys(['status', 'bill']),
#  '1705898': dict_keys(['status', 'bill']),
#  '1714709': dict_keys(['status', 'bill']),
#  '1714562': dict_keys(['status', 'bill']),
#  '1714444': dict_keys(['status', 'bill']),
#  '1388319': dict_keys(['status', 'bill']),
#  '1459059': dict_keys(['status', 'bill']),
#  '1691375': dict_keys(['status', 'bill']),
#  '1455006': dict_keys(['status', 'bill']),
#  '1444443': dict_keys(['status', 'bill']),
#  '1592723': dict_keys(['status', 'bill']),
#  '1458961': dict_keys(['status', 'bill']),
#  '1398195': dict_keys(['status', 'bill']),
#  '1398285': dict_keys(['status', 'bill']),
#  '1649615': dict_keys(['status', 'bill']),
#  '1453487': dict_keys(['status', 'bill']),
#  '1707695': dict_keys(['status', 'bill']),
#  '1398250': dict_keys(['status', 'bill']),
#  '1590364': dict_keys(['status', 'bill']),
#  '1398299': dict_keys(['status', 'bill']),
#  '1697071': dict_keys(['status', 'bill']),
#  '1707543': dict_keys(['status', 'bill']),
#  '1644455': dict_keys(['status', 'bill']),
#  '1385513': dict_keys(['status', 'bill']),
#  '1398302': dict_keys(['status', 'bill']),
#  '1411974': dict_keys(['status', 'bill']),
#  '1456895': dict_keys(['status', 'bill']),
#  '1385573': dict_keys(['status', 'bill']),
#  '1398164': dict_keys(['status', 'bill']),
#  '1451043': dict_keys(['status', 'bill']),
#  '1453475': dict_keys(['status', 'bill']),
#  '1459106': dict_keys(['status', 'bill']),
#  '1456998': dict_keys(['status', 'bill']),
#  '1592818': dict_keys(['status', 'bill']),
#  '1594789': dict_keys(['status', 'bill']),
#  '1705902': dict_keys(['status', 'bill']),
#  '1709774': dict_keys(['status', 'bill']),
#  '1714532': dict_keys(['status', 'bill']),
#  '1394328': dict_keys(['status', 'bill']),
#  '1459112': dict_keys(['status', 'bill']),
#  '1702700': dict_keys(['status', 'bill']),
#  '1627793': dict_keys(['status', 'bill']),
#  '1581326': dict_keys(['status', 'bill']),
#  '1454939': dict_keys(['status', 'bill']),
#  '1398149': dict_keys(['status', 'bill']),
#  '1453371': dict_keys(['status', 'bill']),
#  '1588092': dict_keys(['status', 'bill']),
#  '1438466': dict_keys(['status', 'bill']),
#  '1450061': dict_keys(['status', 'bill']),
#  '1398186': dict_keys(['status', 'bill']),
#  '1398146': dict_keys(['status', 'bill']),
#  '1584635': dict_keys(['status', 'bill']),
#  '1441537': dict_keys(['status', 'bill']),
#  '1667836': dict_keys(['status', 'bill']),
#  '1594603': dict_keys(['status', 'bill']),
#  '1588130': dict_keys(['status', 'bill']),
#  '1560018': dict_keys(['status', 'bill']),
#  '1592501': dict_keys(['status', 'bill']),
#  '1609637': dict_keys(['status', 'bill']),
#  '1667857': dict_keys(['status', 'bill']),
#  '1714319': dict_keys(['status', 'bill']),
#  '1755204': dict_keys(['status', 'bill']),
#  '1771715': dict_keys(['status', 'bill']),
#  '1592796': dict_keys(['status', 'bill']),
#  '1731371': dict_keys(['status', 'bill']),
#  '1433158': dict_keys(['status', 'bill']),
#  '1417853': dict_keys(['status', 'bill']),
#  '1592805': dict_keys(['status', 'bill']),
#  '1691348': dict_keys(['status', 'bill']),
#  '1398253': dict_keys(['status', 'bill']),
#  '1714767': dict_keys(['status', 'bill']),
#  '1702748': dict_keys(['status', 'bill']),
#  '1698914': dict_keys(['status', 'bill']),
#  '1705843': dict_keys(['status', 'bill']),
#  '1709927': dict_keys(['status', 'bill']),
#  '1456980': dict_keys(['status', 'bill']),
#  '1593791': dict_keys(['status', 'bill']),
#  '1594941': dict_keys(['status', 'bill']),
#  '1593543': dict_keys(['status', 'bill']),
#  '1667953': dict_keys(['status', 'bill']),
#  '1456765': dict_keys(['status', 'bill']),
#  '1456969': dict_keys(['status', 'bill']),
#  '1593593': dict_keys(['status', 'bill']),
#  '1456837': dict_keys(['status', 'bill']),
#  '1398212': dict_keys(['status', 'bill']),
#  '1649636': dict_keys(['status', 'bill']),
#  '1594596': dict_keys(['status', 'bill']),
#  '1705988': dict_keys(['status', 'bill']),
#  '1478615': dict_keys(['status', 'bill']),
#  '1385560': dict_keys(['status', 'bill']),
#  '1608382': dict_keys(['status', 'bill']),
#  '1609634': dict_keys(['status', 'bill']),
#  '1459224': dict_keys(['status', 'bill']),
#  '1398192': dict_keys(['status', 'bill']),
#  '1594558': dict_keys(['status', 'bill']),
#  '1707631': dict_keys(['status', 'bill']),
#  '1594852': dict_keys(['status', 'bill']),
#  '1582915': dict_keys(['status', 'bill']),
#  '1441562': dict_keys(['status', 'bill']),
#  '1500884': dict_keys(['status', 'bill']),
#  '1385571': dict_keys(['status', 'bill']),
#  '1438472': dict_keys(['status', 'bill']),
#  '1608924': dict_keys(['status', 'bill']),
#  '1615805': dict_keys(['status', 'bill']),
#  '1593639': dict_keys(['status', 'bill']),
#  '1594628': dict_keys(['status', 'bill']),
#  '1398183': dict_keys(['status', 'bill']),
#  '1714449': dict_keys(['status', 'bill']),
#  '1705827': dict_keys(['status', 'bill']),
#  '1712188': dict_keys(['status', 'bill']),
#  '1686434': dict_keys(['status', 'bill']),
#  '1714621': dict_keys(['status', 'bill']),
#  '1705905': dict_keys(['status', 'bill']),
#  '1714683': dict_keys(['status', 'bill']),
#  '1712152': dict_keys(['status', 'bill']),
#  '1707647': dict_keys(['status', 'bill']),
#  '1709738': dict_keys(['status', 'bill']),
#  '1398173': dict_keys(['status', 'bill']),
#  '1398152': dict_keys(['status', 'bill']),
#  '1508535': dict_keys(['status', 'bill']),
#  '1586981': dict_keys(['status', 'bill']),
#  '1667861': dict_keys(['status', 'bill']),
#  '1398184': dict_keys(['status', 'bill']),
#  '1637884': dict_keys(['status', 'bill']),
#  '1456794': dict_keys(['status', 'bill']),
#  '1458791': dict_keys(['status', 'bill']),
#  '1459062': dict_keys(['status', 'bill']),
#  '1456843': dict_keys(['status', 'bill']),
#  '1594865': dict_keys(['status', 'bill']),
#  '1709848': dict_keys(['status', 'bill']),
#  '1705952': dict_keys(['status', 'bill']),
#  '1592685': dict_keys(['status', 'bill']),
#  '1772090': dict_keys(['status', 'bill']),
#  '1590291': dict_keys(['status', 'bill']),
#  '1649640': dict_keys(['status', 'bill']),
#  '1714508': dict_keys(['status', 'bill']),
#  '1657752': dict_keys(['status', 'bill']),
#  '1567067': dict_keys(['status', 'bill']),
#  '1705844': dict_keys(['status', 'bill']),
#  '1398288': dict_keys(['status', 'bill']),
#  '1398259': dict_keys(['status', 'bill']),
#  '1593506': dict_keys(['status', 'bill']),
#  '1398316': dict_keys(['status', 'bill']),
#  '1398256': dict_keys(['status', 'bill']),
#  '1697014': dict_keys(['status', 'bill']),
#  '1398296': dict_keys(['status', 'bill']),
#  '1581319': dict_keys(['status', 'bill']),
#  '1492081': dict_keys(['status', 'bill']),
#  '1592770': dict_keys(['status', 'alert']),
#  '1707671': dict_keys(['status', 'bill']),
#  '1709925': dict_keys(['status', 'bill']),
#  '1759810': dict_keys(['status', 'bill']),
#  '1398310': dict_keys(['status', 'bill']),
#  '1441568': dict_keys(['status', 'bill']),
#  '1454936': dict_keys(['status', 'bill']),
#  '1385586': dict_keys(['status', 'bill']),
#  '1649628': dict_keys(['status', 'bill']),
#  '1714453': dict_keys(['status', 'bill']),
#  '1667853': dict_keys(['status', 'bill']),
#  '1598796': dict_keys(['status', 'bill']),
#  '1398148': dict_keys(['status', 'bill']),
#  '1649632': dict_keys(['status', 'bill']),
#  '1607955': dict_keys(['status', 'bill']),
#  '1398147': dict_keys(['status', 'bill']),
#  '1398308': dict_keys(['status', 'bill']),
#  '1434871': dict_keys(['status', 'bill']),
#  '1588142': dict_keys(['status', 'bill']),
#  '1689325': dict_keys(['status', 'bill']),
#  '1711982': dict_keys(['status', 'bill']),
#  '1702834': dict_keys(['status', 'bill']),
#  '1698948': dict_keys(['status', 'bill']),
#  '1592800': dict_keys(['status', 'bill']),
#  '1749145': dict_keys(['status', 'bill']),
#  '1398206': dict_keys(['status', 'bill']),
#  '1398216': dict_keys(['status', 'bill']),
#  '1398204': dict_keys(['status', 'bill']),
#  '1398251': dict_keys(['status', 'bill']),
#  '1398252': dict_keys(['status', 'bill']),
#  '1398279': dict_keys(['status', 'bill']),
#  '1593815': dict_keys(['status', 'bill']),
#  '1586986': dict_keys(['status', 'bill']),
#  '1593669': dict_keys(['status', 'bill']),
#  '1385399': dict_keys(['status', 'bill']),
#  '1667849': dict_keys(['status', 'bill']),
#  '1454876': dict_keys(['status', 'bill']),
#  '1450058': dict_keys(['status', 'bill']),
#  '1453445': dict_keys(['status', 'bill']),
#  '1453469': dict_keys(['status', 'bill']),
#  '1455003': dict_keys(['status', 'bill']),
#  '1456703': dict_keys(['status', 'bill']),
#  '1459076': dict_keys(['status', 'bill']),
#  '1459227': dict_keys(['status', 'bill']),
#  '1459247': dict_keys(['status', 'bill']),
#  '1592712': dict_keys(['status', 'alert']),
#  '1594987': dict_keys(['status', 'bill']),
#  '1594571': dict_keys(['status', 'bill']),
#  '1590283': dict_keys(['status', 'bill']),
#  '1592812': dict_keys(['status', 'bill']),
#  '1706006': dict_keys(['status', 'bill']),
#  '1709901': dict_keys(['status', 'bill']),
#  '1773123': dict_keys(['status', 'bill']),
#  '1398160': dict_keys(['status', 'bill']),
#  '1424583': dict_keys(['status', 'bill']),
#  '1398320': dict_keys(['status', 'bill']),
#  '1398287': dict_keys(['status', 'bill']),
#  '1398222': dict_keys(['status', 'bill']),
#  '1456981': dict_keys(['status', 'bill']),
#  '1398264': dict_keys(['status', 'bill']),
#  '1667850': dict_keys(['status', 'bill']),
#  '1459005': dict_keys(['status', 'bill']),
#  '1455027': dict_keys(['status', 'bill']),
#  '1398189': dict_keys(['status', 'bill']),
#  '1398258': dict_keys(['status', 'bill']),
#  '1599989': dict_keys(['status', 'bill']),
#  '1444428': dict_keys(['status', 'bill']),
#  '1459237': dict_keys(['status', 'bill']),
#  '1398175': dict_keys(['status', 'bill']),
#  '1649629': dict_keys(['status', 'bill']),
#  '1398293': dict_keys(['status', 'bill']),
#  '1398243': dict_keys(['status', 'bill']),
#  '1592585': dict_keys(['status', 'bill']),
#  '1398217': dict_keys(['status', 'bill']),
#  '1398150': dict_keys(['status', 'bill']),
#  '1398254': dict_keys(['status', 'bill']),
#  '1398321': dict_keys(['status', 'bill']),
#  '1649630': dict_keys(['status', 'bill']),
#  '1667851': dict_keys(['status', 'bill'])}

# %%
# TEST
docs = []
docs1 = {}

for bill in bills1:
    
    # extract bill info
    bill_id = bill
    requestbill = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id="+bill_id
    b = requests.get(requestbill)
    binfo = json.loads(b.text)
    
    # FIND doc_id for most recent bill version: https://www.geeksforgeeks.org/python-check-whether-given-key-already-exists-in-a-dictionary/#
    if 'bill' in binfo.keys():
        doclist = binfo['bill']['texts']
        docs = [value['doc_id'] for value in doclist]
        docs1 = [str(doc) for doc in docs] # converting int to str
    if 'alert' in binfo.keys():
        doc_id = None
        
docs1
# Out:
# {'1453447': dict_keys(['status', 'bill']),
#  '1693920': dict_keys(['status', 'bill']),
#  '1456707': dict_keys(['status', 'bill']),
#  '1388510': dict_keys(['status', 'bill']),
#  '1711942': dict_keys(['status', 'bill']),
#  '1454994': dict_keys(['status', 'bill']),
#  '1594832': dict_keys(['status', 'bill']),
#  '1614129': dict_keys(['status', 'bill']),
#  '1592497': dict_keys(['status', 'bill']),
#  '1453388': dict_keys(['status', 'bill']),
#  '1593665': dict_keys(['status', 'bill']),
#  '1702780': dict_keys(['status', 'bill']),
#  '1458834': dict_keys(['status', 'bill']),
#  '1433188': dict_keys(['status', 'bill']),
#  '1451034': dict_keys(['status', 'bill']),
#  '1578060': dict_keys(['status', 'bill']),
#  '1438442': dict_keys(['status', 'bill']),
#  '1588122': dict_keys(['status', 'bill']),
#  '1417874': dict_keys(['status', 'bill']),
#  '1398281': dict_keys(['status', 'bill']),
#  '1712167': dict_keys(['status', 'bill']),
#  '1581321': dict_keys(['status', 'bill']),
#  '1707639': dict_keys(['status', 'bill']),
#  '1592396': dict_keys(['status', 'bill']),
#  '1456801': dict_keys(['status', 'bill']),
#  '1593664': dict_keys(['status', 'bill']),
#  '1453516': dict_keys(['status', 'bill']),
#  '1671132': dict_keys(['status', 'bill']),
#  '1454889': dict_keys(['status', 'bill']),
#  '1592492': dict_keys(['status', 'bill']),
#  '1453379': dict_keys(['status', 'bill']),
#  '1459192': dict_keys(['status', 'bill']),
#  '1712103': dict_keys(['status', 'bill']),
#  '1447168': dict_keys(['status', 'bill']),
#  '1441536': dict_keys(['status', 'bill']),
#  '1429103': dict_keys(['status', 'bill']),
#  '1458841': dict_keys(['status', 'bill']),
#  '1588179': dict_keys(['status', 'bill']),
#  '1456723': dict_keys(['status', 'bill']),
#  '1471518': dict_keys(['status', 'bill']),
#  '1385467': dict_keys(['status', 'bill']),
#  '1592403': dict_keys(['status', 'bill']),
#  '1701021': dict_keys(['status', 'bill']),
#  '1398228': dict_keys(['status', 'bill']),
#  '1594480': dict_keys(['status', 'bill']),
#  '1659520': dict_keys(['status', 'bill']),
#  '1709841': dict_keys(['status', 'bill']),
#  '1605378': dict_keys(['status', 'bill']),
#  '1714546': dict_keys(['status', 'bill']),
#  '1702725': dict_keys(['status', 'bill']),
#  '1398158': dict_keys(['status', 'bill']),
#  '1398220': dict_keys(['status', 'bill']),
#  '1707512': dict_keys(['status', 'bill']),
#  '1411987': dict_keys(['status', 'bill']),
#  '1649742': dict_keys(['status', 'bill']),
#  '1714501': dict_keys(['status', 'bill']),
#  '1447180': dict_keys(['status', 'bill']),
#  '1738922': dict_keys(['status', 'bill']),
#  '1593707': dict_keys(['status', 'bill']),
#  '1398241': dict_keys(['status', 'bill']),
#  '1394329': dict_keys(['status', 'bill']),
#  '1472781': dict_keys(['status', 'bill']),
#  '1458850': dict_keys(['status', 'bill']),
#  '1714731': dict_keys(['status', 'bill']),
#  '1456899': dict_keys(['status', 'bill']),
#  '1447141': dict_keys(['status', 'bill']),
#  '1693914': dict_keys(['status', 'bill']),
#  '1712067': dict_keys(['status', 'bill']),
#  '1585831': dict_keys(['status', 'bill']),
#  '1714651': dict_keys(['status', 'bill']),
#  '1398262': dict_keys(['status', 'bill']),
#  '1697043': dict_keys(['status', 'bill']),
#  '1456784': dict_keys(['status', 'bill']),
#  '1434863': dict_keys(['status', 'bill']),
#  '1398167': dict_keys(['status', 'bill']),
#  '1458914': dict_keys(['status', 'bill']),
#  '1454993': dict_keys(['status', 'bill']),
#  '1714813': dict_keys(['status', 'bill']),
#  '1385447': dict_keys(['status', 'bill']),
#  '1717506': dict_keys(['status', 'bill']),
#  '1700993': dict_keys(['status', 'bill']),
#  '1585846': dict_keys(['status', 'bill']),
#  '1592516': dict_keys(['status', 'bill']),
#  '1697060': dict_keys(['status', 'bill']),
#  '1729722': dict_keys(['status', 'bill']),
#  '1712107': dict_keys(['status', 'bill']),
#  '1709716': dict_keys(['status', 'bill']),
#  '1398271': dict_keys(['status', 'bill']),
#  '1689320': dict_keys(['status', 'bill']),
#  '1594675': dict_keys(['status', 'bill']),
#  '1693918': dict_keys(['status', 'bill']),
#  '1456942': dict_keys(['status', 'bill']),
#  '1702715': dict_keys(['status', 'bill']),
#  '1693916': dict_keys(['status', 'bill']),
#  '1711952': dict_keys(['status', 'bill']),
#  '1693952': dict_keys(['status', 'bill']),
#  '1474176': dict_keys(['status', 'bill']),
#  '1585842': dict_keys(['status', 'bill']),
#  '1709742': dict_keys(['status', 'bill']),
#  '1714485': dict_keys(['status', 'bill']),
#  '1434856': dict_keys(['status', 'bill']),
#  '1604715': dict_keys(['status', 'bill']),
#  '1450056': dict_keys(['status', 'bill']),
#  '1570768': dict_keys(['status', 'bill']),
#  '1693932': dict_keys(['status', 'bill']),
#  '1456953': dict_keys(['status', 'bill']),
#  '1581302': dict_keys(['status', 'bill']),
#  '1593554': dict_keys(['status', 'bill']),
#  '1478617': dict_keys(['status', 'bill']),
#  '1417854': dict_keys(['status', 'bill']),
#  '1407540': dict_keys(['status', 'bill']),
#  '1422155': dict_keys(['status', 'bill']),
#  '1585818': dict_keys(['status', 'bill']),
#  '1594554': dict_keys(['status', 'bill']),
#  '1459051': dict_keys(['status', 'bill']),
#  '1454867': dict_keys(['status', 'bill']),
#  '1595005': dict_keys(['status', 'bill']),
#  '1424575': dict_keys(['status', 'bill']),
#  '1593680': dict_keys(['status', 'bill']),
#  '1584607': dict_keys(['status', 'bill']),
#  '1693917': dict_keys(['status', 'bill']),
#  '1707654': dict_keys(['status', 'bill']),
#  '1594815': dict_keys(['status', 'bill']),
#  '1592405': dict_keys(['status', 'bill']),
#  '1593523': dict_keys(['status', 'bill']),
#  '1482845': dict_keys(['status', 'bill']),
#  '1709744': dict_keys(['status', 'bill']),
#  '1450052': dict_keys(['status', 'bill']),
#  '1424571': dict_keys(['status', 'bill']),
#  '1711977': dict_keys(['status', 'bill']),
#  '1602323': dict_keys(['status', 'bill']),
#  '1616338': dict_keys(['status', 'bill']),
#  '1454942': dict_keys(['status', 'bill']),
#  '1454843': dict_keys(['status', 'bill']),
#  '1593611': dict_keys(['status', 'bill']),
#  '1594718': dict_keys(['status', 'bill']),
#  '1714818': dict_keys(['status', 'bill']),
#  '1521964': dict_keys(['status', 'bill']),
#  '1594902': dict_keys(['status', 'bill']),
#  '1564469': dict_keys(['status', 'bill']),
#  '1709872': dict_keys(['status', 'bill']),
#  '1521873': dict_keys(['status', 'bill']),
#  '1388506': dict_keys(['status', 'bill']),
#  '1429105': dict_keys(['status', 'bill']),
#  '1594615': dict_keys(['status', 'bill']),
#  '1453527': dict_keys(['status', 'bill']),
#  '1592779': dict_keys(['status', 'alert']),
#  '1714521': dict_keys(['status', 'bill']),
#  '1667855': dict_keys(['status', 'bill']),
#  '1454832': dict_keys(['status', 'bill']),
#  '1594512': dict_keys(['status', 'bill']),
#  '1458842': dict_keys(['status', 'bill']),
#  '1702767': dict_keys(['status', 'bill']),
#  '1441546': dict_keys(['status', 'bill']),
#  '1551314': dict_keys(['status', 'bill']),
#  '1659519': dict_keys(['status', 'bill']),
#  '1594595': dict_keys(['status', 'bill']),
#  '1567065': dict_keys(['status', 'bill']),
#  '1731372': dict_keys(['status', 'bill']),
#  '1712049': dict_keys(['status', 'bill']),
#  '1711904': dict_keys(['status', 'bill']),
#  '1594677': dict_keys(['status', 'bill']),
#  '1724789': dict_keys(['status', 'bill']),
#  '1691346': dict_keys(['status', 'bill']),
#  '1714317': dict_keys(['status', 'bill']),
#  '1453384': dict_keys(['status', 'bill']),
#  '1712204': dict_keys(['status', 'bill']),
#  '1398177': dict_keys(['status', 'bill']),
#  '1398276': dict_keys(['status', 'bill']),
#  '1649739': dict_keys(['status', 'bill']),
#  '1456732': dict_keys(['status', 'bill']),
#  '1388071': dict_keys(['status', 'bill']),
#  '1422169': dict_keys(['status', 'bill']),
#  '1398240': dict_keys(['status', 'bill']),
#  '1398165': dict_keys(['status', 'bill']),
#  '1649612': dict_keys(['status', 'bill']),
#  '1433151': dict_keys(['status', 'bill']),
#  '1701039': dict_keys(['status', 'bill']),
#  '1456842': dict_keys(['status', 'bill']),
#  '1459086': dict_keys(['status', 'bill']),
#  '1712180': dict_keys(['status', 'bill']),
#  '1422147': dict_keys(['status', 'bill']),
#  '1447125': dict_keys(['status', 'bill']),
#  '1594937': dict_keys(['status', 'bill']),
#  '1707500': dict_keys(['status', 'bill']),
#  '1398291': dict_keys(['status', 'bill']),
#  '1385404': dict_keys(['status', 'bill']),
#  '1459210': dict_keys(['status', 'bill']),
#  '1594456': dict_keys(['status', 'bill']),
#  '1398226': dict_keys(['status', 'bill']),
#  '1458774': dict_keys(['status', 'bill']),
#  '1714491': dict_keys(['status', 'bill']),
#  '1616339': dict_keys(['status', 'bill']),
#  '1709864': dict_keys(['status', 'bill']),
#  '1594986': dict_keys(['status', 'bill']),
#  '1649634': dict_keys(['status', 'bill']),
#  '1456769': dict_keys(['status', 'bill']),
#  '1649639': dict_keys(['status', 'bill']),
#  '1592715': dict_keys(['status', 'alert']),
#  '1459177': dict_keys(['status', 'bill']),
#  '1398269': dict_keys(['status', 'bill']),
#  '1398197': dict_keys(['status', 'bill']),
#  '1712004': dict_keys(['status', 'bill']),
#  '1398172': dict_keys(['status', 'bill']),
#  '1398187': dict_keys(['status', 'bill']),
#  '1454844': dict_keys(['status', 'bill']),
#  '1385449': dict_keys(['status', 'bill']),
#  '1588169': dict_keys(['status', 'bill']),
#  '1714422': dict_keys(['status', 'bill']),
#  '1398301': dict_keys(['status', 'bill']),
#  '1590298': dict_keys(['status', 'bill']),
#  '1590444': dict_keys(['status', 'bill']),
#  '1702772': dict_keys(['status', 'bill']),
#  '1667833': dict_keys(['status', 'bill']),
#  '1453363': dict_keys(['status', 'bill']),
#  '1441549': dict_keys(['status', 'bill']),
#  '1588128': dict_keys(['status', 'bill']),
#  '1385433': dict_keys(['status', 'bill']),
#  '1592472': dict_keys(['status', 'bill']),
#  '1636426': dict_keys(['status', 'bill']),
#  '1398249': dict_keys(['status', 'bill']),
#  '1441541': dict_keys(['status', 'bill']),
#  '1582925': dict_keys(['status', 'bill']),
#  '1714407': dict_keys(['status', 'bill']),
#  '1588097': dict_keys(['status', 'bill']),
#  '1385430': dict_keys(['status', 'bill']),
#  '1691357': dict_keys(['status', 'bill']),
#  '1772423': dict_keys(['status', 'bill']),
#  '1667860': dict_keys(['status', 'bill']),
#  '1456710': dict_keys(['status', 'bill']),
#  '1593806': dict_keys(['status', 'bill']),
#  '1454921': dict_keys(['status', 'bill']),
#  '1709708': dict_keys(['status', 'bill']),
#  '1450112': dict_keys(['status', 'bill']),
#  '1459270': dict_keys(['status', 'bill']),
#  '1398247': dict_keys(['status', 'bill']),
#  '1385409': dict_keys(['status', 'bill']),
#  '1438433': dict_keys(['status', 'bill']),
#  '1385425': dict_keys(['status', 'bill']),
#  '1714547': dict_keys(['status', 'bill']),
#  '1385436': dict_keys(['status', 'bill']),
#  '1398196': dict_keys(['status', 'bill']),
#  '1417857': dict_keys(['status', 'bill']),
#  '1593839': dict_keys(['status', 'bill']),
#  '1594487': dict_keys(['status', 'bill']),
#  '1459036': dict_keys(['status', 'bill']),
#  '1441570': dict_keys(['status', 'bill']),
#  '1398178': dict_keys(['status', 'bill']),
#  '1714633': dict_keys(['status', 'bill']),
#  '1457004': dict_keys(['status', 'bill']),
#  '1426683': dict_keys(['status', 'bill']),
#  '1398231': dict_keys(['status', 'bill']),
#  '1581314': dict_keys(['status', 'bill']),
#  '1559216': dict_keys(['status', 'bill']),
#  '1705874': dict_keys(['status', 'bill']),
#  '1714551': dict_keys(['status', 'bill']),
#  '1458962': dict_keys(['status', 'bill']),
#  '1702786': dict_keys(['status', 'bill']),
#  '1592784': dict_keys(['status', 'bill']),
#  '1594741': dict_keys(['status', 'bill']),
#  '1459297': dict_keys(['status', 'bill']),
#  '1759484': dict_keys(['status', 'bill']),
#  '1458837': dict_keys(['status', 'bill']),
#  '1398233': dict_keys(['status', 'bill']),
#  '1398300': dict_keys(['status', 'bill']),
#  '1590264': dict_keys(['status', 'bill']),
#  '1385557': dict_keys(['status', 'bill']),
#  '1545618': dict_keys(['status', 'bill']),
#  '1705803': dict_keys(['status', 'bill']),
#  '1398145': dict_keys(['status', 'bill']),
#  '1594476': dict_keys(['status', 'bill']),
#  '1579404': dict_keys(['status', 'bill']),
#  '1458971': dict_keys(['status', 'bill']),
#  '1590411': dict_keys(['status', 'bill']),
#  '1398174': dict_keys(['status', 'bill']),
#  '1714533': dict_keys(['status', 'bill']),
#  '1594437': dict_keys(['status', 'bill']),
#  '1698897': dict_keys(['status', 'bill']),
#  '1649614': dict_keys(['status', 'bill']),
#  '1726105': dict_keys(['status', 'bill']),
#  '1398275': dict_keys(['status', 'bill']),
#  '1551318': dict_keys(['status', 'bill']),
#  '1551330': dict_keys(['status', 'bill']),
#  '1594904': dict_keys(['status', 'bill']),
#  '1398236': dict_keys(['status', 'bill']),
#  '1592680': dict_keys(['status', 'bill']),
#  '1593821': dict_keys(['status', 'bill']),
#  '1398282': dict_keys(['status', 'bill']),
#  '1385403': dict_keys(['status', 'bill']),
#  '1451072': dict_keys(['status', 'bill']),
#  '1667835': dict_keys(['status', 'bill']),
#  '1590352': dict_keys(['status', 'bill']),
#  '1592579': dict_keys(['status', 'bill']),
#  '1450073': dict_keys(['status', 'bill']),
#  '1398171': dict_keys(['status', 'bill']),
#  '1588168': dict_keys(['status', 'bill']),
#  '1458874': dict_keys(['status', 'bill']),
#  '1594814': dict_keys(['status', 'bill']),
#  '1521874': dict_keys(['status', 'bill']),
#  '1454852': dict_keys(['status', 'bill']),
#  '1693927': dict_keys(['status', 'bill']),
#  '1714704': dict_keys(['status', 'bill']),
#  '1593819': dict_keys(['status', 'bill']),
#  '1667828': dict_keys(['status', 'bill']),
#  '1456836': dict_keys(['status', 'bill']),
#  '1575742': dict_keys(['status', 'bill']),
#  '1707538': dict_keys(['status', 'bill']),
#  '1667847': dict_keys(['status', 'bill']),
#  '1584633': dict_keys(['status', 'bill']),
#  '1593686': dict_keys(['status', 'bill']),
#  '1712034': dict_keys(['status', 'bill']),
#  '1705903': dict_keys(['status', 'bill']),
#  '1458946': dict_keys(['status', 'bill']),
#  '1438467': dict_keys(['status', 'bill']),
#  '1454890': dict_keys(['status', 'bill']),
#  '1398181': dict_keys(['status', 'bill']),
#  '1714773': dict_keys(['status', 'bill']),
#  '1385434': dict_keys(['status', 'bill']),
#  '1459037': dict_keys(['status', 'bill']),
#  '1702745': dict_keys(['status', 'bill']),
#  '1667834': dict_keys(['status', 'bill']),
#  '1649738': dict_keys(['status', 'bill']),
#  '1649626': dict_keys(['status', 'bill']),
#  '1398198': dict_keys(['status', 'bill']),
#  '1458863': dict_keys(['status', 'bill']),
#  '1652083': dict_keys(['status', 'bill']),
#  '1652088': dict_keys(['status', 'bill']),
#  '1731369': dict_keys(['status', 'bill']),
#  '1593778': dict_keys(['status', 'bill']),
#  '1593649': dict_keys(['status', 'bill']),
#  '1590380': dict_keys(['status', 'bill']),
#  '1707490': dict_keys(['status', 'bill']),
#  '1714634': dict_keys(['status', 'bill']),
#  '1459132': dict_keys(['status', 'bill']),
#  '1649613': dict_keys(['status', 'bill']),
#  '1453432': dict_keys(['status', 'bill']),
#  '1593826': dict_keys(['status', 'bill']),
#  '1593557': dict_keys(['status', 'bill']),
#  '1714412': dict_keys(['status', 'bill']),
#  '1705898': dict_keys(['status', 'bill']),
#  '1714709': dict_keys(['status', 'bill']),
#  '1714562': dict_keys(['status', 'bill']),
#  '1714444': dict_keys(['status', 'bill']),
#  '1388319': dict_keys(['status', 'bill']),
#  '1459059': dict_keys(['status', 'bill']),
#  '1691375': dict_keys(['status', 'bill']),
#  '1455006': dict_keys(['status', 'bill']),
#  '1444443': dict_keys(['status', 'bill']),
#  '1592723': dict_keys(['status', 'bill']),
#  '1458961': dict_keys(['status', 'bill']),
#  '1398195': dict_keys(['status', 'bill']),
#  '1398285': dict_keys(['status', 'bill']),
#  '1649615': dict_keys(['status', 'bill']),
#  '1453487': dict_keys(['status', 'bill']),
#  '1707695': dict_keys(['status', 'bill']),
#  '1398250': dict_keys(['status', 'bill']),
#  '1590364': dict_keys(['status', 'bill']),
#  '1398299': dict_keys(['status', 'bill']),
#  '1697071': dict_keys(['status', 'bill']),
#  '1707543': dict_keys(['status', 'bill']),
#  '1644455': dict_keys(['status', 'bill']),
#  '1385513': dict_keys(['status', 'bill']),
#  '1398302': dict_keys(['status', 'bill']),
#  '1411974': dict_keys(['status', 'bill']),
#  '1456895': dict_keys(['status', 'bill']),
#  '1385573': dict_keys(['status', 'bill']),
#  '1398164': dict_keys(['status', 'bill']),
#  '1451043': dict_keys(['status', 'bill']),
#  '1453475': dict_keys(['status', 'bill']),
#  '1459106': dict_keys(['status', 'bill']),
#  '1456998': dict_keys(['status', 'bill']),
#  '1592818': dict_keys(['status', 'bill']),
#  '1594789': dict_keys(['status', 'bill']),
#  '1705902': dict_keys(['status', 'bill']),
#  '1709774': dict_keys(['status', 'bill']),
#  '1714532': dict_keys(['status', 'bill']),
#  '1394328': dict_keys(['status', 'bill']),
#  '1459112': dict_keys(['status', 'bill']),
#  '1702700': dict_keys(['status', 'bill']),
#  '1627793': dict_keys(['status', 'bill']),
#  '1581326': dict_keys(['status', 'bill']),
#  '1454939': dict_keys(['status', 'bill']),
#  '1398149': dict_keys(['status', 'bill']),
#  '1453371': dict_keys(['status', 'bill']),
#  '1588092': dict_keys(['status', 'bill']),
#  '1438466': dict_keys(['status', 'bill']),
#  '1450061': dict_keys(['status', 'bill']),
#  '1398186': dict_keys(['status', 'bill']),
#  '1398146': dict_keys(['status', 'bill']),
#  '1584635': dict_keys(['status', 'bill']),
#  '1441537': dict_keys(['status', 'bill']),
#  '1667836': dict_keys(['status', 'bill']),
#  '1594603': dict_keys(['status', 'bill']),
#  '1588130': dict_keys(['status', 'bill']),
#  '1560018': dict_keys(['status', 'bill']),
#  '1592501': dict_keys(['status', 'bill']),
#  '1609637': dict_keys(['status', 'bill']),
#  '1667857': dict_keys(['status', 'bill']),
#  '1714319': dict_keys(['status', 'bill']),
#  '1755204': dict_keys(['status', 'bill']),
#  '1771715': dict_keys(['status', 'bill']),
#  '1592796': dict_keys(['status', 'bill']),
#  '1731371': dict_keys(['status', 'bill']),
#  '1433158': dict_keys(['status', 'bill']),
#  '1417853': dict_keys(['status', 'bill']),
#  '1592805': dict_keys(['status', 'bill']),
#  '1691348': dict_keys(['status', 'bill']),
#  '1398253': dict_keys(['status', 'bill']),
#  '1714767': dict_keys(['status', 'bill']),
#  '1702748': dict_keys(['status', 'bill']),
#  '1698914': dict_keys(['status', 'bill']),
#  '1705843': dict_keys(['status', 'bill']),
#  '1709927': dict_keys(['status', 'bill']),
#  '1456980': dict_keys(['status', 'bill']),
#  '1593791': dict_keys(['status', 'bill']),
#  '1594941': dict_keys(['status', 'bill']),
#  '1593543': dict_keys(['status', 'bill']),
#  '1667953': dict_keys(['status', 'bill']),
#  '1456765': dict_keys(['status', 'bill']),
#  '1456969': dict_keys(['status', 'bill']),
#  '1593593': dict_keys(['status', 'bill']),
#  '1456837': dict_keys(['status', 'bill']),
#  '1398212': dict_keys(['status', 'bill']),
#  '1649636': dict_keys(['status', 'bill']),
#  '1594596': dict_keys(['status', 'bill']),
#  '1705988': dict_keys(['status', 'bill']),
#  '1478615': dict_keys(['status', 'bill']),
#  '1385560': dict_keys(['status', 'bill']),
#  '1608382': dict_keys(['status', 'bill']),
#  '1609634': dict_keys(['status', 'bill']),
#  '1459224': dict_keys(['status', 'bill']),
#  '1398192': dict_keys(['status', 'bill']),
#  '1594558': dict_keys(['status', 'bill']),
#  '1707631': dict_keys(['status', 'bill']),
#  '1594852': dict_keys(['status', 'bill']),
#  '1582915': dict_keys(['status', 'bill']),
#  '1441562': dict_keys(['status', 'bill']),
#  '1500884': dict_keys(['status', 'bill']),
#  '1385571': dict_keys(['status', 'bill']),
#  '1438472': dict_keys(['status', 'bill']),
#  '1608924': dict_keys(['status', 'bill']),
#  '1615805': dict_keys(['status', 'bill']),
#  '1593639': dict_keys(['status', 'bill']),
#  '1594628': dict_keys(['status', 'bill']),
#  '1398183': dict_keys(['status', 'bill']),
#  '1714449': dict_keys(['status', 'bill']),
#  '1705827': dict_keys(['status', 'bill']),
#  '1712188': dict_keys(['status', 'bill']),
#  '1686434': dict_keys(['status', 'bill']),
#  '1714621': dict_keys(['status', 'bill']),
#  '1705905': dict_keys(['status', 'bill']),
#  '1714683': dict_keys(['status', 'bill']),
#  '1712152': dict_keys(['status', 'bill']),
#  '1707647': dict_keys(['status', 'bill']),
#  '1709738': dict_keys(['status', 'bill']),
#  '1398173': dict_keys(['status', 'bill']),
#  '1398152': dict_keys(['status', 'bill']),
#  '1508535': dict_keys(['status', 'bill']),
#  '1586981': dict_keys(['status', 'bill']),
#  '1667861': dict_keys(['status', 'bill']),
#  '1398184': dict_keys(['status', 'bill']),
#  '1637884': dict_keys(['status', 'bill']),
#  '1456794': dict_keys(['status', 'bill']),
#  '1458791': dict_keys(['status', 'bill']),
#  '1459062': dict_keys(['status', 'bill']),
#  '1456843': dict_keys(['status', 'bill']),
#  '1594865': dict_keys(['status', 'bill']),
#  '1709848': dict_keys(['status', 'bill']),
#  '1705952': dict_keys(['status', 'bill']),
#  '1592685': dict_keys(['status', 'bill']),
#  '1772090': dict_keys(['status', 'bill']),
#  '1590291': dict_keys(['status', 'bill']),
#  '1649640': dict_keys(['status', 'bill']),
#  '1714508': dict_keys(['status', 'bill']),
#  '1657752': dict_keys(['status', 'bill']),
#  '1567067': dict_keys(['status', 'bill']),
#  '1705844': dict_keys(['status', 'bill']),
#  '1398288': dict_keys(['status', 'bill']),
#  '1398259': dict_keys(['status', 'bill']),
#  '1593506': dict_keys(['status', 'bill']),
#  '1398316': dict_keys(['status', 'bill']),
#  '1398256': dict_keys(['status', 'bill']),
#  '1697014': dict_keys(['status', 'bill']),
#  '1398296': dict_keys(['status', 'bill']),
#  '1581319': dict_keys(['status', 'bill']),
#  '1492081': dict_keys(['status', 'bill']),
#  '1592770': dict_keys(['status', 'alert']),
#  '1707671': dict_keys(['status', 'bill']),
#  '1709925': dict_keys(['status', 'bill']),
#  '1759810': dict_keys(['status', 'bill']),
#  '1398310': dict_keys(['status', 'bill']),
#  '1441568': dict_keys(['status', 'bill']),
#  '1454936': dict_keys(['status', 'bill']),
#  '1385586': dict_keys(['status', 'bill']),
#  '1649628': dict_keys(['status', 'bill']),
#  '1714453': dict_keys(['status', 'bill']),
#  '1667853': dict_keys(['status', 'bill']),
#  '1598796': dict_keys(['status', 'bill']),
#  '1398148': dict_keys(['status', 'bill']),
#  '1649632': dict_keys(['status', 'bill']),
#  '1607955': dict_keys(['status', 'bill']),
#  '1398147': dict_keys(['status', 'bill']),
#  '1398308': dict_keys(['status', 'bill']),
#  '1434871': dict_keys(['status', 'bill']),
#  '1588142': dict_keys(['status', 'bill']),
#  '1689325': dict_keys(['status', 'bill']),
#  '1711982': dict_keys(['status', 'bill']),
#  '1702834': dict_keys(['status', 'bill']),
#  '1698948': dict_keys(['status', 'bill']),
#  '1592800': dict_keys(['status', 'bill']),
#  '1749145': dict_keys(['status', 'bill']),
#  '1398206': dict_keys(['status', 'bill']),
#  '1398216': dict_keys(['status', 'bill']),
#  '1398204': dict_keys(['status', 'bill']),
#  '1398251': dict_keys(['status', 'bill']),
#  '1398252': dict_keys(['status', 'bill']),
#  '1398279': dict_keys(['status', 'bill']),
#  '1593815': dict_keys(['status', 'bill']),
#  '1586986': dict_keys(['status', 'bill']),
#  '1593669': dict_keys(['status', 'bill']),
#  '1385399': dict_keys(['status', 'bill']),
#  '1667849': dict_keys(['status', 'bill']),
#  '1454876': dict_keys(['status', 'bill']),
#  '1450058': dict_keys(['status', 'bill']),
#  '1453445': dict_keys(['status', 'bill']),
#  '1453469': dict_keys(['status', 'bill']),
#  '1455003': dict_keys(['status', 'bill']),
#  '1456703': dict_keys(['status', 'bill']),
#  '1459076': dict_keys(['status', 'bill']),
#  '1459227': dict_keys(['status', 'bill']),
#  '1459247': dict_keys(['status', 'bill']),
#  '1592712': dict_keys(['status', 'alert']),
#  '1594987': dict_keys(['status', 'bill']),
#  '1594571': dict_keys(['status', 'bill']),
#  '1590283': dict_keys(['status', 'bill']),
#  '1592812': dict_keys(['status', 'bill']),
#  '1706006': dict_keys(['status', 'bill']),
#  '1709901': dict_keys(['status', 'bill']),
#  '1773123': dict_keys(['status', 'bill']),
#  '1398160': dict_keys(['status', 'bill']),
#  '1424583': dict_keys(['status', 'bill']),
#  '1398320': dict_keys(['status', 'bill']),
#  '1398287': dict_keys(['status', 'bill']),
#  '1398222': dict_keys(['status', 'bill']),
#  '1456981': dict_keys(['status', 'bill']),
#  '1398264': dict_keys(['status', 'bill']),
#  '1667850': dict_keys(['status', 'bill']),
#  '1459005': dict_keys(['status', 'bill']),
#  '1455027': dict_keys(['status', 'bill']),
#  '1398189': dict_keys(['status', 'bill']),
#  '1398258': dict_keys(['status', 'bill']),
#  '1599989': dict_keys(['status', 'bill']),
#  '1444428': dict_keys(['status', 'bill']),
#  '1459237': dict_keys(['status', 'bill']),
#  '1398175': dict_keys(['status', 'bill']),
#  '1649629': dict_keys(['status', 'bill']),
#  '1398293': dict_keys(['status', 'bill']),
#  '1398243': dict_keys(['status', 'bill']),
#  '1592585': dict_keys(['status', 'bill']),
#  '1398217': dict_keys(['status', 'bill']),
#  '1398150': dict_keys(['status', 'bill']),
#  '1398254': dict_keys(['status', 'bill']),
#  '1398321': dict_keys(['status', 'bill']),
#  '1649630': dict_keys(['status', 'bill']),
#  '1667851': dict_keys(['status', 'bill'])}

# %%
# TEST: checking structure
docs1 = {}

for bill in bills1:
    
    # extract bill info
    bill_id = bill
    requestbill = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id="+bill_id
    b = requests.get(requestbill)
    binfo = json.loads(b.text)
    
    # FIND doc_id for most recent bill version: https://www.geeksforgeeks.org/python-check-whether-given-key-already-exists-in-a-dictionary/#
    if 'alert' in binfo.keys():
        docs1[bill] = binfo['alert'].keys()
        
docs1
# Out:
# {'1592779': dict_keys(['message']),
#  '1592715': dict_keys(['message']),
#  '1592770': dict_keys(['message']),
#  '1592712': dict_keys(['message'])}

# %%
## EXTRACT doc_id for most recent version of bill, select bill info, save as df

# empty dict to store cleaned bill info
infotxt = {}
# empty list to store list of bill texts
texts = []

# loop
for bill in bills1:
    
    # extract bill info
    bill_id = bill
    requestbill = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id="+bill_id
    b = requests.get(requestbill)
    binfo = json.loads(b.text)
    
    # FIND doc_id for most recent bill version:
    if 'bill' in binfo.keys():
        doclist = binfo['bill']['texts']
        docs = [value['doc_id'] for value in doclist]
        docs1 = [str(doc) for doc in docs] # converting int to str
        # identify most recently amended version of doc text
        doc_id = docs1[-1] 

        # get bill text for doc text
        requestdoc = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBillText&id='+doc_id
        d = requests.get(requestdoc)
        btext = json.loads(d.text)

        # get URL for doc
        URL = btext['text']['state_link']

        # get status page URL
        statusURL = btext['text']['state_link'].replace('Text', 'Status') 
        #statusURL = btext['text']['url'].split("/id")[0].replace('text', 'bill')
        URL1 = statusURL

        ## EXTRACT select info from URLs

        # main page
        r = urlopen(URL)
        html_bytes = r.read()
        html = html_bytes.decode("utf-8")
        soup = BeautifulSoup(html, features='html.parser')

        # status page
        r1 = urlopen(URL1)
        html_bytes = r1.read()
        html1 = html_bytes.decode("utf-8")
        soup1 = BeautifulSoup(html1, features='html.parser')

        # bill title
        t = soup.find_all('title')
        ti = t[0]

        # bill year
        #yi = soup.find_all(id = 'bill_intro_date') 
        yi = soup.find_all(class_ = 'bill_title_yr')

        # bill text
        txt = soup.find_all('div', id = 'bill')

        # bill status
        #status = soup1.find_all('td')
        status = soup1.find_all(id = 'billhistory')

        ## REMOVE html style and isolate key info

        # title
        for text in ti:
            title = text.text.strip()
            title = title.split("- ")[-1]

        # bill text: remove html formatting and clean
        for text in txt:
            billtxt = text.text.strip()
            # remove non ASCII chars; adapted from: https://stackoverflow.com/questions/20078816/replace-non-ascii-characters-with-a-single-space
            billtxt = re.sub(r'[^\x00-\x7F]+', ' ', billtxt)
            # remove tabs and new lines
            billtxt = re.sub(r'(\s)', ' ', billtxt)
            # add space after colons and semicolons
            billtxt = re.sub(r'(\:|\;)+', r'\1 ', billtxt)
            # add space after periods only if preceded by words >=4 chars
            billtxt = re.sub(r'([A-z]{4,}\.)+', r'\1 ', billtxt)
            # remove any extra white spaces
            billtxt = re.sub(r'\s+', ' ', billtxt)

       # year
        for text in yi:
            if text is None:
                year = None
            else:
                year = text.text.strip()
                #year = year[-4:]

       # status
        #if len(status) < 1:
         #   status = None
        #else:
            #for text in status[-1]:
        for text in status:
            status = text.text.strip()
            status = status.split("Action")[-1]
            status = re.sub(r'(\s)', ' ', status)
            status = re.sub(r'\s+', ' ', status)

    # PLACEHOLDER code until bills can be identified
    if 'alert' in binfo.keys():
        title = None
        year = None
        status = None
        billtxt = None
            
    # concatenate into one list
    infotxt = [title, year, status, billtxt]

    # add bill_id to list
    #infotxt.insert(0, bill_id)
    #bill_id = infotxt[0].split("- ")[-1][:7]
    bill_id = bill_id
    
     ## CONVERT lists to df  
    itxtdf = pd.DataFrame(infotxt)
    texts.append(itxtdf)
    fulltext = pd.concat(texts, axis = 1).transpose()

# rename columns
fulltext.columns = ['bill_id', 'title', 'year', 'status', 'text']

# inspect/show
fulltext.head()
# Out:
#    bill_id                                              title  year  \
# 0  1453447  AB-778 Institutional purchasers: purchase of C...  None
# 0  1693920  AB-408 Climate-resilient Farms, Sustainable He...  2023
# 0  1456707        AB-1009 Farm to Community Food Hub Program.  2023
# 0  1388510  AB-125 Equitable Economic Recovery, Healthy Fo...  2020
# 0  1711942  AB-1197 Agricultural Protection Planning Grant...  2023
#
#               status                                               text
# 0               None  The people of the State of California do enact...
# 0  February 02, 2023  The people of the State of California do enact...
# 0               None  The people of the State of California do enact...
# 0  December 18, 2020  The people of the State of California do enact...
# 0  February 16, 2023  The people of the State of California do enact...

# %%
# create bill_id column after df created
#fulltext['bill_id'] = infotxt[0].split("- ")[-1][:7]
#fulltext['bill_id'] = fulltext['title']#.str.split("- ")[-1][:7]
#fulltext.head()

# %%
# saving
fulltext.to_csv('CA_food and ag bills_recent.csv')

# %%
fulltext
# Out:
#     bill_id                                              title  year  \
# 0   1453447  AB-778 Institutional purchasers: purchase of C...  None
# 0   1693920  AB-408 Climate-resilient Farms, Sustainable He...  2023
# 0   1456707        AB-1009 Farm to Community Food Hub Program.  2023
# 0   1388510  AB-125 Equitable Economic Recovery, Healthy Fo...  2020
# 0   1711942  AB-1197 Agricultural Protection Planning Grant...  2023
# ..      ...                                                ...   ...
# 0   1398150                                     AB-133 Health.  2021
# 0   1398254                         SB-133 Budget Act of 2022.  2021
# 0   1398321                      SB-200 Public safety omnibus.  2021
# 0   1649630                 AB-118 Budget Act of 2023: health.  2021
# 0   1667851                 SB-118 Budget Act of 2023: health.  2023
#
#                                                status  \
# 0                                                None
# 0                                   February 02, 2023
# 0                                                None
# 0                                   December 18, 2020
# 0                                   February 16, 2023
# ..                                                ...
# 0   [[], [], [[Procedures and]], [[Publication]], ...
# 0   [[[\n                Amended\n               I...
# 0                                           $ 200,000
# 0                                                None
# 0                                    January 18, 2023
#
#                                                  text
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
# ..                                                ...
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
# 0   The people of the State of California do enact...
#
# [565 rows x 5 columns]

# %%
## TEST: SCRAPE SEARCH RESULTS for bill_ids: RECENT

# scrape LegiScan search results for CA bills RE: food and ag for current year
requeststring = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=2&query=food%20and%20agriculture"
# request: CA, food and ag, results for recent years
requeststring1 = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=3&query=food%20and%20agriculture"
# request: CA, food and ag, results for all available years
requeststring2 = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=1&query=food%20and%20agriculture"

# pull request: ge\tting results as JSON object
r = requests.get(requeststring1)
# turning JSON object into a dict
dict1 = json.loads(r.text)

# creating subset dict with only keys of interest
list1 = dict1['searchresult']['results']
# generating list of bill_ids
bills = [value['bill_id'] for value in list1]

# each bill in bills is stored as an integer; convert to list of str
bills1 = [str(bill) for bill in bills]

#inspect/show results
print(len(bills1))
print(bills1[:5])
# Out:
# 565
# ['1453447', '1693920', '1456707', '1388510', '1711942']

# %%
# TEST CELL 
bills2 = bills1[:5]
bills2
# Out:
# ['1453447', '1693920', '1456707', '1388510', '1711942']

# %%
## EXTRACT doc_id for most recent version of bill, select bill info, save as df

# empty dict to store cleaned bill info
infotxt = {}
# empty list to store list of bill texts
texts = []

# loop
for bill in bills2:
    
    # extract bill info
    bill_id = bill
    requestbill = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id="+bill_id
    b = requests.get(requestbill)
    binfo = json.loads(b.text)
    
    # FIND doc_id for most recent bill version
    doclist = binfo['bill']['texts']
    docs = [value['doc_id'] for value in doclist]
    docs1 = [str(doc) for doc in docs] # converting int to str
    
    # identify most recently amended version of text
    doc_id = docs1[-1] 
    
    # get bill text for doc
    requestdoc = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBillText&id='+doc_id
    d = requests.get(requestdoc)
    btext = json.loads(d.text)
    
    # get URL for amended doc
    URL = btext['text']['state_link']
    
    # get status page URL
    statusURL = btext['text']['state_link'].replace('Text', 'Status') 
    #statusURL = btext['text']['url'].split("/id")[0].replace('text', 'bill')
    URL1 = statusURL

    ## EXTRACT select info from URL
    
    # main page
    r = urlopen(URL)
    html_bytes = r.read()
    html = html_bytes.decode("utf-8")
    soup = BeautifulSoup(html, features='html.parser')

    # status page
    r1 = urlopen(URL1)
    html_bytes = r1.read()
    html1 = html_bytes.decode("utf-8")
    soup1 = BeautifulSoup(html1, features='html.parser')
    
    # bill title
    t = soup.find_all('title')
    ti = t[0]

    # bill year: introduced
    #yi = soup.find_all(id = 'bill_intro_date')
    yi = soup.find_all(class_ = 'bill_title_yr')

    # bill text
    txt = soup.find_all('div', id = 'bill')

    # bill status
    #status = soup.find_all('td')
    status = soup1.find_all(id = 'billhistory')
    #status = soup.find_all(id = "bill-last-action")
    
    ## REMOVE html style and tags from bill text
    
    # title
    for text in ti:
        title = text.text.strip()
        title = title.split("- ")[-1]
                  
    # bill text
    for text in txt:
        billtxt = text.text.strip()
    
    # bill status
    #if len(status) < 1:
    #    status = None
    #else:
     #   for text in status[-1]:
      #      status = text.text.strip()
            
    for text in status:
        status = text.text
        status = status.split("Action")[-1]
        status = re.sub(r'(\s)', ' ', status)
        status = re.sub(r'\s+', ' ', status)
            
        #for text in status:
         #   status = text.text.strip()
          #  status = status.split("Action: ")[-1].split("Pending")[0]
        
    # year
    for text in yi:
        if text is None:
            year = None
        else:
            year = text.text.strip()
            #year = year[-4:]
    
    # concatenating into one list
    infotxt = [title, year, status, billtxt]

    # creating bill_id
    #bill_id = infotxt[0].split("- ")[-1][:7]
    bill_id = bill_id
    
    # adding bill_id to list
    infotxt.insert(0, bill_id)
    
     ## CONVERT to df  
    itxtdf = pd.DataFrame(infotxt)
    texts.append(itxtdf)
    fulltext = pd.concat(texts, axis = 1).transpose()

# rename columns
fulltext.columns = ['bill_id', 'title', 'year', 'status', 'text']
#fulltext.columns = ['bill_id', 'title', 'status', 'text']

# inspect/show
fulltext.head()
# Out:
#    bill_id                                              title         year  \
# 0  1453447  AB-778 Institutional purchasers: purchase of C...  (2021-2022)
# 0  1693920  AB-408 Climate-resilient Farms, Sustainable He...  (2023-2024)
# 0  1456707        AB-1009 Farm to Community Food Hub Program.  (2021-2022)
# 0  1388510  AB-125 Equitable Economic Recovery, Healthy Fo...  (2021-2022)
# 0  1711942  AB-1197 Agricultural Protection Planning Grant...  (2023-2024)
#
#                                               status  \
# 0   09/27/22 Chaptered by Secretary of State - Ch...
# 0   08/02/23 In committee: Set, first hearing. He...
# 0   10/07/21 Chaptered by Secretary of State - Ch...
# 0   02/01/22 From committee: Filed with the Chief...
# 0   07/05/23 From committee: Do pass and re-refer...
#
#                                                 text
# 0  The people of the State of California do enact...
# 0  The people of the State of California do enact...
# 0  The people of the State of California do enact...
# 0  The people of the State of California do enact...
# 0  The people of the State of California do enact...

# %%
# SAVE: pieces

# FIND doc_id for most recent bill version
doclist = binfo['bill']['texts']
docs = [value['doc_id'] for value in doclist]
docs1 = [str(doc) for doc in docs] # converting int to str

# call the most recently amended version of bill text
doc_id = docs1[-1] 

# get bill text for doc
btext1 = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBillText&id='+doc_id
b = requests.get(btext1)
btext = json.loads(b.text)

# get URL for amended doc
URL = btext['text']['state_link']

## EXTRACTION: relevant info from URL
r = urlopen(URL)
html_bytes = r.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, features='html.parser')

# bill title
t = soup.find_all('title')
ti = t[0]

# bill year: introduced
yi = soup.find_all(id = 'bill_intro_date') # will have to be cleaned

# bill year: amended
ya = soup.find_all('tbody')
yam = (ya[0])

# bill text
txt = soup.find_all('div', id = 'bill')

## REMOVE: html style and tags from bill text

# title
for text in ti:
    title = text.text.strip()
    title = title.split("- ")[-1]

# year intro
for text in yi:
    yeari = text.text.strip()
    yeari = yeari[-4:]

# year recent activity
for text in yam:
    yeara = text.text.strip()
    yeara = yeara[-4:]

# bill text
for text in txt:
    billtxt = text.text.strip()
    
# creating bill_id
bill_id = title.split("- ")[-1][:7]

# concatenating into one list
infotxt = [bill_id, title, yeari, yeara, billtxt]
infotxt

## CONVERT to df

itxtdf = pd.DataFrame(infotxt).transpose()

# rename columns
itxtdf.columns = ['bill_id', 'title', 'y_intro', 'y_recent', 'text']
itxtdf
# Out:
#      status                                               bill
# text     OK  {'bill_id': 1711942, 'change_hash': 'cd9d825f6...
# text     OK  {'bill_id': 1693920, 'change_hash': '464be2cde...
# text     OK  {'bill_id': 1702780, 'change_hash': '266b25df3...
# text     OK  {'bill_id': 1712167, 'change_hash': '37ed87e95...
# text     OK  {'bill_id': 1707639, 'change_hash': '6bddb0f6f...
# text     OK  {'bill_id': 1671132, 'change_hash': '3f4199a2f...
# text     OK  {'bill_id': 1712103, 'change_hash': 'ce1242ff4...
# text     OK  {'bill_id': 1707512, 'change_hash': '85d63281d...
# text     OK  {'bill_id': 1714501, 'change_hash': 'f094de3f6...
# text     OK  {'bill_id': 1738922, 'change_hash': '95e252ff3...
# text     OK  {'bill_id': 1659520, 'change_hash': '6e9c3a09c...
# text     OK  {'bill_id': 1709841, 'change_hash': '3f69d2430...
# text     OK  {'bill_id': 1702725, 'change_hash': '86574f8ad...
# text     OK  {'bill_id': 1714731, 'change_hash': 'b194953c6...
# text     OK  {'bill_id': 1714546, 'change_hash': '32c5c8246...
# text     OK  {'bill_id': 1701021, 'change_hash': '39ac916c6...
# text     OK  {'bill_id': 1714651, 'change_hash': '21338194e...
# text     OK  {'bill_id': 1649742, 'change_hash': 'aa17e5c5d...
# text     OK  {'bill_id': 1693914, 'change_hash': '4fde30eda...
# text     OK  {'bill_id': 1714813, 'change_hash': 'd4bf439ae...
# text     OK  {'bill_id': 1717506, 'change_hash': '95d04db7a...
# text     OK  {'bill_id': 1712067, 'change_hash': 'dd2363f13...
# text     OK  {'bill_id': 1729722, 'change_hash': 'fb63c6e80...
# text     OK  {'bill_id': 1712107, 'change_hash': '48387cd0b...
# text     OK  {'bill_id': 1709716, 'change_hash': '7730c0e81...
# text     OK  {'bill_id': 1700993, 'change_hash': '3c6bcef93...
# text     OK  {'bill_id': 1697043, 'change_hash': 'c0a9f9903...
# text     OK  {'bill_id': 1693918, 'change_hash': '5506b66cd...
# text     OK  {'bill_id': 1693916, 'change_hash': '300dc33d0...
# text     OK  {'bill_id': 1689320, 'change_hash': 'aa0e9982f...
# text     OK  {'bill_id': 1702715, 'change_hash': 'f2bf918eb...
# text     OK  {'bill_id': 1709742, 'change_hash': 'fd8501717...
# text     OK  {'bill_id': 1697060, 'change_hash': 'e291d2447...
# text     OK  {'bill_id': 1693932, 'change_hash': '6f14721d1...
# text     OK  {'bill_id': 1693917, 'change_hash': '01cb29a4d...
# text     OK  {'bill_id': 1709744, 'change_hash': '1b07a1b11...
# text     OK  {'bill_id': 1711952, 'change_hash': '6db38492e...
# text     OK  {'bill_id': 1711977, 'change_hash': '8d9bef99e...
# text     OK  {'bill_id': 1693952, 'change_hash': '921c5f46a...
# text     OK  {'bill_id': 1714485, 'change_hash': 'a15947213...
# text     OK  {'bill_id': 1714521, 'change_hash': 'b42a94762...
# text     OK  {'bill_id': 1709872, 'change_hash': '325a7c834...
# text     OK  {'bill_id': 1707654, 'change_hash': 'f39c94658...
# text     OK  {'bill_id': 1731372, 'change_hash': 'f81a84a14...
# text     OK  {'bill_id': 1711904, 'change_hash': 'bfecfedd7...
# text     OK  {'bill_id': 1724789, 'change_hash': '049dc8121...
# text     OK  {'bill_id': 1691346, 'change_hash': '9bc238120...
# text     OK  {'bill_id': 1712204, 'change_hash': '51e644266...
# text     OK  {'bill_id': 1712049, 'change_hash': 'db9ff52a4...
# text     OK  {'bill_id': 1714818, 'change_hash': 'f5f177fee...
# text     OK  {'bill_id': 1712180, 'change_hash': 'ab3296bf5...
# text     OK  {'bill_id': 1659519, 'change_hash': 'b43f4c4dd...
# text     OK  {'bill_id': 1702767, 'change_hash': '837ce31bb...
# text     OK  {'bill_id': 1649739, 'change_hash': 'a5e2e7863...
# text     OK  {'bill_id': 1712004, 'change_hash': '9d396eef7...
# text     OK  {'bill_id': 1667855, 'change_hash': 'b0fa57373...
# text     OK  {'bill_id': 1714317, 'change_hash': '671f2d892...
# text     OK  {'bill_id': 1702772, 'change_hash': '9f3f0543e...
# text     OK  {'bill_id': 1636426, 'change_hash': 'e0a89e2bd...
# text     OK  {'bill_id': 1709864, 'change_hash': '3c71d76fe...
# text     OK  {'bill_id': 1701039, 'change_hash': '93d11e603...
# text     OK  {'bill_id': 1772423, 'change_hash': '364d09f2d...
# text     OK  {'bill_id': 1707500, 'change_hash': '8a6f05636...
# text     OK  {'bill_id': 1714491, 'change_hash': '6769455b3...
# text     OK  {'bill_id': 1714547, 'change_hash': '69a7ee3ba...
# text     OK  {'bill_id': 1649612, 'change_hash': 'c7f3264e8...
# text     OK  {'bill_id': 1714422, 'change_hash': '3052c3425...
# text     OK  {'bill_id': 1649634, 'change_hash': '251768e06...
# text     OK  {'bill_id': 1714633, 'change_hash': 'ce7358fa7...
# text     OK  {'bill_id': 1709708, 'change_hash': 'e4bac41ab...
# text     OK  {'bill_id': 1714407, 'change_hash': 'ab106d9bf...
# text     OK  {'bill_id': 1691357, 'change_hash': 'aa61d08fc...
# text     OK  {'bill_id': 1759484, 'change_hash': '40cf0ed85...
# text     OK  {'bill_id': 1705874, 'change_hash': '64c223f33...
# text     OK  {'bill_id': 1649639, 'change_hash': 'd8377c0bb...
# text     OK  {'bill_id': 1667833, 'change_hash': '2a0631621...
# text     OK  {'bill_id': 1705803, 'change_hash': '101eab091...
# text     OK  {'bill_id': 1714533, 'change_hash': 'a488ecdef...
# text     OK  {'bill_id': 1698897, 'change_hash': 'eb90c8961...
# text     OK  {'bill_id': 1667860, 'change_hash': '27e4475ee...
# text     OK  {'bill_id': 1702786, 'change_hash': '957ffc61f...
# text     OK  {'bill_id': 1693927, 'change_hash': '8eaae548d...
# text     OK  {'bill_id': 1712034, 'change_hash': '79ed129d8...
# text     OK  {'bill_id': 1707538, 'change_hash': 'c049e28f8...
# text     OK  {'bill_id': 1714704, 'change_hash': 'fb197014f...
# text     OK  {'bill_id': 1649738, 'change_hash': 'a8728aab3...
# text     OK  {'bill_id': 1714551, 'change_hash': '277b9a7cd...
# text     OK  {'bill_id': 1714412, 'change_hash': '137a126bb...
# text     OK  {'bill_id': 1705898, 'change_hash': '732887395...
# text     OK  {'bill_id': 1714709, 'change_hash': 'be43fc426...
# text     OK  {'bill_id': 1691375, 'change_hash': '56cc90bf5...
# text     OK  {'bill_id': 1644455, 'change_hash': '75e63a1c6...
# text     OK  {'bill_id': 1707543, 'change_hash': 'c1a561814...
# text     OK  {'bill_id': 1707490, 'change_hash': '03d1b05b0...
# text     OK  {'bill_id': 1705903, 'change_hash': '9c13a807d...
# text     OK  {'bill_id': 1705902, 'change_hash': 'b1c8090bf...
# text     OK  {'bill_id': 1709774, 'change_hash': '5a3487223...
# text     OK  {'bill_id': 1714532, 'change_hash': 'bb19ee6d0...
# text     OK  {'bill_id': 1702700, 'change_hash': 'c4e66cc00...
# text     OK  {'bill_id': 1714773, 'change_hash': '9fc6a826a...
# text     OK  {'bill_id': 1649614, 'change_hash': 'b382e16ec...
# text     OK  {'bill_id': 1726105, 'change_hash': 'd69ef12e7...
# text     OK  {'bill_id': 1697071, 'change_hash': '36f81c6b9...
# text     OK  {'bill_id': 1667835, 'change_hash': '8879f7a19...
# text     OK  {'bill_id': 1667828, 'change_hash': '09de74990...
# text     OK  {'bill_id': 1702745, 'change_hash': '93a12f3c5...
# text     OK  {'bill_id': 1714319, 'change_hash': 'c35cced74...
# text     OK  {'bill_id': 1771715, 'change_hash': '5d54d92d6...
# text     OK  {'bill_id': 1667847, 'change_hash': '75f22d12a...
# text     OK  {'bill_id': 1702748, 'change_hash': '874e77afc...
# text     OK  {'bill_id': 1698914, 'change_hash': 'f8ccf3508...
# text     OK  {'bill_id': 1714562, 'change_hash': 'd40e5e852...
# text     OK  {'bill_id': 1714634, 'change_hash': 'a265d1588...
# text     OK  {'bill_id': 1649626, 'change_hash': 'd51c3ff53...
# text     OK  {'bill_id': 1731369, 'change_hash': '16546fc93...
# text     OK  {'bill_id': 1667834, 'change_hash': '022fe7499...
# text     OK  {'bill_id': 1652083, 'change_hash': 'e85361333...
# text     OK  {'bill_id': 1652088, 'change_hash': 'a97b642ed...
# text     OK  {'bill_id': 1707695, 'change_hash': '2b2226970...
# text     OK  {'bill_id': 1714444, 'change_hash': 'fc02d80a3...
# text     OK  {'bill_id': 1755204, 'change_hash': '6994b27d1...
# text     OK  {'bill_id': 1649613, 'change_hash': '92d588e4b...
# text     OK  {'bill_id': 1649615, 'change_hash': '37f9dc7ed...
# text     OK  {'bill_id': 1714449, 'change_hash': '050279eab...
# text     OK  {'bill_id': 1705827, 'change_hash': '22ac81092...
# text     OK  {'bill_id': 1714621, 'change_hash': '47303d89f...
# text     OK  {'bill_id': 1714683, 'change_hash': '6a98dbe0f...
# text     OK  {'bill_id': 1712152, 'change_hash': '49df7bb80...
# text     OK  {'bill_id': 1712188, 'change_hash': '328c4a4b7...
# text     OK  {'bill_id': 1691348, 'change_hash': '78f038d6e...
# text     OK  {'bill_id': 1705905, 'change_hash': '0b2d5128d...
# text     OK  {'bill_id': 1667861, 'change_hash': '2ba229342...
# text     OK  {'bill_id': 1709927, 'change_hash': '522e27c83...
# text     OK  {'bill_id': 1705843, 'change_hash': '33585e9a4...
# text     OK  {'bill_id': 1667836, 'change_hash': '8883727ed...
# text     OK  {'bill_id': 1731371, 'change_hash': '03a3e0c4a...
# text     OK  {'bill_id': 1667953, 'change_hash': 'ca2aeab03...
# text     OK  {'bill_id': 1686434, 'change_hash': '3dbdf3756...
# text     OK  {'bill_id': 1667857, 'change_hash': '50bc51977...
# text     OK  {'bill_id': 1772090, 'change_hash': 'e56933e52...
# text     OK  {'bill_id': 1709738, 'change_hash': '792a58ccd...
# text     OK  {'bill_id': 1707647, 'change_hash': '9d03f553f...
# text     OK  {'bill_id': 1705988, 'change_hash': 'f85721e19...
# text     OK  {'bill_id': 1714767, 'change_hash': '33d220426...
# text     OK  {'bill_id': 1707671, 'change_hash': '79c18218b...
# text     OK  {'bill_id': 1649636, 'change_hash': 'd7f1b0dc5...
# text     OK  {'bill_id': 1705844, 'change_hash': 'f0159cdd4...
# text     OK  {'bill_id': 1709925, 'change_hash': '0965b4b99...
# text     OK  {'bill_id': 1759810, 'change_hash': '8cc87d32d...
# text     OK  {'bill_id': 1657752, 'change_hash': '649de8a02...
# text     OK  {'bill_id': 1637884, 'change_hash': 'fd10ffcd3...
# text     OK  {'bill_id': 1705952, 'change_hash': '08d9c317b...
# text     OK  {'bill_id': 1714508, 'change_hash': 'e24390e48...
# text     OK  {'bill_id': 1649640, 'change_hash': '7cd361c3f...
# text     OK  {'bill_id': 1714453, 'change_hash': '90cab0798...
# text     OK  {'bill_id': 1707631, 'change_hash': 'fbdc14b88...
# text     OK  {'bill_id': 1711982, 'change_hash': '2b74383ca...
# text     OK  {'bill_id': 1702834, 'change_hash': '8b2626088...
# text     OK  {'bill_id': 1698948, 'change_hash': 'be07c109b...
# text     OK  {'bill_id': 1709848, 'change_hash': '38050c9b8...
# text     OK  {'bill_id': 1689325, 'change_hash': '1afe77894...
# text     OK  {'bill_id': 1697014, 'change_hash': '12b4db961...
# text     OK  {'bill_id': 1749145, 'change_hash': 'a7cb40f36...
# text     OK  {'bill_id': 1649628, 'change_hash': 'f95bf81f8...
# text     OK  {'bill_id': 1706006, 'change_hash': 'a71151914...
# text     OK  {'bill_id': 1773123, 'change_hash': '03f610642...
# text     OK  {'bill_id': 1667853, 'change_hash': 'ac0007f84...
# text     OK  {'bill_id': 1649632, 'change_hash': '5646aa597...
# text     OK  {'bill_id': 1709901, 'change_hash': '9d1e34a32...
# text     OK  {'bill_id': 1667849, 'change_hash': 'f6646284a...
# text     OK  {'bill_id': 1667850, 'change_hash': 'a53200c24...
# text     OK  {'bill_id': 1649629, 'change_hash': '50b7be8e5...
# text     OK  {'bill_id': 1649630, 'change_hash': 'f59dee709...
# text     OK  {'bill_id': 1667851, 'change_hash': '511075920...
