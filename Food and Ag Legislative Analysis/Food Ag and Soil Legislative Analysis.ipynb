# %% [markdown]
# # Food, Agriculture, and Soils: California Legislation
#
# This notebook explores state level legislation from the Legiscan API. It conducts text analysis of all available California Legislation that mentions food and agriculture from years 20XX to 2023, with special attention to mentions of land, soil, and environmental management.
#
# LegiScan API documentation [here](https://legiscan.com/gaits/documentation/legiscan) and [here](https://api.legiscan.com/dl/).

# %%
# libraries
import pandas as pd
import geopandas as gpd
import numpy as np

import requests
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup

import re
import os
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer
import json

# set display
pd.options.display.max_columns = 150
pd.options.display.max_rows = 300

# %% [markdown]
# First, I will pull the bill ID, year/session, and full texts for all CA legisation that passed mentioning "food" and "agriculture".
#
# Then I will narrow my search to all bills mentioning "food", "agriculture", "environment", and "soil".
#
# I will store relevant information into a dictionary that can be transformed into a pandas dataframe.
#
# Pull API template: "https://api.legiscan.com/?key=APIKEY&op=OPERATION&PARAMS"
# APIKey = '7e00040f1f7618af234e7415484d2494'
#
# **OPERATIONS**
# getBill, getBillText, getSearch, getSearchRaw
#
# **PARAMETERS**
# state, year, query (URL encoded), page
#
# **IDENTIFIERS**
# bill_id, doc_id

# %%
# request: CA, food and ag, results for current year
requeststring = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=2&query=food%20and%20agriculture"

# %%
# pull request: getting results as JSON object
r = requests.get(requeststring)

# %%
# examining results
#print(r.text)

# %%
# turning JSON object into a dict
dict1 = json.loads(r.text)

# %%
# examining structure of dictionary and identifying relevant keys
print(dict1.keys())
print(dict1['searchresult'].keys())
print(dict1['searchresult']['summary'].keys())
print(dict1['searchresult']['results'])
# Out:
# dict_keys(['status', 'searchresult'])
# dict_keys(['summary', 'results'])
# dict_keys(['page', 'range', 'relevancy', 'count', 'page_current', 'page_total', 'query'])
# [{'relevance': 100, 'bill_id': 1711942, 'change_hash': 'cd9d825f6d643ff19d5d789db7760174'}, {'relevance': 99, 'bill_id': 1693920, 'change_hash': '464be2cde28c223849b4efe7d1b2e894'}, {'relevance': 99, 'bill_id': 1702780, 'change_hash': '266b25df310d9ebd3e42bb97fdec3adf'}, {'relevance': 99, 'bill_id': 1712167, 'change_hash': '37ed87e95a3bc0627706e74408a2a63a'}, {'relevance': 99, 'bill_id': 1707639, 'change_hash': '6bddb0f6f615ed90a9bafc8ec369b181'}, {'relevance': 99, 'bill_id': 1671132, 'change_hash': '3f4199a2ffe1d27113d5607be727e6db'}, {'relevance': 99, 'bill_id': 1712103, 'change_hash': 'ce1242ff43bcfe48ae2d9a3325bd5959'}, {'relevance': 99, 'bill_id': 1707512, 'change_hash': '85d63281d189d8a6f47466e7268baa96'}, {'relevance': 99, 'bill_id': 1714501, 'change_hash': 'f094de3f6fb0046b0ab05b73f8ae9b46'}, {'relevance': 99, 'bill_id': 1738922, 'change_hash': '95e252ff327015dca16387a7a55cb1e7'}, {'relevance': 99, 'bill_id': 1659520, 'change_hash': '6e9c3a09cddb8be6373ce89f3c06252f'}, {'relevance': 99, 'bill_id': 1709841, 'change_hash': '3f69d2430058bab34c1d0fe4df45c135'}, {'relevance': 99, 'bill_id': 1702725, 'change_hash': '86574f8adac15933050524775e0680a3'}, {'relevance': 99, 'bill_id': 1714731, 'change_hash': 'b194953c61c2c8f8857b17bf2afe8843'}, {'relevance': 99, 'bill_id': 1714546, 'change_hash': '32c5c8246ca8a7a5fad33d152fc7f4c2'}, {'relevance': 99, 'bill_id': 1701021, 'change_hash': '39ac916c6a0c97e9fe5dda5ca2568434'}, {'relevance': 99, 'bill_id': 1714651, 'change_hash': '21338194ea4334aa90cfa2bd048f39d8'}, {'relevance': 99, 'bill_id': 1649742, 'change_hash': 'aa17e5c5dfb995948f9b2dc8326b01da'}, {'relevance': 99, 'bill_id': 1693914, 'change_hash': '4fde30edaecd69924af8e06613eaf47a'}, {'relevance': 99, 'bill_id': 1714813, 'change_hash': 'd4bf439ae0cce4fe1bf2de42374fbdf7'}, {'relevance': 99, 'bill_id': 1717506, 'change_hash': '95d04db7a95485a95627f9dedb8ccad6'}, {'relevance': 99, 'bill_id': 1712067, 'change_hash': 'dd2363f13f6032610cc3631fd13cbcda'}, {'relevance': 99, 'bill_id': 1729722, 'change_hash': 'fb63c6e80bb441dc5837f850baebc4b8'}, {'relevance': 99, 'bill_id': 1712107, 'change_hash': '48387cd0be4a6e03e0452fe04cdd0570'}, {'relevance': 99, 'bill_id': 1709716, 'change_hash': '7730c0e817cfd0db3f3b76edaef657a9'}, {'relevance': 99, 'bill_id': 1700993, 'change_hash': '3c6bcef9309e3595416a54290d7cbbf4'}, {'relevance': 99, 'bill_id': 1697043, 'change_hash': 'c0a9f9903c46147e51fde14ad1eafb0e'}, {'relevance': 99, 'bill_id': 1693918, 'change_hash': '5506b66cdbd10c69ba310a41768c95ec'}, {'relevance': 99, 'bill_id': 1693916, 'change_hash': '300dc33d000216b97b40159ee402815f'}, {'relevance': 99, 'bill_id': 1689320, 'change_hash': 'aa0e9982faeeadab3a977384c572dd40'}, {'relevance': 99, 'bill_id': 1702715, 'change_hash': 'f2bf918eb24ac7dc0c58545f8aa76d46'}, {'relevance': 99, 'bill_id': 1709742, 'change_hash': 'fd85017179beb8f6e27f446fb4394fc4'}, {'relevance': 99, 'bill_id': 1697060, 'change_hash': 'e291d244793b1d248f76a727d6f7caee'}, {'relevance': 99, 'bill_id': 1693932, 'change_hash': '6f14721d1291976b9dddf7696569a1a3'}, {'relevance': 98, 'bill_id': 1693917, 'change_hash': '01cb29a4d5af97c81ffd684193e68258'}, {'relevance': 98, 'bill_id': 1709744, 'change_hash': '1b07a1b119a52cf93887bb53afb61c92'}, {'relevance': 98, 'bill_id': 1711952, 'change_hash': '6db38492ec97b16ce6c9c83e7bcd25b0'}, {'relevance': 98, 'bill_id': 1711977, 'change_hash': '8d9bef99e03043d2e31ced93dd469670'}, {'relevance': 98, 'bill_id': 1693952, 'change_hash': '921c5f46af05b53ace33b7d500485c2e'}, {'relevance': 98, 'bill_id': 1714485, 'change_hash': 'a15947213d0244fc394a27b5a9a9875b'}, {'relevance': 98, 'bill_id': 1714521, 'change_hash': 'b42a94762fb407f6ba2e692e66695531'}, {'relevance': 98, 'bill_id': 1709872, 'change_hash': '325a7c834b76a5547735843a092e4d37'}, {'relevance': 98, 'bill_id': 1707654, 'change_hash': 'f39c946580f56d34871d74c3f9ba29e8'}, {'relevance': 98, 'bill_id': 1731372, 'change_hash': 'f81a84a14845244ab7011ab249dcc8f9'}, {'relevance': 98, 'bill_id': 1711904,  ...

# %%
# creating subset dict with only keys of interest
list1 = dict1['searchresult']['results']
list1[:5]
# Out:
# [{'relevance': 100,
#   'bill_id': 1711942,
#   'change_hash': 'cd9d825f6d643ff19d5d789db7760174'},
#  {'relevance': 99,
#   'bill_id': 1693920,
#   'change_hash': '464be2cde28c223849b4efe7d1b2e894'},
#  {'relevance': 99,
#   'bill_id': 1702780,
#   'change_hash': '266b25df310d9ebd3e42bb97fdec3adf'},
#  {'relevance': 99,
#   'bill_id': 1712167,
#   'change_hash': '37ed87e95a3bc0627706e74408a2a63a'},
#  {'relevance': 99,
#   'bill_id': 1707639,
#   'change_hash': '6bddb0f6f615ed90a9bafc8ec369b181'}]

# %%
# generating list of bill_ids
# https://www.geeksforgeeks.org/python-get-values-of-particular-key-in-list-of-dictionaries/
bills = [value['bill_id'] for value in list1]
bills[:5]
# Out:
# [1711942, 1693920, 1702780, 1712167, 1707639]

# %%
# turning list of bill_ids for each relevant result from query into a df
df = pd.DataFrame(bills, columns = ['bill_id'])
df.head()
# Out:
#    bill_id
# 0  1711942
# 1  1693920
# 2  1702780
# 3  1712167
# 4  1707639

# %%
# sampling bill pull
bill1 = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id=1711942'
b = requests.get(bill1)
binfo = json.loads(b.text)
print(binfo.keys()) 
print(binfo)
# Out:
# dict_keys(['status', 'bill'])
# {'status': 'OK', 'bill': {'bill_id': 1711942, 'change_hash': 'cd9d825f6d643ff19d5d789db7760174', 'session_id': 2016, 'session': {'session_id': 2016, 'state_id': 5, 'year_start': 2023, 'year_end': 2024, 'prefile': 0, 'sine_die': 0, 'prior': 0, 'special': 0, 'session_tag': 'Regular Session', 'session_title': '2023-2024 Regular Session', 'session_name': '2023-2024 Session'}, 'url': 'https://legiscan.com/CA/bill/AB1197/2023', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billStatusClient.xhtml?bill_id=202320240AB1197', 'completed': 0, 'status': 2, 'status_date': '2023-05-30', 'progress': [{'date': '2023-02-16', 'event': 1}, {'date': '2023-03-02', 'event': 9}, {'date': '2023-03-13', 'event': 10}, {'date': '2023-03-14', 'event': 9}, {'date': '2023-04-19', 'event': 10}, {'date': '2023-04-19', 'event': 9}, {'date': '2023-05-10', 'event': 9}, {'date': '2023-05-18', 'event': 10}, {'date': '2023-05-30', 'event': 2}, {'date': '2023-05-31', 'event': 9}, {'date': '2023-06-07', 'event': 9}, {'date': '2023-06-12', 'event': 10}, {'date': '2023-06-12', 'event': 9}, {'date': '2023-06-22', 'event': 10}, {'date': '2023-06-26', 'event': 9}, {'date': '2023-07-05', 'event': 10}, {'date': '2023-07-05', 'event': 9}], 'state': 'CA', 'state_id': 5, 'bill_number': 'AB1197', 'bill_type': 'B', 'bill_type_id': '1', 'body': 'A', 'body_id': 19, 'current_body': 'S', 'current_body_id': 20, 'title': 'Agricultural Protection Planning Grant Program: local food producers.', 'description': 'An act to amend Sections 10280, 10280.5, and 10282 of the Public Resources Code, relating to agricultural lands.', 'pending_committee_id': 475, 'committee': {'committee_id': 475, 'chamber': 'S', 'chamber_id': 20, 'name': 'Appropriations'}, 'referrals': [{'date': '2023-03-02', 'committee_id': 448, 'chamber': 'A', 'chamber_id': 19, 'name': 'Agriculture'}, {'date': '2023-04-19', 'committee_id': 449, 'chamber': 'A', 'chamber_id': 19, 'name': 'Appropriations'}, {'date': '2023-05-31', 'committee_id': 489, 'chamber': 'S', 'chamber_id': 20, 'name': 'Rules'}, {'date': '2023-06-07', 'committee_id': 485, 'chamber': 'S', 'chamber_id': 20, 'name': 'Natural Resources and Water'}, {'date': '2023-06-22', 'committee_id': 2523, 'chamber': 'S', 'chamber_id': 20, 'name': 'Agriculture'}, {'date': '2023-07-05', 'committee_id': 475, 'chamber': 'S', 'chamber_id': 20, 'name': 'Appropriations'}], 'history': [{'date': '2023-02-16', 'action': 'Read first time. To print.', 'chamber': 'A', 'chamber_id': 19, 'importance': 1}, {'date': '2023-02-17', 'action': 'From printer. May be heard in committee March 19.', 'chamber': 'A', 'chamber_id': 19, 'importance': 0}, {'date': '2023-03-02', 'action': 'Referred to Com. on AGRI.', 'chamber': 'A', 'chamber_id': 19, 'importance': 1}, {'date': '2023-03-13', 'action': "From committee chair, with author's amendments: Amend, and re-refer to Com. on AGRI. Read second time and amended.", 'chamber': 'A', 'chamber_id': 19, 'importance': 1}, {'date': '2023-03-14', 'action': 'Re-referred to Com. on AGRI.', 'chamber': 'A', 'chamber_id': 19, 'importance': 1}, {'date': '2023-04-19', 'action': 'From committee: Do pass and re-refer to Com. on APPR. (Ayes 11. Noes 0.) (April 19). Re-referred to Com. on APPR.', 'chamber': 'A', 'chamber_id': 19, 'importance': 1}, {'date': '2023-05-10', 'action': 'In committee: Set, first hearing. Referred to APPR. suspense file.', 'chamber': 'A', 'chamber_id': 19, 'importance': 1}, {'date': '2023-05-18', 'action': 'From committee: Amend, and do pass as amended. (Ayes 12. Noes 1.) (May 18).', 'chamber': 'A', 'chamber_id': 19, 'importance': 1}, {'date': '2023-05-18', 'action': 'Read second time and amended. Ordered returned to second reading.', 'chamber': 'A', 'chamber_id': 19, 'importance': 0}, {'date': '2023-05-22', 'action': 'Read second time. Ordered to third reading.', 'chamber': 'A', 'chamber_id': 19, 'importance': 0}, {'date': '2023-05-30', 'action': 'Read third time. Passed. Ordered to the Senate. (Ayes 66. Noes 2.)', 'chamber': 'A', 'chamb ...

# %%
# exploring structure and extracting doc_ids from bill
print(binfo.keys())
print(binfo['bill'].keys())
print(binfo['bill']['texts'])
# Out:
# dict_keys(['status', 'bill'])
# dict_keys(['bill_id', 'change_hash', 'session_id', 'session', 'url', 'state_link', 'completed', 'status', 'status_date', 'progress', 'state', 'state_id', 'bill_number', 'bill_type', 'bill_type_id', 'body', 'body_id', 'current_body', 'current_body_id', 'title', 'description', 'pending_committee_id', 'committee', 'referrals', 'history', 'sponsors', 'sasts', 'subjects', 'texts', 'votes', 'amendments', 'supplements', 'calendar'])
# [{'doc_id': 2704856, 'date': '2023-02-16', 'type': 'Introduced', 'type_id': 1, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2704856', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#99INT', 'text_size': 7488, 'text_hash': 'b048ef4ee2d51bcb0266641e75d77798', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2743399, 'date': '2023-03-13', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2743399', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#98AMD', 'text_size': 16765, 'text_hash': '6c6473e25573a816224c51042f38df4c', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2814717, 'date': '2023-05-18', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2814717', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#97AMD', 'text_size': 15111, 'text_hash': '75d49ee492b6398604544bb921295627', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2826589, 'date': '2023-06-12', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2826589', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#96AMD', 'text_size': 15450, 'text_hash': 'e9f9e9a599422bc4e8dc0913f2f02a8a', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}, {'doc_id': 2830807, 'date': '2023-06-26', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2830807', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#95AMD', 'text_size': 16144, 'text_hash': 'ad35b5cac4cbc4fc4fb154c8f1ed301b', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': ''}]

# %%
# isolating list of dictionaries
doclist = binfo['bill']['texts']

# %%
# generating list of bill_ids
docs = [sub['doc_id'] for sub in doclist]
docs
# Out:
# [2704856, 2743399, 2814717, 2826589, 2830807]

# %%
# indexing last element (most recently amended version of bill text)
docs[-1]
# Out:
# 2830807

# %%
# sampling bill text pull
btext1 = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBillText&id=2830807'
b = requests.get(btext1)
btext = json.loads(b.text)
print(btext.keys()) 
print(btext)
# Out:
# dict_keys(['status', 'text'])
# {'status': 'OK', 'text': {'doc_id': 2830807, 'bill_id': 1711942, 'date': '2023-06-26', 'type': 'Amended', 'type_id': 3, 'mime': 'text/html', 'mime_id': 1, 'url': 'https://legiscan.com/CA/text/AB1197/id/2830807', 'state_link': 'https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#95AMD', 'text_size': 16144, 'text_hash': 'ad35b5cac4cbc4fc4fb154c8f1ed301b', 'doc': '...', 'alt_bill_text': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_state_link': '', 'alt_text_size': 0, 'alt_text_hash': '', 'alt_doc': ''}}

# %%
# exploring structure
print(btext.keys())
print(btext['text'].keys())
print(btext['text']['url'])
print(btext['text']['state_link']) # this URL less likely to turn up errors
# Out:
# dict_keys(['status', 'text'])
# dict_keys(['doc_id', 'bill_id', 'date', 'type', 'type_id', 'mime', 'mime_id', 'url', 'state_link', 'text_size', 'text_hash', 'doc', 'alt_bill_text', 'alt_mime', 'alt_mime_id', 'alt_state_link', 'alt_text_size', 'alt_text_hash', 'alt_doc'])
# https://legiscan.com/CA/text/AB1197/id/2830807
# https://leginfo.legislature.ca.gov/faces/billTextClient.xhtml?bill_id=202320240AB1197#95AMD

# %%
# extracting text from bill text url
URL = btext['text']['state_link']
r = urlopen(URL)
html_bytes = r.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, features='html.parser')

# %%
# inspecting structure to locate text bloc
print(soup.prettify())
# Out:
# <?xml version='1.0' encoding='UTF-8' ?>
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head id="j_idt5">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!--&lt;meta http-equiv="refresh" content=";url=faces/home.xhtml"/&gt;-->
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_master.css" media="screen   ,print" rel="stylesheet" type="text/css"/>
#   <!--&lt;link rel="stylesheet" type="text/css" href="./resources/css/leginfo_mobile.css" media="screen and (-webkit-min-device-pixel-ratio: 1.1) and (max-device-width: 990px)" /&gt;
#     &lt;link rel="stylesheet" type="text/css" href="./resources/css/leginfo_mobile.css" media="screen and (min-device-width: 481px)and (max-device-width: 640px)and (-webkit-max-device-pixel-ratio: 1)" /&gt;-->
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_mobile.css" media="screen and (orientation: portrait) and (max-device-width: 767px),screen and (orientation: landscape)  and (-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" rel="stylesheet" type="text/css"/>
#   <!--&lt;link rel="stylesheet" type="text/css" href="./resources/css/leginfo_mobile_low_res.css" media="screen and (max-device-width: 480px)and (-webkit-max-device-pixel-ratio: 1)" /&gt;-->
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_print.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_codes.css" media="screen,print" rel="stylesheet" type="text/css"/>
#   <title>
#    Bill Text  - AB-1197 Agricultural Protection Planning Grant Program: local food producers.
#   </title>
#   <link href="favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <style>
#    /* Hide page by default*/
#       html { display : none; }
#   </style>
#   <script type="text/javascript">
#    //<![CDATA[
#
#       if (self===top) {
#         // Show the page
#         document.documentElement.style.display='block';
#       } else {
#         // Inside a frame. Replace the frame.
#         var parentUrl=document.referrer;
#         var num=-1;
#         if (parentUrl!=='') {
#
#           num=parseInt(parentUrl.indexOf('calchannel.granicus.com'));
#
#           if (!(num>=0)) {
#             window.top.location.replace(window.location);
#             top.location=self.location;
#           }
#         }
#       }
#       // ]]>
#   </script>
#   <style>
#    /* Hide page by default*/
#       html { display : inline; }
#   </style>
#  </head>
#  <body>
#   <span id="j_idt12">
#    <script language="javascript" type="text/javascript">
#     //<![CDATA[
# function faceletsDebug(URL) {day = new Date();id = day.getTime();eval("page" + id + " = window.open(URL, '" + id + "', 'toolbar=0,scrollbars=1,location=0,statusbar=0,menubar=0,resizable=1,width=800,height=600,left = 240,top = 212');"); };(function() { if (typeof jsfFaceletsDebug === 'undefined') { var jsfFaceletsDebug = false; } if (!jsfFaceletsDebug) {var faceletsOrigKeyup = document.onkeyup;document.onkeyup = function(e) { if (window.event) e = window.event; if (String.fromCharCode(e.keyCode) == 'D' & e.shiftKey & e.ctrlKey) faceletsDebug('/faces/billTextClient.xhtml?facelets.ui.DebugOutput=1691070197820'); jsfFaceletsDebug = true; if (faceletsOrigKeyup) faceletsOrigKeyup(e); };
# }})();//]]>
#    </script>
#   </span>
#   <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#    <script language="JavaScript">
#     function changePlaceHolder() {
#             var x = document.getElementById("billheaderinit_form:quick_search_select_id");
#             var input = document.getElementById("billheaderinit_form:searchall");
#
#             if (x !== null) {
#                 for (i = 0; i < x.options.length; i++) {
#                     if (x.options[i].selected) {
#                         if (x.options[i].value === 'billKeyword') {
#                             input.placeholder = "Search phrase";
#                         } else {
#                             input.placeholder = "AB1 or ab 1 or ABX1-1";
#                         }
#                     }
#                 }
#             }
#         }
#    </script>
#    <body onload="changePlaceHolder()">
#     <form action="/faces/billTextClient.xhtml" enctype="application/x-www-form-urlencoded" id="billheaderinit_form" method="post" name="billheaderinit_form">
#      <input name="billheaderinit_form" type="hidden" value="billheaderinit_form"/>
#      <!--&lt;div class="skip textright"&gt;&lt;/div&gt;-->
#      <!-- END: skip textright div -->
#      <div id="banner">
#       <div class="horznavigation textright" id="system">
#        <ul>
#         <li>
#          <a href="#content_anchor">
#           skip to content
#          </a>
#         </li>
#         <li>
#          <script src="/faces/javax.faces.resource/jsf.js?ln=javax.faces" type="text/javascript">
#          </script>
#          <a href="#" id="billheaderinit_form:nav_bar_link_home" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_home':'billheaderinit_form:nav_bar_link_home'},'');return false">
#           home
#          </a>
#         </li>
#         <li>
#          <a href="#" id="billheaderinit_form:nav_bar_link_accessibility" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_accessibility':'billheaderinit_form:nav_bar_link_accessibility'},'');return false">
#           accessibility
#          </a>
#         </li>
#         <li>
#          <a href="#" id="billheaderinit_form:nav_bar_link_faq" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_faq':'billheaderinit_form:nav_bar_link_faq'},'');return false">
#           FAQ
#          </a>
#         </li>
#         <li>
#          <a href="#" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:j_idt27':'billheaderinit_form:j_idt27','destPage':'feedbackNewidea.xhtml'},'');return false">
#           feedback
#          </a>
#         </li>
#         <li>
#          <a href="#" id="billheaderinit_form:nav_bar_link_sitemap" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:nav_bar_link_sitemap':'billheaderinit_form:nav_bar_link_sitemap'},'');return false">
#           sitemap
#          </a>
#         </li>
#         <!--  &lt;li&gt; &lt;h:link outcome="loginClient" rendered="true"&gt;
#                                   &lt;h:outputText value="login"/&gt;
#                                   &lt;f:param name="destPage" value="home.xhtml"&gt;&lt;/f:param&gt;
#                               &lt;/h:link&gt;
#                         &lt;/li&gt;-->
#         <li>
#          <a href="#" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:j_idt33':'billheaderinit_form:j_idt33','destPage':'home.xhtml'},'');return false">
#           login
#          </a>
#         </li>
#         <li>
#          <span style="visibility:hidden;">
#           x
#          </span>
#         </li>
#         <!-- invisible span removes IE horiz window scroll bar -->
#         <!--&lt;li&gt;&lt;h:commandLink id="nav_bar_link_espanol" action="{profile_Backing.changeLocaleToES}"&gt;&lt;h:outputText value="{profile_Backing.language}"/&gt;&lt;/h:commandLink&gt;&lt;/li&gt;-->
#        </ul>
#       </div>
#       <!-- END: system div -->
#       <!-- BEGIN quick search -->
#       <div id="logo">
#        <a href="#" id="billheaderinit_form:header_img" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:header_img':'billheaderinit_form:header_img'},'');return false">
#         <img alt="Legislative Information header image: click to go to the home page" id="capitol" src="/resources/images/header_img.png"/>
#        </a>
#       </div>
#       <!-- END: logo div -->
#       <div id="logo_mobile">
#        <img alt="Legislative Information header image" id="capitol_mobile1" src="/resources/images/header_img_mobile_01.png"/>
#        <a href="#" id="billheaderinit_form:header_img_mobile2" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:header_img_mobile2':'billheaderinit_form:header_img_mobile2'},'');return false">
#         <img alt="home image: click to go to the home page" id="capitol_mobile2" src="/resources/images/header_img_mobile_02.png"/>
#        </a>
#        <a href="#" id="billheaderinit_form:header_img_mobile25" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:header_img_mobile25':'billheaderinit_form:header_img_mobile25'},'');return false">
#         <img alt="Bill Search image: click to go to the bill search page" id="capitol_mobile25" src="/resources/images/header_img_mobile_025.png"/>
#        </a>
#        <a href="" onclick="history.back();                             return false;">
#         <img alt="back button image: click to go to previous page" id="capitol_mobile3" src="/resources/images/header_img_mobile_03.png"/>
#        </a>
#        <br/>
#        <img alt="Legislative Information text image" id="capitol_mobile4" src="/resources/images/header_img_mobile_04.png"/>
#       </div>
#       <div id="billheaderinit_form:quick_search_div">
#        <div id="quick_search">
#         <div id="quick_search_text">
#          <img alt="magnifying glass image" id="quick_search_mag_glass" src="/resources/images/mag_glass.png"/>
#          <label for="billheaderinit_form:quick_search_select_id">
#           Quick Search:
#          </label>
#         </div>
#         <div id="quick_search_form">
#          <select id="billheaderinit_form:quick_search_select_id" name="billheaderinit_form:quick_search_select_id" onchange="changePlaceHolder()" size="1" style="background-color: #fff ; color:#0D0D0D;">
#           <option value="billNumber">
#            Bill Number
#           </option>
#           <option value="billKeyword">
#            Bill Keyword
#           </option>
#          </select>
#          <!-- &lt;select id="quick_search_select_id" &gt;
#                              &lt;option value="billNumber"&gt;Bill Number&lt;/option&gt;
#                              &lt;option value="billKeyword"&gt;Bill Keyword&lt;/option&gt;
#                              &lt;option value="billCode"&gt;Code&lt;/option&gt;
#                              &lt;/select&gt;-->
#          <input aria-label="Bill number / Keyword" id="billheaderinit_form:searchall" maxlength="2048" name="billheaderinit_form:searchall" onkeypress="if (event.keyCode == 13) {                                                      document.getElementById('billheaderinit_form:quick_search_submit').click();                                                      return false;                                                  }                                                  ;                                                  return true;" placeholder="AB1 or ab 1 or ABX1-1" size="13" type="text"/>
#          <input class="quick_search_submit" id="billheaderinit_form:quick_search_submit" name="billheaderinit_form:quick_search_submit" onmouseout="this.className = 'quick_search_submit'" onmouseover="this.className = 'quick_search_submit_hover'" type="submit" value="go"/>
#         </div>
#        </div>
#        <!-- END  quick search -->
#       </div>
#      </div>
#      <!-- END: banner div -->
#      <!-- End Header -->
#      <!-- End Header -->
#      <!-- Begin Navigation -->
#      <html xmlns="http://www.w3.org/1999/xhtml">
#       <link href="https://leginfo.legislature.ca.gov/resources/css/navigation.css" media="screen,print" rel="stylesheet" type="text/css"/>
#       <!--  &lt;link rel="stylesheet" type="text/css" href="/resources/css/leginfo_mobile.css"
#         media="screen and (orientation: portrait) and (max-device-width: 767px),
#         screen and (orientation: landscape) and (max-device-height: 750px)" /&gt;-->
#       <link href="https://leginfo.legislature.ca.gov/resources/css/leginfo_mobile.css" media="screen and (orientation: portrait) and (max-device-width: 767px),screen and (orientation: landscape)             and (-webkit-min-device-pixel-ratio: 2) and (min-resolution: 192dpi)" rel="stylesheet" type="text/css"/>
#       <!-- Start Navigation -->
#       <div id="tabs">
#        <ul>
#         <!-- CSS Tabs -->
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:home_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:home_link':'billheaderinit_form:home_link'},'');return false">
#           <span class="nav_text">
#            Home
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_selected" href="#" id="billheaderinit_form:bill_info_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:bill_info_link':'billheaderinit_form:bill_info_link'},'');return false">
#           <span class="nav_text">
#            Bill Information
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:codes_info_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:codes_info_link':'billheaderinit_form:codes_info_link'},'');return false">
#           <span class="nav_text">
#            California Law
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:pubs_info_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:pubs_info_link':'billheaderinit_form:pubs_info_link'},'');return false">
#           <span class="nav_text">
#            Publications
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:resources_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:resources_link':'billheaderinit_form:resources_link'},'');return false">
#           <span class="nav_text">
#            Other Resources
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:my_bills_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:my_bills_link':'billheaderinit_form:my_bills_link'},'');return false">
#           <span class="nav_text">
#            My Subscriptions
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nav_not_selected" href="#" id="billheaderinit_form:my_favs_link" onclick="mojarra.jsfcljs(document.getElementById('billheaderinit_form'),{'billheaderinit_form:my_favs_link':'billheaderinit_form:my_favs_link'},'');return false">
#           <span class="nav_text">
#            My Favorites
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <!-- End Navigation -->
#      </html>
#      <input autocomplete="off" id="j_id1:javax.faces.ViewState:0" name="javax.faces.ViewState" type="hidden" value="..."/>
#     </form>
#     <a id="content_anchor" name="content_anchor">
#     </a>
#    </body>
#   </html>
#   <div id="content_main">
#    <!-- Main content -->
#    <div class="column centercolumntwo" id="centercolumn">
#     <!-- BEGIN: breadcrumb -->
#     <!--
# To change this license header, choose License Headers in Project Properties.
# To change this template file, choose Tools | Templates
# and open the template in the editor.
# -->
#     <html xmlns="http://www.w3.org/1999/xhtml">
#      <body>
#       <div class="horznavigation" id="breadcrumbs">
#        <ul>
#         <li>
#          <a href="/faces/billSearchClient.xhtml">
#           Bill Information
#          </a>
#          &gt;&gt;
#         </li>
#         <li>
#          <a href="/faces/billSearchClient.xhtml">
#           Bill Search
#          </a>
#          &gt;&gt;
#         </li>
#         <li>
#          Text
#         </li>
#        </ul>
#       </div>
#      </body>
#     </html>
#     <!-- END: breadcrumb -->
#     <h1>
#      Bill Text
#     </h1>
#     <div id="bill_text_navigation">
#      <html xmlns="http://www.w3.org/1999/xhtml">
#       <!--&lt;script type="text/javascript"&gt;-->
#       <script language="javascript" type="text/javascript">
#        function asAmendsPopup() {
#             window.open("asAmendsInfo.xhtml", "Information", "width=330, height=220, toolbar=no, location=no, directories=no, menubar=no, scrollbars=no, top=270, left=150")
#         }
#
#         function selectVersion() {
#
#             var versionObj = document.getElementById("version");
#             var selectedVersionId = '20230AB119795AMD';
#             var len = versionObj.options.length;
#             //alert('selectedVersionId='+selectedVersionId);
#             for (i = 0; i < len; i++) {
#                 if (versionObj.options[i].value == selectedVersionId) {
#                     versionObj.options[i].selected = true;
#                 }
#             }
#         }
#
#         function  downLoadPDF() {
#             document.getElementById("pdf_link2").click();
#         }
#       </script>
#       <body>
#        <form action="/faces/billTextClient.xhtml" enctype="application/x-www-form-urlencoded" id="billDetailTopNavBarId" method="post" name="billDetailTopNavBarId">
#         <input name="billDetailTopNavBarId" type="hidden" value="billDetailTopNavBarId"/>
#         <input id="bid" name="bid" type="hidden" value="202320240AB1197"/>
#         <input id="vid" name="vid" type="hidden" value="20230AB119795AMD"/>
#         <div id="bill_header">
#          <br/>
#          <div id="bill_version" style="margin-top: 1em;">
#           <a aria-hidden="true" class="bill_nav_sub_mobile" hidden="true" href="#" id="pdf_link2" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'pdf_link2':'pdf_link2','bill_id':'202320240AB1197','version':''},'');return false" style="display:none" type="hidden">
#            PDF2
#           </a>
#           <a href="/faces/billPdf.xhtml?bill_id=202320240AB1197&amp;version=20230AB119795AMD" onclick="downLoadPDF();                                 return false;">
#            Bill PDF
#           </a>
#           <!--TODO:: Add rendered condition above-->
#           <!--rendered="{billDetail_Backing.billDetailBean.isCurrentSession}"-->
#           <!--                &lt;h:link outcome="billTextClient"  includeViewParams="true" target="_blank" &gt;
#                                         &lt;h:outputText value="click"/&gt;
#                                         &lt;f:viewParam name="bill_id" value="{billDetailText.billId}"/&gt;
#                                         &lt;f:viewParam name="version" value="{billDetailText.version}"/&gt;
#
#                                     &lt;/h:link&gt;-->
#           <span class="bill_nav_sub_mobile">
#            |
#           </span>
#           <a class="bill_nav_sub_mobile" href="#" id="myfavs_link" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'myfavs_link':'myfavs_link','bill_id':'202320240AB1197'},'');return false" style="margin-left: .8em;">
#            Add To My Favorites
#           </a>
#           <span class="bill_nav_sub_mobile">
#            |
#           </span>
#           <a class="bill_nav_sub_mobile" href="#" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'j_idt119':'j_idt119','bill_id':'202320240AB1197'},'');return false" style="margin-left: .8em;">
#            Track Bill
#           </a>
#           <span class="bill_nav_sub_mobile" style="margin:0 .5em 0 .5em;">
#            |
#           </span>
#           <label for="version">
#            Version:
#           </label>
#           <select class="bill_version_select" id="version" name="version" size="1">
#            <option value="20230AB119795AMD">
#             06/26/23 - Amended Senate
#            </option>
#            <option value="20230AB119796AMD">
#             06/12/23 - Amended Senate
#            </option>
#            <option value="20230AB119797AMD">
#             05/18/23 - Amended Assembly
#            </option>
#            <option value="20230AB119798AMD">
#             03/13/23 - Amended Assembly
#            </option>
#            <option value="20230AB119799INT">
#             02/16/23 - Introduced
#            </option>
#           </select>
#           <input class="bill_version_go" id="ddbill_version" name="ddbill_version" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'ddbill_version':'ddbill_version','bill_id':'202320240AB1197','version':''},'');return false" type="submit" value="Go"/>
#           <!--{billDetail_Backing.reloadPageForNewVersion}-->
#           <span class="bill_nav_sub_mobile" style="margin:0 .5em 0 .5em;">
#           </span>
#           <a class="bill_nav_sub_mobile" href="#" onclick="jsf.util.chain(this,event,'javascript:window.print();                             return false;','mojarra.jsfcljs(document.getElementById(\'billDetailTopNavBarId\'),{\'j_idt133\':\'j_idt133\'},\'\')');return false" title="Print Bills1">
#            <img alt="print page" src="/resources/images/print_24.gif"/>
#           </a>
#          </div>
#          <div>
#           <h1 style="display:block; text-align: left; font-size: 18px; font-weight: bold;border-bottom: none; white-space: nowrap; font-family:  Verdana, Arial, helvetica, sans-serif; text-transform: none; padding-top:  .2em;">
#            AB-1197 Agricultural Protection Planning Grant Program: local food producers.
#            <span class="bill_title_yr">
#             (2023-2024)
#            </span>
#           </h1>
#          </div>
#         </div>
#         <div id="tab_panel">
#          <span class="tab_simple_start tab_selected">
#           <a class="tab_link" href="/faces/billTextClient.xhtml?bill_id=202320240AB1197" id="nav_bar_top_text" name="nav_bar_top_text">
#            <span class="float_left" title="Bill Text">
#             Text
#            </span>
#            <!--&lt;f:param name="bill_id" value="{billDetail_Backing.billId}"&gt;&lt;/f:param&gt;-->
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billVotesClient.xhtml?bill_id=202320240AB1197" id="nav_bar_top_votes" name="nav_bar_top_votes">
#            <span class="float_left" title="Bill Votes">
#             Votes
#            </span>
#            <!--&lt;f:param name="bill_id" value="{billDetail_Backing.billId}"&gt;&lt;/f:param&gt;-->
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billHistoryClient.xhtml?bill_id=202320240AB1197" id="nav_bar_top_history" name="nav_bar_top_history">
#            <span class="float_left" title="Bill History">
#             History
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billAnalysisClient.xhtml?bill_id=202320240AB1197" id="nav_bar_top_analysis" name="nav_bar_top_analysis" title="Bill Analysis">
#            <span class="float_left">
#             Bill Analysis
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billCompareClient.xhtml?bill_id=202320240AB1197&amp;showamends=false" id="nav_bar_top_compare" name="nav_bar_top_compare" onclick="document.body.style.cursor = 'wait';" title="As Amends the Law">
#            <span class="float_left">
#             Today's Law As Amended
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#           <a href="/faces/billTextClient.xhtml?bill_id=202320240AB1197" id="billInfoLink" name="billInfoLink" onclick="asAmendsPopup();">
#            <img alt="information" src="/resources/images/info_popup.gif" style="padding-left: 2px; height: 12px;"/>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected">
#           <a class="tab_link" href="/faces/billVersionsCompareClient.xhtml?bill_id=202320240AB1197" id="nav_bar_top_version_compare" name="nav_bar_top_version_compare">
#            <span class="float_left" title="Compare two versions of the same bill">
#             Compare Versions
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected" id="nav_bar_status">
#           <a class="tab_link" href="/faces/billStatusClient.xhtml?bill_id=202320240AB1197" id="nav_bar_top_status" name="nav_bar_top_status" title="Bill Status">
#            <span class="float_left">
#             Status
#            </span>
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span class="tab_simple tab_not_selected" id="nav_bar_commment">
#           <a class="tab_link" href="#" id="nav_bar_top_comment" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'nav_bar_top_comment':'nav_bar_top_comment','bill_id':'202320240AB1197'},'');return false">
#            <span class="float_left" title="Send comments to Members">
#             Comments To Author
#            </span>
#            <!--          &lt;f:param name="version" value="20230AB119795AMD"/&gt;-->
#            <div class="arrow_right">
#             &gt;&gt;
#            </div>
#           </a>
#          </span>
#          <span id="track_bill_span">
#           <span class="tab_simple tab_not_selected" id="nav_bar_track_bill">
#            <a class="tab_link" href="/faces/billTrackingEdit.xhtml?bill_id=202320240AB1197" id="nav_bar_top_track_bill" name="nav_bar_top_track_bill">
#             <span class="float_left" title="Track Bills">
#              Track Bill
#             </span>
#             <div class="arrow_right">
#              &gt;&gt;
#             </div>
#            </a>
#           </span>
#          </span>
#          <span id="my_favorites_span">
#           <span class="tab_simple tab_not_selected" id="nav_bar_my_favorites">
#            <a class="tab_link" href="#" id="nav_bar_top_my_favorites" onclick="mojarra.jsfcljs(document.getElementById('billDetailTopNavBarId'),{'nav_bar_top_my_favorites':'nav_bar_top_my_favorites','bill_id':'202320240AB1197'},'');return false">
#             <span class="float_left" title="Add Bill to my favorites">
#              Add To My Favorites
#             </span>
#             <div class="arrow_right">
#              &gt;&gt;
#             </div>
#            </a>
#           </span>
#          </span>
#         </div>
#         <script>
#          selectVersion();
#         </script>
#         <input autocomplete="off" id="j_id1:javax.faces.ViewState:1" name="javax.faces.ViewState" type="hidden" value="..."/>
#        </form>
#       </body>
#      </html>
#     </div>
#     <div class="tab_content" id="billtext">
#      <form action="/faces/billTextClient.xhtml" enctype="application/x-www-form-urlencoded" id="j_idt197" method="post" name="j_idt197">
#       <input name="j_idt197" type="hidden" value="j_idt197"/>
#       <div style="float: left; width:15em; font-weight: bold; padding-top: 1.2em;">
#        <span style="font-weight:bold">
#         SHARE THIS:
#        </span>
#        <a href="https://www.facebook.com/sharer/sharer.php?u=https%3A//leginfo.legislature.ca.gov%3A443/faces/billNavClient.xhtml%3Fbill_id=202320240AB1197&amp;t=20232024AB-1197&amp;" id="j_idt197:facebook_link" name="j_idt197:facebook_link" style="margin-left: .8em;" target="_blank">
#         <img alt="share this bill in Facebook" border="0" src="./resources/images/facebook_32.png"/>
#        </a>
#        <a href="https://twitter.com/home?status=20232024AB-1197 https://leginfo.legislature.ca.gov:443/faces/billNavClient.xhtml?bill_id=202320240AB1197&amp;" id="twitter_link" style="margin-left: .8em;" target="_blank">
#         <img alt="share this bill in Twitter" border="0" src="./resources/images/twitter_32.png"/>
#        </a>
#       </div>
#       <div style="float:right; width:25em; padding-top: 2.7em;">
#        <span style="font-weight:bold; size:12;">
#         Date Published: 06/26/2023 02:00 PM
#        </span>
#       </div>
#       <input autocomplete="off" id="j_id1:javax.faces.ViewState:2" name="javax.faces.ViewState" type="hidden" value="..."/>
#      </form>
#      <html xmlns="http://www.w3.org/1999/xhtml" xmlns:caml="http://lc.ca.gov/legalservices/schemas/caml.1#" xmlns:fn="http://www.w3.org/2005/02/xpath-functions" xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:math="java.lang.Math" xmlns:xdt="http://www.w3.org/2005/02/xpath-datatypes" xmlns:xhtml="http://www.w3.org/1999/xhtml" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xs="http://www.w3.org/2001/XMLSchema">
#       <head>
#        <title>
#         AB1197:v95#DOCUMENT
#        </title>
#        <meta content="AB1197" name="dc:identifier"/>
#        <meta content="AB
#               1197-
#                 AMENDED
#               " name="dc:title"/>
#        <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#       </head>
#       <body>
#        <span class="hidden">
#         <h2>
#          Bill Start
#         </h2>
#        </span>
#        <div align="justify" id="bill_all">
#         <div id="about">
#          <br clear="all"/>
#          <div align="center">
#           <table align="center" cellspacing="0" role="presentation" style="border-collapse: collapse">
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Senate
#               </span>
#               <span style="text-transform: uppercase">
#                June 26, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Senate
#               </span>
#               <span style="text-transform: uppercase">
#                June 12, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Assembly
#               </span>
#               <span style="text-transform: uppercase">
#                May 18, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Amended
#                IN
#               </span>
#               <span style=" text-transform: uppercase; font-size: 1em">
#                Assembly
#               </span>
#               <span style="text-transform: uppercase">
#                March 13, 2023
#               </span>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#            <tbody>
#             <tr>
#              <td align="center">
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <br clear="all"/>
#          <div align="center">
#           <font size="3" style="FONT-FAMILY: MinionPC, Arial Unicode MS">
#            CALIFORNIA LEGISLATURE—
#                     2023–2024 REGULAR SESSION
#           </font>
#          </div>
#          <br clear="all"/>
#          <span id="bill_house_num">
#           <div style="float: left; width:50%; font-weight: bold; ">
#            <span style="text-transform: uppercase; text-align:left;width:50%;">
#             <b>
#              Assembly Bill
#             </b>
#            </span>
#           </div>
#           <div style="float:right; width:50%; text-align:right;">
#            <span style="text-transform: uppercase;">
#             <b>
#              No. 1197
#             </b>
#            </span>
#           </div>
#          </span>
#          <hr/>
#          <br clear="all"/>
#          <div align="center">
#           <table align="center" cellspacing="0" role="presentation" style="border-collapse: collapse">
#            <tbody>
#             <tr>
#              <td align="center" id="bill_authors">
#               <span style="font-weight:bold;">
#                Introduced by Assembly Member Hart
#                <br/>
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td align="center" class="textcenter" id="bill_intro_date">
#               <br/>
#               February 16, 2023
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <hr/>
#          <br clear="all"/>
#          <div id="title">
#           <span style="font-weight:normal;font-size:0.9em;">
#            An act to amend Sections 10280, 10280.5, and 10282 of the Public Resources Code, relating to agricultural lands.
#           </span>
#          </div>
#          <br clear="all"/>
#          <br clear="all"/>
#          <div align="center">
#           <h2>
#            LEGISLATIVE COUNSEL'S DIGEST
#           </h2>
#          </div>
#          <br/>
#          <div style="margin:0 0 1em 0">
#           <span id="subject">
#            AB 1197, as amended, Hart.
#                           Agricultural Protection Planning Grant Program: local food
#            <font color="#B30000">
#             <strike>
#              producers: grant limits.
#             </strike>
#            </font>
#            <font class="blue_text" color="blue">
#             <i>
#              producers.
#             </i>
#            </font>
#           </span>
#          </div>
#          <div>
#           <span id="digesttext">
#            <div style="margin:0 0 1em 0;">
#             Existing law establishes the Agricultural Protection Planning Grant Program within the Department of Conservation, to provide planning grants to improve the protection of agricultural lands and grazing lands, including oak woodlands and grasslands. Existing law provides these planning grants to, among other things, maintain local food supplies and agricultural economies through the protection of agricultural lands. Existing law authorizes certain purposes for which these grants may be made for agricultural protection, including, among others, to develop public-private partnerships for the long-term protection and stewardship of agricultural lands. Existing law prohibits the department from awarding a grant in excess of $500,000 to any applicant and $750,000 if the department determines that the grant application is for collaborative planning activities proposed to include 2 or more
# 			 adjacent counties, cities, or city and county.
#            </div>
#            <font color="#B30000">
#             <strike>
#              <p style="display:inline;">
#               <strike>
#                This bill would increase these grant limits to $1,000,000 and $1,500,000, respectively. The
#               </strike>
#              </p>
#              <div style="margin:0 0 1em 0;">
#              </div>
#             </strike>
#            </font>
#            <div style="margin:0 0 1em 0;">
#             <font class="blue_text" color="blue">
#              <i>
#               This
#              </i>
#             </font>
#             bill would additionally authorize a nonprofit organization to apply to the department for a planning grant to assist in identifying and mapping local food producers, as defined, if the department receives an appropriation from the Legislature for those purposes. The bill would authorize planning grants to be awarded for the purpose of maintaining local food producers through the protection of agricultural lands, as specified. The bill would, among other purposes for which these
# 			 grants may be made for agricultural protection, authorize the development of public-private partnerships for the long-term protection and stewardship of local food producers, as specified. The bill would also make nonsubstantive changes.
#            </div>
#           </span>
#          </div>
#          <span class="hidden">
#           <h2>
#            Digest Key
#           </h2>
#          </span>
#          <span id="vote">
#           Vote:
#           <span style=" text-transform: lowercase">
#            MAJORITY
#           </span>
#          </span>
#          <span id="appropriation">
#           Appropriation:
#           <span style=" text-transform: lowercase">
#            NO
#           </span>
#          </span>
#          <span id="fiscalcommittee">
#           Fiscal Committee:
#           <span style=" text-transform: lowercase">
#            YES
#           </span>
#          </span>
#          <span id="localprogram">
#           Local Program:
#           <span style=" text-transform: lowercase">
#            NO
#           </span>
#          </span>
#         </div>
#         <hr/>
#         <span class="hidden">
#          <h2>
#           Bill Text
#          </h2>
#         </span>
#         <div id="bill">
#          <div style=" text-transform: uppercase">
#           <h2 style=" text-align: left;">
#            The people of the State of California do enact as follows:
#           </h2>
#           <br/>
#          </div>
#          <div id="s10.8574569622048498">
#           <div class="ActionLine" style="margin:0 0 1em 0">
#            <h3 style="font-weight:bold; display:inline;">
#             SECTION 1.
#            </h3>
#            Section 10280 of the Public Resources Code is amended to read:
#           </div>
#           <div>
#            <div id="id_3C722B0F-3B2E-4E9E-84DB-4C2AF0F1DC0C">
#             <div>
#              <p>
#               <div style="margin:0 0 1em 0;">
#                <h6 style="display:inline;">
#                 10280.
#                </h6>
#                The Agricultural Protection Planning Grant Program is hereby established within the Department of Conservation, to provide planning grants to do all of the following:
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (a) Conserve California’s most productive farmlands and ecologically important rangelands.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (b) Advance California’s climate change goals through carbon sequestration and greenhouse gas emissions reductions resulting from the implementation of local plans.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (c) Maintain local food supplies, local food producers, and agricultural economies through the protection of agricultural lands.
#               </div>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div id="s20.058822916495747224">
#           <div class="ActionLine" style="margin:0 0 1em 0">
#            <h3 style="font-weight:bold; display:inline;">
#             SEC. 2.
#            </h3>
#            Section 10280.5 of the Public Resources Code is amended to read:
#           </div>
#           <div>
#            <div id="id_C1836643-C833-426C-A845-3B240D05EC08">
#             <div>
#              <p>
#               <div style="margin:0 0 1em 0;">
#                <h6 style="display:inline;">
#                 10280.5.
#                </h6>
#                The following terms have the following meanings as used in this division, unless the context clearly requires otherwise:
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (a) “Authority” means an entity established by the state that requires its members, including, but not limited to, local government entities, to adopt a resolution stating their intent to participate.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (b) “Department” means the Department of Conservation.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (c) “Grant program” means the program established pursuant to Section 10280.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (d) “Joint powers authority”
# 						means a joint powers authority established pursuant to Chapter 5 (commencing with Section 6500) of Division 7 of Title 1 of the Government Code that is formed in part to protect agricultural land.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (e) “Local food producer” means a food producer or an agricultural producer that self-certifies that it satisfies either of the following conditions:
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (1) Is an agricultural producer that does all of the following:
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 2.5em;">
#                (A) Farms on 500 acres or less of farmland across all properties or grazes livestock on rangelands and has gross meat sales of less than two million dollars ($2,000,000) per year, as adjusted for annual changes to the California Consumer Price Index, as calculated by the Department of Finance.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 2.5em;">
#                (B) Sells more than 75 percent of its products within the state.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 2.5em;">
#                (C) Does at least one of the following:
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 4em;">
#                (i) Operates a farm stand that meets the requirements of Section 47050 of the Food and Agricultural Code or a field retail stand that meets the requirements of Section 47030 of the Food and Agricultural Code on its property that makes its agricultural products available to the community.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 4em;">
#                (ii) Has a certified producer certificate and regularly sells in a California certified farmers’ market that meets the requirements of Section 47020 of the Food and Agricultural Code.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 4em;">
#                (iii) Operates a subscription-based
# 						community-supported agriculture program that meets the requirements of subdivision (a) of Section 47060 of the Food and Agricultural Code.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 4em;">
#                (iv) Operates an agritourism business, including, but not limited to, by providing educational opportunities for schoolchildren on its property to learn about how food is grown and farm conservation practices.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 4em;">
#                (v) Sells agricultural products directly to a restaurant or retail food establishment that is purchasing the food for sale directly to consumers at the restaurant or retail food establishment and the restaurant or retail food establishment meets the requirements of a food facility pursuant to Section 113789 of the Health and Safety Code.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 4em;">
#                (vi) Provides food products to a
# 						farm to community food hub that meets the requirements of Section 592 of the Food and Agricultural Code.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (2) Processes, aggregates, distributes, or otherwise facilitates the sale of agricultural products from an agricultural producer that meets the requirements of paragraph (1) and 75 percent of those sales occur within the state.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (f) “Local government entity” means any city, county, city and county, or district, including, but not limited to, park and open-space districts, resource conservation districts, and other special districts.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (g) “Nonprofit organization” means any nonprofit public benefit corporation that has among its purposes the conservation of agricultural lands, and holds a tax exemption, as defined
# 						under Section 501(c)(3) of the Internal Revenue Code, and further qualifies as an organization under Section 170(b)(1)(A)(iv) or 170(h)(3) of the Internal Revenue Code.
#               </div>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div id="s30.8345737019974078">
#           <div class="ActionLine" style="margin:0 0 1em 0">
#            <h3 style="font-weight:bold; display:inline;">
#             SEC. 3.
#            </h3>
#            Section 10282 of the Public Resources Code is amended to read:
#           </div>
#           <div>
#            <div id="id_B8B27B6D-7E13-4702-B879-F34616E3FE0B">
#             <div>
#              <p>
#               <div style="margin:0 0 1em 0;">
#                <h6 style="display:inline;">
#                 10282.
#                </h6>
#                (a) Under the grant program, a local government entity, nonprofit organization, authority, or joint powers authority may apply to the department for a planning grant to be used for the protection of agricultural lands and grazing lands, including oak woodlands and grasslands. In addition to any requirements established by the department, to be eligible for a grant under the grant program, an applicant shall do all of the following:
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (1) Identify and map, utilizing the designations in the farmlands mapping and monitoring program of the department pursuant to Section 65570 of the Government Code, existing or potential agricultural lands in its jurisdiction.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (2) Specify its existing goals, objectives, policies, or programs that support the long-term protection of agricultural land.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (3) Specify the proposed changes to its existing goals, objectives, policies, or programs that support the long-term protection of agricultural land.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (4) Specify how the planning grant would be used to improve the long-term protection of agricultural land within its jurisdiction.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (b) Under the grant program, and in addition to subdivision (a), a nonprofit organization may apply to the department for a planning grant to assist in identifying and mapping local food producers if the department receives an appropriation from the Legislature for those
# 						purposes.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (c) A grant awarded by the department under the grant program shall not exceed
#                <font color="#B30000">
#                 <strike>
#                  one million dollars ($1,000,000)
#                 </strike>
#                </font>
#                <font class="blue_text" color="blue">
#                 <i>
#                  five hundred thousand dollars ($500,000)
#                 </i>
#                </font>
#                to any applicant, or
#                <font color="#B30000">
#                 <strike>
#                  one million five hundred thousand dollars ($1,500,000)
#                 </strike>
#                </font>
#                <font class="blue_text" color="blue">
#                 <i>
#                  seven hundred fifty thousand dollars ($750,000)
#                 </i>
#                </font>
#                if the department determines that a grant application is for collaborative planning activities proposed to include two or more adjacent counties, cities, or city and county.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (d) In
# 						granting funds pursuant to this division, the department shall give priority to proposals that include matching funds from local sources.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (e) A grant proposal by a park or open-space district, resource conservation district, other special district, authority, or joint powers authority shall be approved by resolution of the city, county, or city and county, or multiple cities and counties, whose jurisdiction the proposal is intended to benefit. The city, county, or city and county shall provide evidence that it is willing to implement some of the planning process funded by the grant.
#               </div>
#               <div style="margin:0 0 1em 0;">
#                (f) The purposes for which a grant may be made pursuant to this division for agricultural protection may include, but need not be limited to, the following:
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (1) To update the general plan of a city, county, or city and county to improve protection of agricultural land, or a zoning ordinance designed to improve protection of agricultural land.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (2) To develop multicounty strategies to protect agricultural land.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (3) To develop city-county agreements to protect agricultural land.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (4) To develop strategies to implement existing general plan provisions, city-county agreements, or multicounty agreements to protect agricultural land, including technical assistance.
#               </div>
#               <div style="margin:0 0 1em 0;margin-left: 1em;">
#                (5) To develop public-private partnerships for the long-term
# 						protection and stewardship of agricultural lands and local food producers.
#               </div>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </body>
#      </html>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# locating title in html
t = soup.find_all('title')
print(len(t))
print(t[0])
# Out:
# 2
# <title>Bill Text  - AB-1197 Agricultural Protection Planning Grant Program: local food producers.</title>

# %%
# locating status in html
s = soup.find_all('title')
print(len(s))
print(s)
# Out:
# 2
# [<title>Bill Text  - AB-1197 Agricultural Protection Planning Grant Program: local food producers.</title>, <title>AB1197:v95#DOCUMENT</title>]

# %%
# locating bill year introduced in html
y = soup.find_all(id = 'bill_intro_date')
print(len(y))
print(y[0])
# Out:
# 1
# <td align="center" class="textcenter" id="bill_intro_date"><br/>February 16, 2023</td>

# %%
# locating bill year amended in html
y1 = soup.find_all('tbody')
print(len(y1))
print(y1[0])
# Out:
# 6
# <tbody><tr><td align="center"><span style=" text-transform: uppercase; font-size: 1em">
#                 Amended
#                IN </span><span style=" text-transform: uppercase; font-size: 1em">
#                 Senate
#               </span> <span style="text-transform: uppercase">June 26, 2023</span><br/></td></tr></tbody>

# %%
# locating bill text bloc in html
ti = soup.find_all('div', id = 'bill')
print(len(ti))
print(type(ti))
print(ti)
# Out:
# 1
# <class 'bs4.element.ResultSet'>
# [<div id="bill"><div style=" text-transform: uppercase"><h2 style=" text-align: left;">The people of the State of California do enact as follows:</h2><br/></div><div id="s10.8574569622048498"><div class="ActionLine" style="margin:0 0 1em 0"><h3 style="font-weight:bold; display:inline;">SECTION 1.</h3> Section 10280 of the Public Resources Code is amended to read:</div><div><div id="id_3C722B0F-3B2E-4E9E-84DB-4C2AF0F1DC0C"><div><p><div style="margin:0 0 1em 0;"><h6 style="display:inline;">10280.</h6> The Agricultural Protection Planning Grant Program is hereby established within the Department of Conservation, to provide planning grants to do all of the following:</div><div style="margin:0 0 1em 0;">(a) Conserve California’s most productive farmlands and ecologically important rangelands.</div><div style="margin:0 0 1em 0;">(b) Advance California’s climate change goals through carbon sequestration and greenhouse gas emissions reductions resulting from the implementation of local plans.</div><div style="margin:0 0 1em 0;">(c) Maintain local food supplies, local food producers, and agricultural economies through the protection of agricultural lands.</div></p></div></div></div></div><div id="s20.058822916495747224"><div class="ActionLine" style="margin:0 0 1em 0"><h3 style="font-weight:bold; display:inline;">SEC. 2.</h3> Section 10280.5 of the Public Resources Code is amended to read:</div><div><div id="id_C1836643-C833-426C-A845-3B240D05EC08"><div><p><div style="margin:0 0 1em 0;"><h6 style="display:inline;">10280.5.</h6> The following terms have the following meanings as used in this division, unless the context clearly requires otherwise:</div><div style="margin:0 0 1em 0;">(a) “Authority” means an entity established by the state that requires its members, including, but not limited to, local government entities, to adopt a resolution stating their intent to participate.</div><div style="margin:0 0 1em 0;">(b) “Department” means the Department of Conservation.</div><div style="margin:0 0 1em 0;">(c) “Grant program” means the program established pursuant to Section 10280.</div><div style="margin:0 0 1em 0;">(d) “Joint powers authority”
# 						means a joint powers authority established pursuant to Chapter 5 (commencing with Section 6500) of Division 7 of Title 1 of the Government Code that is formed in part to protect agricultural land.</div><div style="margin:0 0 1em 0;">(e) “Local food producer” means a food producer or an agricultural producer that self-certifies that it satisfies either of the following conditions:</div><div style="margin:0 0 1em 0;margin-left: 1em;">(1) Is an agricultural producer that does all of the following:</div><div style="margin:0 0 1em 0;margin-left: 2.5em;">(A) Farms on 500 acres or less of farmland across all properties or grazes livestock on rangelands and has gross meat sales of less than two million dollars ($2,000,000) per year, as adjusted for annual changes to the California Consumer Price Index, as calculated by the Department of Finance.</div><div style="margin:0 0 1em 0;margin-left: 2.5em;">(B) Sells more than 75 percent of its products within the state.</div><div style="margin:0 0 1em 0;margin-left: 2.5em;">(C) Does at least one of the following:</div><div style="margin:0 0 1em 0;margin-left: 4em;">(i) Operates a farm stand that meets the requirements of Section 47050 of the Food and Agricultural Code or a field retail stand that meets the requirements of Section 47030 of the Food and Agricultural Code on its property that makes its agricultural products available to the community.</div><div style="margin:0 0 1em 0;margin-left: 4em;">(ii) Has a certified producer certificate and regularly sells in a California certified farmers’ market that meets the requirements of Section 47020 of the Food and Agricultural Code.</div><div style="margin:0 0 1em 0;margin-left: 4em;">(iii) Operates a subscription-based
# 						community-supported agriculture program that meets the requirements of subdivision (a) of Section 47060 of the Food and Agricultural Code.</div><div style="margin:0 0 1em 0;margin-left: 4em;">(iv) Operates an agritourism business, including, but not limited to, by providing educational opportunities for schoolchildren on its property to learn about how food is grown and farm conservation practices.</div><div style="margin:0 0 1em 0;margin-left: 4em;"> (v) Sells agricultural products directly to a restaurant or retail food establishment that is purchasing the food for sale directly to consumers at the restaurant or retail food establishment and the restaurant or retail food establishment meets the requirements of a food facility pursuant to Section 113789 of the Health and Safety Code.</div><div style="margin:0 0 1em 0;margin-left: 4em;">(vi) Provides food products to a
# 						farm to community food hub that meets the requirements of Section 592 of the Food and Agricultural Code.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(2) Processes, aggregates, distributes, or otherwise facilitates the sale of agricultural products from an agricultural producer that meets the requirements of paragraph (1) and 75 percent of those sales occur within the state.</div><div style="margin:0 0 1em 0;">(f) “Local government entity” means any city, county, city and county, or district, including, but not limited to, park and open-space districts, resource conservation districts, and other special districts.</div><div style="margin:0 0 1em 0;">(g) “Nonprofit organization” means any nonprofit public benefit corporation that has among its purposes the conservation of agricultural lands, and holds a tax exemption, as defined
# 						under Section 501(c)(3) of the Internal Revenue Code, and further qualifies as an organization under Section 170(b)(1)(A)(iv) or 170(h)(3) of the Internal Revenue Code.</div></p></div></div></div></div><div id="s30.8345737019974078"><div class="ActionLine" style="margin:0 0 1em 0"><h3 style="font-weight:bold; display:inline;">SEC. 3.</h3> Section 10282 of the Public Resources Code is amended to read:</div><div><div id="id_B8B27B6D-7E13-4702-B879-F34616E3FE0B"><div><p><div style="margin:0 0 1em 0;"><h6 style="display:inline;">10282.</h6> (a) Under the grant program, a local government entity, nonprofit organization, authority, or joint powers authority may apply to the department for a planning grant to be used for the protection of agricultural lands and grazing lands, including oak woodlands and grasslands. In addition to any requirements established by the department, to be eligible for a grant under the grant program, an applicant shall do all of the following:</div><div style="margin:0 0 1em 0;margin-left: 1em;">(1) Identify and map, utilizing the designations in the farmlands mapping and monitoring program of the department pursuant to Section 65570 of the Government Code, existing or potential agricultural lands in its jurisdiction.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(2) Specify its existing goals, objectives, policies, or programs that support the long-term protection of agricultural land.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(3) Specify the proposed changes to its existing goals, objectives, policies, or programs that support the long-term protection of agricultural land.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(4) Specify how the planning grant would be used to improve the long-term protection of agricultural land within its jurisdiction.</div><div style="margin:0 0 1em 0;">(b) Under the grant program, and in addition to subdivision (a), a nonprofit organization may apply to the department for a planning grant to assist in identifying and mapping local food producers if the department receives an appropriation from the Legislature for those
# 						purposes.</div><div style="margin:0 0 1em 0;">(c) A grant awarded by the department under the grant program shall not exceed<font color="#B30000"><strike> one million dollars ($1,000,000)</strike></font><font class="blue_text" color="blue"><i> five hundred thousand dollars ($500,000)</i></font> to any applicant, or<font color="#B30000"><strike> one million five hundred thousand dollars ($1,500,000)</strike></font><font class="blue_text" color="blue"><i> seven hundred fifty thousand dollars ($750,000)</i></font> if the department determines that a grant application is for collaborative planning activities proposed to include two or more adjacent counties, cities, or city and county.</div><div style="margin:0 0 1em 0;">(d) In
# 						granting funds pursuant to this division, the department shall give priority to proposals that include matching funds from local sources.</div><div style="margin:0 0 1em 0;">(e) A grant proposal by a park or open-space district, resource conservation district, other special district, authority, or joint powers authority shall be approved by resolution of the city, county, or city and county, or multiple cities and counties, whose jurisdiction the proposal is intended to benefit. The city, county, or city and county shall provide evidence that it is willing to implement some of the planning process funded by the grant.</div><div style="margin:0 0 1em 0;">(f) The purposes for which a grant may be made pursuant to this division for agricultural protection may include, but need not be limited to, the following:</div><div style="margin:0 0 1em 0;margin-left: 1em;">(1) To update the general plan of a city, county, or city and county to improve protection of agricultural land, or a zoning ordinance designed to improve protection of agricultural land.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(2) To develop multicounty strategies to protect agricultural land.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(3) To develop city-county agreements to protect agricultural land.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(4) To develop strategies to implement existing general plan provisions, city-county agreements, or multicounty agreements to protect agricultural land, including technical assistance.</div><div style="margin:0 0 1em 0;margin-left: 1em;">(5) To develop public-private partnerships for the long-term
# 						protection and stewardship of agricultural lands and local food producers.</div></p></div></div></div></div></div>]

# %%
# remove html style and tags from title
for text in t[0]:
    title = text.text.strip()
    title = title.split("- ")[-1]
title
# Out:
# 'AB-1197 Agricultural Protection Planning Grant Program: local food producers.'

# %%
# remove html style and tags from year int
for text in y:
    yeari = text.text.strip()
    yeari = yeari[-4:]
yeari
# Out:
# '2023'

# %%
# remove html style and tags from year amended
for text in y1[0]:
    yeara = text.text.strip()
    yeara = yeara[-4:]
yeara
# Out:
# '2023'

# %%
# remove html style and tags from bill text
for text in ti:
    billtxt = text.text.strip()
billtxt
# Out:
# 'The people of the State of California do enact as follows:SECTION 1.\xa0Section 10280 of the Public Resources Code is amended to read:10280.\xa0The Agricultural Protection Planning Grant Program is hereby established within the Department of Conservation, to provide planning grants to do all of the following:(a)\xa0Conserve California’s most productive farmlands and ecologically important rangelands.(b)\xa0Advance California’s climate change goals through carbon sequestration and greenhouse gas emissions reductions resulting from the implementation of local plans.(c)\xa0Maintain local food supplies, local food producers, and agricultural economies through the protection of agricultural lands.SEC. 2.\xa0Section 10280.5 of the Public Resources Code is amended to read:10280.5.\xa0The following terms have the following meanings as used in this division, unless the context clearly requires otherwise:(a)\xa0“Authority” means an entity established by the state that requires its members, including, but not limited to, local government entities, to adopt a resolution stating their intent to participate.(b)\xa0“Department” means the Department of Conservation.(c)\xa0“Grant program” means the program established pursuant to Section 10280.(d)\xa0“Joint powers authority”\n\t\t\t\t\t\tmeans a joint powers authority established pursuant to Chapter 5 (commencing with Section 6500) of Division 7 of Title 1 of the Government Code that is formed in part to protect agricultural land.(e)\xa0“Local food producer” means a food producer or an agricultural producer that self-certifies that it satisfies either of the following conditions:(1)\xa0Is an agricultural producer that does all of the following:(A)\xa0Farms on 500 acres or less of farmland across all properties or grazes livestock on rangelands and has gross meat sales of less than two million dollars ($2,000,000) per year, as adjusted for annual changes to the California Consumer Price Index, as calculated by the Department of Finance.(B)\xa0Sells more than 75 percent of its products within the state.(C)\xa0Does at least one of the following:(i)\xa0Operates a farm stand that meets the requirements of Section 47050 of the Food and Agricultural Code or a field retail stand that meets the requirements of Section 47030 of the Food and Agricultural Code on its property that makes its agricultural products available to the community.(ii)\xa0Has a certified producer certificate and regularly sells in a California certified farmers’ market that meets the requirements of Section 47020 of the Food and Agricultural Code.(iii)\xa0Operates a subscription-based\n\t\t\t\t\t\tcommunity-supported agriculture program that meets the requirements of subdivision (a) of Section 47060 of the Food and Agricultural Code.(iv)\xa0Operates an agritourism business, including, but not limited to, by providing educational opportunities for schoolchildren on its property to learn about how food is grown and farm conservation practices. (v)\xa0Sells agricultural products directly to a restaurant or retail food establishment that is purchasing the food for sale directly to consumers at the restaurant or retail food establishment and the restaurant or retail food establishment meets the requirements of a food facility pursuant to Section 113789 of the Health and Safety Code.(vi)\xa0Provides food products to a\n\t\t\t\t\t\tfarm to community food hub that meets the requirements of Section 592 of the Food and Agricultural Code.(2)\xa0Processes, aggregates, distributes, or otherwise facilitates the sale of agricultural products from an agricultural producer that meets the requirements of paragraph (1) and 75 percent of those sales occur within the state.(f)\xa0“Local government entity” means any city, county, city and county, or district, including, but not limited to, park and open-space districts, resource conservation districts, and other special districts.(g)\xa0“Nonprofit organization” means any nonprofit public benefit corpo ...

# %%
# creating bill_id
bill_id = title.split("- ")[-1][:7]

# concatenating into one list
infotxt1 = [bill_id, title, yeari, yeara, billtxt]
infotxt1
# Out:
# ['AB-1197',
#  'AB-1197 Agricultural Protection Planning Grant Program: local food producers.',
#  '2023',
#  '2023',
#  'The people of the State of California do enact as follows:SECTION 1.\xa0Section 10280 of the Public Resources Code is amended to read:10280.\xa0The Agricultural Protection Planning Grant Program is hereby established within the Department of Conservation, to provide planning grants to do all of the following:(a)\xa0Conserve California’s most productive farmlands and ecologically important rangelands.(b)\xa0Advance California’s climate change goals through carbon sequestration and greenhouse gas emissions reductions resulting from the implementation of local plans.(c)\xa0Maintain local food supplies, local food producers, and agricultural economies through the protection of agricultural lands.SEC. 2.\xa0Section 10280.5 of the Public Resources Code is amended to read:10280.5.\xa0The following terms have the following meanings as used in this division, unless the context clearly requires otherwise:(a)\xa0“Authority” means an entity established by the state that requires its members, including, but not limited to, local government entities, to adopt a resolution stating their intent to participate.(b)\xa0“Department” means the Department of Conservation.(c)\xa0“Grant program” means the program established pursuant to Section 10280.(d)\xa0“Joint powers authority”\n\t\t\t\t\t\tmeans a joint powers authority established pursuant to Chapter 5 (commencing with Section 6500) of Division 7 of Title 1 of the Government Code that is formed in part to protect agricultural land.(e)\xa0“Local food producer” means a food producer or an agricultural producer that self-certifies that it satisfies either of the following conditions:(1)\xa0Is an agricultural producer that does all of the following:(A)\xa0Farms on 500 acres or less of farmland across all properties or grazes livestock on rangelands and has gross meat sales of less than two million dollars ($2,000,000) per year, as adjusted for annual changes to the California Consumer Price Index, as calculated by the Department of Finance.(B)\xa0Sells more than 75 percent of its products within the state.(C)\xa0Does at least one of the following:(i)\xa0Operates a farm stand that meets the requirements of Section 47050 of the Food and Agricultural Code or a field retail stand that meets the requirements of Section 47030 of the Food and Agricultural Code on its property that makes its agricultural products available to the community.(ii)\xa0Has a certified producer certificate and regularly sells in a California certified farmers’ market that meets the requirements of Section 47020 of the Food and Agricultural Code.(iii)\xa0Operates a subscription-based\n\t\t\t\t\t\tcommunity-supported agriculture program that meets the requirements of subdivision (a) of Section 47060 of the Food and Agricultural Code.(iv)\xa0Operates an agritourism business, including, but not limited to, by providing educational opportunities for schoolchildren on its property to learn about how food is grown and farm conservation practices. (v)\xa0Sells agricultural products directly to a restaurant or retail food establishment that is purchasing the food for sale directly to consumers at the restaurant or retail food establishment and the restaurant or retail food establishment meets the requirements of a food facility pursuant to Section 113789 of the Health and Safety Code.(vi)\xa0Provides food products to a\n\t\t\t\t\t\tfarm to community food hub that meets the requirements of Section 592 of the Food and Agricultural Code.(2)\xa0Processes, aggregates, distributes, or otherwise facilitates the sale of agricultural products from an agricultural producer that meets the requirements of paragraph (1) and 75 percent of those sales occur within the state.(f)\xa0“Local government entity” means any city, county, city and county, or district, including, but not limited to, park and open-space districts, resource conservation districts, and other special districts.(g)\xa0“Nonprofit organization” means any nonprofit public benefit corp ...

# %%
# remove html style and tags from all bill info (B)

# list of all bill elements
billinfo = [t[0], y, y1[0], ti]

# remove html style and tags from bill text
infotxt = []

for info in billinfo:
    for text in info:
        row = text.text.strip()
        infotxt.append(row)
        
    # create bill id from bill title
    bill_id = infotxt[0].split("- ")[-1][:7]
    
# add an item to the list that will serve as the bill id later
infotxt.insert(0, bill_id)
        
print(len(infotxt))
infotxt
# Out:
# 5
# ['AB-1197',
#  'Bill Text  - AB-1197 Agricultural Protection Planning Grant Program: local food producers.',
#  'February\xa016,\xa02023',
#  'Amended\n              \xa0IN\xa0\n                Senate\n              \xa0June\xa026,\xa02023',
#  'The people of the State of California do enact as follows:SECTION 1.\xa0Section 10280 of the Public Resources Code is amended to read:10280.\xa0The Agricultural Protection Planning Grant Program is hereby established within the Department of Conservation, to provide planning grants to do all of the following:(a)\xa0Conserve California’s most productive farmlands and ecologically important rangelands.(b)\xa0Advance California’s climate change goals through carbon sequestration and greenhouse gas emissions reductions resulting from the implementation of local plans.(c)\xa0Maintain local food supplies, local food producers, and agricultural economies through the protection of agricultural lands.SEC. 2.\xa0Section 10280.5 of the Public Resources Code is amended to read:10280.5.\xa0The following terms have the following meanings as used in this division, unless the context clearly requires otherwise:(a)\xa0“Authority” means an entity established by the state that requires its members, including, but not limited to, local government entities, to adopt a resolution stating their intent to participate.(b)\xa0“Department” means the Department of Conservation.(c)\xa0“Grant program” means the program established pursuant to Section 10280.(d)\xa0“Joint powers authority”\n\t\t\t\t\t\tmeans a joint powers authority established pursuant to Chapter 5 (commencing with Section 6500) of Division 7 of Title 1 of the Government Code that is formed in part to protect agricultural land.(e)\xa0“Local food producer” means a food producer or an agricultural producer that self-certifies that it satisfies either of the following conditions:(1)\xa0Is an agricultural producer that does all of the following:(A)\xa0Farms on 500 acres or less of farmland across all properties or grazes livestock on rangelands and has gross meat sales of less than two million dollars ($2,000,000) per year, as adjusted for annual changes to the California Consumer Price Index, as calculated by the Department of Finance.(B)\xa0Sells more than 75 percent of its products within the state.(C)\xa0Does at least one of the following:(i)\xa0Operates a farm stand that meets the requirements of Section 47050 of the Food and Agricultural Code or a field retail stand that meets the requirements of Section 47030 of the Food and Agricultural Code on its property that makes its agricultural products available to the community.(ii)\xa0Has a certified producer certificate and regularly sells in a California certified farmers’ market that meets the requirements of Section 47020 of the Food and Agricultural Code.(iii)\xa0Operates a subscription-based\n\t\t\t\t\t\tcommunity-supported agriculture program that meets the requirements of subdivision (a) of Section 47060 of the Food and Agricultural Code.(iv)\xa0Operates an agritourism business, including, but not limited to, by providing educational opportunities for schoolchildren on its property to learn about how food is grown and farm conservation practices. (v)\xa0Sells agricultural products directly to a restaurant or retail food establishment that is purchasing the food for sale directly to consumers at the restaurant or retail food establishment and the restaurant or retail food establishment meets the requirements of a food facility pursuant to Section 113789 of the Health and Safety Code.(vi)\xa0Provides food products to a\n\t\t\t\t\t\tfarm to community food hub that meets the requirements of Section 592 of the Food and Agricultural Code.(2)\xa0Processes, aggregates, distributes, or otherwise facilitates the sale of agricultural products from an agricultural producer that meets the requirements of paragraph (1) and 75 percent of those sales occur within the state.(f)\xa0“Local government entity” means any city, county, city and county, or district, including, but not limited to, park and open-space districts, resource conservation districts, and other special districts.(g)\xa0“Nonprofit organization” means any nonprofit public benefit corp ...

# %%
# storing bill info in df    
itxtdf = pd.DataFrame(infotxt1).transpose()

# rename columns
#itxtdf.rename(columns = {'0':'title', '1':'y_intro', '2': 'y_recent', '3':'text'}, inplace = True)
itxtdf.columns = ['bill_id', 'title', 'y_intro', 'y_recent', 'text']

# optional: create column to serve as new index ID?
#itxtdf.set_index('bill_id', inplace = True)

itxtdf
# Out:
#    bill_id                                              title y_intro  \
# 0  AB-1197  AB-1197 Agricultural Protection Planning Grant...    2023
#
#   y_recent                                               text
# 0     2023  The people of the State of California do enact...

# %%
# further processing bill text for NLP

# list of stopwords to exclude
swords = stopwords.words('english')

# stripping nonessential characters
textonly = re.sub(r"[^A-z\s]", "", billtxt)

# turning cleaned bill text into list of words
wordlist = [word for word in word_tokenize(textonly.lower()) 
                 if word not in swords]
print(len(wordlist))
wordlist
# Out:
# 641
# ['people',
#  'state',
#  'california',
#  'enact',
#  'followssection',
#  'section',
#  'public',
#  'resources',
#  'code',
#  'amended',
#  'read',
#  'agricultural',
#  'protection',
#  'planning',
#  'grant',
#  'program',
#  'hereby',
#  'established',
#  'within',
#  'department',
#  'conservation',
#  'provide',
#  'planning',
#  'grants',
#  'followinga',
#  'conserve',
#  'californias',
#  'productive',
#  'farmlands',
#  'ecologically',
#  'important',
#  'rangelandsb',
#  'advance',
#  'californias',
#  'climate',
#  'change',
#  'goals',
#  'carbon',
#  'sequestration',
#  'greenhouse',
#  'gas',
#  'emissions',
#  'reductions',
#  'resulting',
#  'implementation',
#  'local',
#  'plansc',
#  'maintain',
#  'local',
#  'food',
#  'supplies',
#  'local',
#  'food',
#  'producers',
#  'agricultural',
#  'economies',
#  'protection',
#  'agricultural',
#  'landssec',
#  'section',
#  'public',
#  'resources',
#  'code',
#  'amended',
#  'read',
#  'following',
#  'terms',
#  'following',
#  'meanings',
#  'used',
#  'division',
#  'unless',
#  'context',
#  'clearly',
#  'requires',
#  'otherwisea',
#  'authority',
#  'means',
#  'entity',
#  'established',
#  'state',
#  'requires',
#  'members',
#  'including',
#  'limited',
#  'local',
#  'government',
#  'entities',
#  'adopt',
#  'resolution',
#  'stating',
#  'intent',
#  'participateb',
#  'department',
#  'means',
#  'department',
#  'conservationc',
#  'grant',
#  'program',
#  'means',
#  'program',
#  'established',
#  'pursuant',
#  'section',
#  'joint',
#  'powers',
#  'authority',
#  'means',
#  'joint',
#  'powers',
#  'authority',
#  'established',
#  'pursuant',
#  'chapter',
#  'commencing',
#  'section',
#  'division',
#  'title',
#  'government',
#  'code',
#  'formed',
#  'part',
#  'protect',
#  'agricultural',
#  'lande',
#  'local',
#  'food',
#  'producer',
#  'means',
#  'food',
#  'producer',
#  'agricultural',
#  'producer',
#  'selfcertifies',
#  'satisfies',
#  'either',
#  'following',
#  'conditions',
#  'agricultural',
#  'producer',
#  'followinga',
#  'farms',
#  'acres',
#  'less',
#  'farmland',
#  'across',
#  'properties',
#  'grazes',
#  'livestock',
#  'rangelands',
#  'gross',
#  'meat',
#  'sales',
#  'less',
#  'two',
#  'million',
#  'dollars',
#  'per',
#  'year',
#  'adjusted',
#  'annual',
#  'changes',
#  'california',
#  'consumer',
#  'price',
#  'index',
#  'calculated',
#  'department',
#  'financeb',
#  'sells',
#  'percent',
#  'products',
#  'within',
#  'statec',
#  'least',
#  'one',
#  'followingi',
#  'operates',
#  'farm',
#  'stand',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'code',
#  'field',
#  'retail',
#  'stand',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'code',
#  'property',
#  'makes',
#  'agricultural',
#  'products',
#  'available',
#  'communityii',
#  'certified',
#  'producer',
#  'certificate',
#  'regularly',
#  'sells',
#  'california',
#  'certified',
#  'farmers',
#  'market',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'codeiii',
#  'operates',
#  'subscriptionbased',
#  'communitysupported',
#  'agriculture',
#  'program',
#  'meets',
#  'requirements',
#  'subdivision',
#  'section',
#  'food',
#  'agricultural',
#  'codeiv',
#  'operates',
#  'agritourism',
#  'business',
#  'including',
#  'limited',
#  'providing',
#  'educational',
#  'opportunities',
#  'schoolchildren',
#  'property',
#  'learn',
#  'food',
#  'grown',
#  'farm',
#  'conservation',
#  'practices',
#  'v',
#  'sells',
#  'agricultural',
#  'products',
#  'directly',
#  'restaurant',
#  'retail',
#  'food',
#  'establishment',
#  'purchasing',
#  'food',
#  'sale',
#  'directly',
#  'consumers',
#  'restaurant',
#  'retail',
#  'food',
#  'establishment',
#  'restaurant',
#  'retail',
#  'food',
#  'establishment',
#  'meets',
#  'requirements',
#  'food',
#  'facility',
#  'pursuant',
#  'section',
#  'health',
#  'safety',
#  'codevi',
#  'provides',
#  'food',
#  'products',
#  'farm',
#  'community',
#  'food',
#  'hub',
#  'meets',
#  'requirements',
#  'section',
#  'food',
#  'agricultural',
#  'code',
#  'processes',
#  'aggregates',
#  'distributes',
#  'otherwise',
#  'facilitates',
#  'sale',
#  'agricultural',
#  'products',
#  'agricultural',
#  'producer',
#  'meets',
#  'requirements',
#  'paragraph',
#  'percent',
#  'sales',
#  'occur',
#  'within',
#  'statef',
#  'local',
#  'government',
#  'entity',
#  'means',
#  'city',
#  'county',
#  'city',
#  'county',
#  'district',
#  'including',
#  'limited',
#  'park',
#  'openspace',
#  'districts',
#  'resource',
#  'conservation',
#  'districts',
#  'special',
#  'districtsg',
#  'nonprofit',
#  'organization',
#  'means',
#  'nonprofit',
#  'public',
#  'benefit',
#  'corporation',
#  'among',
#  'purposes',
#  'conservation',
#  'agricultural',
#  'lands',
#  'holds',
#  'tax',
#  'exemption',
#  'defined',
#  'section',
#  'c',
#  'internal',
#  'revenue',
#  'code',
#  'qualifies',
#  'organization',
#  'section',
#  'baiv',
#  'h',
#  'internal',
#  'revenue',
#  'codesec',
#  'section',
#  'public',
#  'resources',
#  'code',
#  'amended',
#  'read',
#  'grant',
#  'program',
#  'local',
#  'government',
#  'entity',
#  'nonprofit',
#  'organization',
#  'authority',
#  'joint',
#  'powers',
#  'authority',
#  'may',
#  'apply',
#  'department',
#  'planning',
#  'grant',
#  'used',
#  'protection',
#  'agricultural',
#  'lands',
#  'grazing',
#  'lands',
#  'including',
#  'oak',
#  'woodlands',
#  'grasslands',
#  'addition',
#  'requirements',
#  'established',
#  'department',
#  'eligible',
#  'grant',
#  'grant',
#  'program',
#  'applicant',
#  'shall',
#  'following',
#  'identify',
#  'map',
#  'utilizing',
#  'designations',
#  'farmlands',
#  'mapping',
#  'monitoring',
#  'program',
#  'department',
#  'pursuant',
#  'section',
#  'government',
#  'code',
#  'existing',
#  'potential',
#  'agricultural',
#  'lands',
#  'jurisdiction',
#  'specify',
#  'existing',
#  'goals',
#  'objectives',
#  'policies',
#  'programs',
#  'support',
#  'longterm',
#  'protection',
#  'agricultural',
#  'land',
#  'specify',
#  'proposed',
#  'changes',
#  'existing',
#  'goals',
#  'objectives',
#  'policies',
#  'programs',
#  'support',
#  'longterm',
#  'protection',
#  'agricultural',
#  'land',
#  'specify',
#  'planning',
#  'grant',
#  'would',
#  'used',
#  'improve',
#  'longterm',
#  'protection',
#  'agricultural',
#  'land',
#  'within',
#  'jurisdictionb',
#  'grant',
#  'program',
#  'addition',
#  'subdivision',
#  'nonprofit',
#  'organization',
#  'may',
#  'apply',
#  'department',
#  'planning',
#  'grant',
#  'assist',
#  'identifying',
#  'mapping',
#  'local',
#  'food',
#  'producers',
#  'department',
#  'receives',
#  'appropriation',
#  'legislature',
#  'purposesc',
#  'grant',
#  'awarded',
#  'department',
#  'grant',
#  'program',
#  'shall',
#  'exceed',
#  'one',
#  'million',
#  'dollars',
#  'five',
#  'hundred',
#  'thousand',
#  'dollars',
#  'applicant',
#  'one',
#  'million',
#  'five',
#  'hundred',
#  'thousand',
#  'dollars',
#  'seven',
#  'hundred',
#  'fifty',
#  'thousand',
#  'dollars',
#  'department',
#  'determines',
#  'grant',
#  'application',
#  'collaborative',
#  'planning',
#  'activities',
#  'proposed',
#  'include',
#  'two',
#  'adjacent',
#  'counties',
#  'cities',
#  'city',
#  'countyd',
#  'granting',
#  'funds',
#  'pursuant',
#  'division',
#  'department',
#  'shall',
#  'give',
#  'priority',
#  'proposals',
#  'include',
#  'matching',
#  'funds',
#  'local',
#  'sourcese',
#  'grant',
#  'proposal',
#  'park',
#  'openspace',
#  'district',
#  'resource',
#  'conservation',
#  'district',
#  'special',
#  'district',
#  'authority',
#  'joint',
#  'powers',
#  'authority',
#  'shall',
#  'approved',
#  'resolution',
#  'city',
#  'county',
#  'city',
#  'county',
#  'multiple',
#  'cities',
#  'counties',
#  'whose',
#  'jurisdiction',
#  'proposal',
#  'intended',
#  'benefit',
#  'city',
#  'county',
#  'city',
#  'county',
#  'shall',
#  'provide',
#  'evidence',
#  'willing',
#  'implement',
#  'planning',
#  'process',
#  'funded',
#  'grantf',
#  'purposes',
#  'grant',
#  'may',
#  'made',
#  'pursuant',
#  'division',
#  'agricultural',
#  'protection',
#  'may',
#  'include',
#  'need',
#  'limited',
#  'following',
#  'update',
#  'general',
#  'plan',
#  'city',
#  'county',
#  'city',
#  'county',
#  'improve',
#  'protection',
#  'agricultural',
#  'land',
#  'zoning',
#  'ordinance',
#  'designed',
#  'improve',
#  'protection',
#  'agricultural',
#  'land',
#  'develop',
#  'multicounty',
#  'strategies',
#  'protect',
#  'agricultural',
#  'land',
#  'develop',
#  'citycounty',
#  'agreements',
#  'protect',
#  'agricultural',
#  'land',
#  'develop',
#  'strategies',
#  'implement',
#  'existing',
#  'general',
#  'plan',
#  'provisions',
#  'citycounty',
#  'agreements',
#  'multicounty',
#  'agreements',
#  'protect',
#  'agricultural',
#  'land',
#  'including',
#  'technical',
#  'assistance',
#  'develop',
#  'publicprivate',
#  'partnerships',
#  'longterm',
#  'protection',
#  'stewardship',
#  'agricultural',
#  'lands',
#  'local',
#  'food',
#  'producers']

# %% [markdown]
# ## Putting All the Pieces Together
#
# This code aims to:
#
# 1. Extract the individual *bill_id* for each bill in the search results for a query of "food and agriculture" bills in California for the most recent legislative session;
# 2. extract the *doc_id* for the most recently amended version of each bill;
# 3. extract (A) the bill title and (B) the bill text for each document;
# 4. and finally, clean the bill text (prepare into either (A) a relatively clean string text block or (B) a cleaned wordlist).

# %%
## SCRAPE SEARCH RESULTS for bill_ids

# scrape LegiScan search results for CA bills RE: food and ag for current year
requeststring = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getSearchRaw&state=CA&year=2&query=food%20and%20agriculture"
# pull request: getting results as JSON object
r = requests.get(requeststring)
# turning JSON object into a dict
dict1 = json.loads(r.text)

# creating subset dict with only keys of interest
list1 = dict1['searchresult']['results']
# generating list of bill_ids
bills = [value['bill_id'] for value in list1]

# each bill in bills is stored as an integer; convert to list of str
bills1 = [str(bill) for bill in bills]

#inspect/show results
#bills1[:5]

# %%
## EXTRACT doc_id for most recent version of bill, select bill info, save as df

# empty list to store individual bill texts
billtext = {}
# empty list to store list of bill texts
texts = []

# loop
for bill in bills1:
    
    # extract bill info
    bill_id = bill
    requestbill = "https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBill&id="+bill_id
    b = requests.get(requestbill)
    binfo = json.loads(b.text)
    
    # FIND doc_id for most recent bill version
    doclist = binfo['bill']['texts']
    docs = [value['doc_id'] for value in doclist]
    docs1 = [str(doc) for doc in docs] # converting int to str
    
    # identify most recently amended version of text
    doc_id = docs1[-1] 
    
    # get bill text for doc
    requestdoc = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBillText&id='+doc_id
    d = requests.get(requestdoc)
    btext = json.loads(d.text)

    # get URL for amended doc
    URL = btext['text']['state_link']

    ## EXTRACT select info from URL
    r = urlopen(URL)
    html_bytes = r.read()
    html = html_bytes.decode("utf-8")
    soup = BeautifulSoup(html, features='html.parser')

    # bill title
    t = soup.find_all('title')
    ti = t[0]

    # bill year: introduced
    yi = soup.find_all(id = 'bill_intro_date') # will have to be cleaned

    # bill year: amended
    ya = soup.find_all('tbody')
    yam = (ya[0])

    # bill text
    txt = soup.find_all('div', id = 'bill')

    for text in ti:
    title = text.text.strip()
    title = title.split("- ")[-1]
    
    ## REMOVE html style and tags from bill text
    # year intro
    for text in yi:
        yeari = text.text.strip()
        yeari = yeari[-4:]

    # year recent activity
    for text in yam:
        yeara = text.text.strip()
        yeara = yeara[-4:]

    # bill text
    for text in txt:
        billtxt = text.text.strip()

    # creating bill_id
    bill_id = title.split("- ")[-1][:7]
    
    # concatenating into one list
    infotxt = [bill_id, title, yeari, yeara, billtxt]

     ## CONVERT to df  
    itxtdf = pd.DataFrame(infotxt)#.transpose()
    #textstore = pd.DataFrame.from_dict(binfo, orient = 'index', columns = ['text'])
    texts.append(itxtdf)
    fulltext = pd.concat(texts)

# rename columns
fulltext.columns = ['bill_id', 'title', 'y_intro', 'y_recent', 'text']

# inspect/show
fulltext.head()
# Out:
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1711942, 'change_hash': 'cd9d825f6...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1693920, 'change_hash': '464be2cde...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702780, 'change_hash': '266b25df3...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712167, 'change_hash': '37ed87e95...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707639, 'change_hash': '6bddb0f6f...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1671132, 'change_hash': '3f4199a2f...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712103, 'change_hash': 'ce1242ff4...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707512, 'change_hash': '85d63281d...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714501, 'change_hash': 'f094de3f6...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1738922, 'change_hash': '95e252ff3...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1659520, 'change_hash': '6e9c3a09c...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709841, 'change_hash': '3f69d2430...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702725, 'change_hash': '86574f8ad...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714731, 'change_hash': 'b194953c6...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714546, 'change_hash': '32c5c8246...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1701021, 'change_hash': '39ac916c6...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714651, 'change_hash': '21338194e...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649742, 'change_hash': 'aa17e5c5d...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1693914, 'change_hash': '4fde30eda...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714813, 'change_hash': 'd4bf439ae...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1717506, 'change_hash': '95d04db7a...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712067, 'change_hash': 'dd2363f13...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1729722, 'change_hash': 'fb63c6e80...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712107, 'change_hash': '48387cd0b...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709716, 'change_hash': '7730c0e81...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1700993, 'change_hash': '3c6bcef93...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1697043, 'change_hash': 'c0a9f9903...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1693918, 'change_hash': '5506b66cd...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1693916, 'change_hash': '300dc33d0...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1689320, 'change_hash': 'aa0e9982f...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702715, 'change_hash': 'f2bf918eb...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709742, 'change_hash': 'fd8501717...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1697060, 'change_hash': 'e291d2447...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1693932, 'change_hash': '6f14721d1...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1693917, 'change_hash': '01cb29a4d...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709744, 'change_hash': '1b07a1b11...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1711952, 'change_hash': '6db38492e...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1711977, 'change_hash': '8d9bef99e...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1693952, 'change_hash': '921c5f46a...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714485, 'change_hash': 'a15947213...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714521, 'change_hash': 'b42a94762...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709872, 'change_hash': '325a7c834...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707654, 'change_hash': 'f39c94658...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1731372, 'change_hash': 'f81a84a14...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1711904, 'change_hash': 'bfecfedd7...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1724789, 'change_hash': '049dc8121...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1691346, 'change_hash': '9bc238120...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712204, 'change_hash': '51e644266...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712049, 'change_hash': 'db9ff52a4...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714818, 'change_hash': 'f5f177fee...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712180, 'change_hash': 'ab3296bf5...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1659519, 'change_hash': 'b43f4c4dd...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702767, 'change_hash': '837ce31bb...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649739, 'change_hash': 'a5e2e7863...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712004, 'change_hash': '9d396eef7...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667855, 'change_hash': 'b0fa57373...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714317, 'change_hash': '671f2d892...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702772, 'change_hash': '9f3f0543e...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1636426, 'change_hash': 'e0a89e2bd...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709864, 'change_hash': '3c71d76fe...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1701039, 'change_hash': '93d11e603...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1772423, 'change_hash': '364d09f2d...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707500, 'change_hash': '8a6f05636...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714491, 'change_hash': '6769455b3...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714547, 'change_hash': '69a7ee3ba...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649612, 'change_hash': 'c7f3264e8...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714422, 'change_hash': '3052c3425...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649634, 'change_hash': '251768e06...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714633, 'change_hash': 'ce7358fa7...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709708, 'change_hash': 'e4bac41ab...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714407, 'change_hash': 'ab106d9bf...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1691357, 'change_hash': 'aa61d08fc...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1759484, 'change_hash': '40cf0ed85...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1705874, 'change_hash': '64c223f33...
#
#                                                      text  ...  \
# status                                                 OK  ...
# bill    {'bill_id': 1649639, 'change_hash': 'd8377c0bb...  ...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714773, 'change_hash': '9fc6a826a...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649614, 'change_hash': 'b382e16ec...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1726105, 'change_hash': 'd69ef12e7...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1697071, 'change_hash': '36f81c6b9...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667835, 'change_hash': '8879f7a19...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667828, 'change_hash': '09de74990...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702745, 'change_hash': '93a12f3c5...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714319, 'change_hash': 'c35cced74...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1771715, 'change_hash': '5d54d92d6...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667847, 'change_hash': '75f22d12a...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702748, 'change_hash': '874e77afc...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1698914, 'change_hash': 'f8ccf3508...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714562, 'change_hash': 'd40e5e852...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714634, 'change_hash': 'a265d1588...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649626, 'change_hash': 'd51c3ff53...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1731369, 'change_hash': '16546fc93...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667834, 'change_hash': '022fe7499...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1652083, 'change_hash': 'e85361333...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1652088, 'change_hash': 'a97b642ed...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707695, 'change_hash': '2b2226970...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714444, 'change_hash': 'fc02d80a3...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1755204, 'change_hash': '6994b27d1...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649613, 'change_hash': '92d588e4b...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649615, 'change_hash': '37f9dc7ed...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714449, 'change_hash': '050279eab...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1705827, 'change_hash': '22ac81092...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714621, 'change_hash': '47303d89f...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714683, 'change_hash': '6a98dbe0f...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712152, 'change_hash': '49df7bb80...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1712188, 'change_hash': '328c4a4b7...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1691348, 'change_hash': '78f038d6e...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1705905, 'change_hash': '0b2d5128d...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667861, 'change_hash': '2ba229342...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709927, 'change_hash': '522e27c83...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1705843, 'change_hash': '33585e9a4...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667836, 'change_hash': '8883727ed...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1731371, 'change_hash': '03a3e0c4a...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667953, 'change_hash': 'ca2aeab03...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1686434, 'change_hash': '3dbdf3756...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667857, 'change_hash': '50bc51977...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1772090, 'change_hash': 'e56933e52...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709738, 'change_hash': '792a58ccd...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707647, 'change_hash': '9d03f553f...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1705988, 'change_hash': 'f85721e19...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714767, 'change_hash': '33d220426...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707671, 'change_hash': '79c18218b...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649636, 'change_hash': 'd7f1b0dc5...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1705844, 'change_hash': 'f0159cdd4...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709925, 'change_hash': '0965b4b99...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1759810, 'change_hash': '8cc87d32d...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1657752, 'change_hash': '649de8a02...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1637884, 'change_hash': 'fd10ffcd3...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1705952, 'change_hash': '08d9c317b...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714508, 'change_hash': 'e24390e48...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649640, 'change_hash': '7cd361c3f...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1714453, 'change_hash': '90cab0798...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1707631, 'change_hash': 'fbdc14b88...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1711982, 'change_hash': '2b74383ca...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1702834, 'change_hash': '8b2626088...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1698948, 'change_hash': 'be07c109b...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709848, 'change_hash': '38050c9b8...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1689325, 'change_hash': '1afe77894...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1697014, 'change_hash': '12b4db961...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1749145, 'change_hash': 'a7cb40f36...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649628, 'change_hash': 'f95bf81f8...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1706006, 'change_hash': 'a71151914...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1773123, 'change_hash': '03f610642...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667853, 'change_hash': 'ac0007f84...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649632, 'change_hash': '5646aa597...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1709901, 'change_hash': '9d1e34a32...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667849, 'change_hash': 'f6646284a...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1667850, 'change_hash': 'a53200c24...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649629, 'change_hash': '50b7be8e5...
#
#                                                      text  \
# status                                                 OK
# bill    {'bill_id': 1649630, 'change_hash': 'f59dee709...
#
#                                                      text
# status                                                 OK
# bill    {'bill_id': 1667851, 'change_hash': '511075920...
#
# [2 rows x 174 columns]

# %%
# TEST CELL

# %%
# SAVE: pieces

# FIND doc_id for most recent bill version
doclist = binfo['bill']['texts']
docs = [value['doc_id'] for value in doclist]
docs1 = [str(doc) for doc in docs] # converting int to str

# call the most recently amended version of bill text
doc_id = docs1[-1] 

# get bill text for doc
btext1 = 'https://api.legiscan.com/?key=7e00040f1f7618af234e7415484d2494&op=getBillText&id='+doc_id
b = requests.get(btext1)
btext = json.loads(b.text)

# get URL for amended doc
URL = btext['text']['state_link']

## EXTRACTION: relevant info from URL
r = urlopen(URL)
html_bytes = r.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, features='html.parser')

# bill title
t = soup.find_all('title')
ti = t[0]

# bill year: introduced
yi = soup.find_all(id = 'bill_intro_date') # will have to be cleaned

# bill year: amended
ya = soup.find_all('tbody')
yam = (ya[0])

# bill text
txt = soup.find_all('div', id = 'bill')

## REMOVE: html style and tags from bill text

# title
for text in ti:
    title = text.text.strip()
    title = title.split("- ")[-1]

# year intro
for text in yi:
    yeari = text.text.strip()
    yeari = yeari[-4:]

# year recent activity
for text in yam:
    yeara = text.text.strip()
    yeara = yeara[-4:]

# bill text
for text in txt:
    billtxt = text.text.strip()
    
# creating bill_id
bill_id = title.split("- ")[-1][:7]

# concatenating into one list
infotxt = [bill_id, title, yeari, yeara, billtxt]
infotxt

## CONVERT to df

itxtdf = pd.DataFrame(infotxt).transpose()

# rename columns
itxtdf.columns = ['bill_id', 'title', 'y_intro', 'y_recent', 'text']
itxtdf
# Out:
#      status                                               bill
# text     OK  {'bill_id': 1711942, 'change_hash': 'cd9d825f6...
# text     OK  {'bill_id': 1693920, 'change_hash': '464be2cde...
# text     OK  {'bill_id': 1702780, 'change_hash': '266b25df3...
# text     OK  {'bill_id': 1712167, 'change_hash': '37ed87e95...
# text     OK  {'bill_id': 1707639, 'change_hash': '6bddb0f6f...
# text     OK  {'bill_id': 1671132, 'change_hash': '3f4199a2f...
# text     OK  {'bill_id': 1712103, 'change_hash': 'ce1242ff4...
# text     OK  {'bill_id': 1707512, 'change_hash': '85d63281d...
# text     OK  {'bill_id': 1714501, 'change_hash': 'f094de3f6...
# text     OK  {'bill_id': 1738922, 'change_hash': '95e252ff3...
# text     OK  {'bill_id': 1659520, 'change_hash': '6e9c3a09c...
# text     OK  {'bill_id': 1709841, 'change_hash': '3f69d2430...
# text     OK  {'bill_id': 1702725, 'change_hash': '86574f8ad...
# text     OK  {'bill_id': 1714731, 'change_hash': 'b194953c6...
# text     OK  {'bill_id': 1714546, 'change_hash': '32c5c8246...
# text     OK  {'bill_id': 1701021, 'change_hash': '39ac916c6...
# text     OK  {'bill_id': 1714651, 'change_hash': '21338194e...
# text     OK  {'bill_id': 1649742, 'change_hash': 'aa17e5c5d...
# text     OK  {'bill_id': 1693914, 'change_hash': '4fde30eda...
# text     OK  {'bill_id': 1714813, 'change_hash': 'd4bf439ae...
# text     OK  {'bill_id': 1717506, 'change_hash': '95d04db7a...
# text     OK  {'bill_id': 1712067, 'change_hash': 'dd2363f13...
# text     OK  {'bill_id': 1729722, 'change_hash': 'fb63c6e80...
# text     OK  {'bill_id': 1712107, 'change_hash': '48387cd0b...
# text     OK  {'bill_id': 1709716, 'change_hash': '7730c0e81...
# text     OK  {'bill_id': 1700993, 'change_hash': '3c6bcef93...
# text     OK  {'bill_id': 1697043, 'change_hash': 'c0a9f9903...
# text     OK  {'bill_id': 1693918, 'change_hash': '5506b66cd...
# text     OK  {'bill_id': 1693916, 'change_hash': '300dc33d0...
# text     OK  {'bill_id': 1689320, 'change_hash': 'aa0e9982f...
# text     OK  {'bill_id': 1702715, 'change_hash': 'f2bf918eb...
# text     OK  {'bill_id': 1709742, 'change_hash': 'fd8501717...
# text     OK  {'bill_id': 1697060, 'change_hash': 'e291d2447...
# text     OK  {'bill_id': 1693932, 'change_hash': '6f14721d1...
# text     OK  {'bill_id': 1693917, 'change_hash': '01cb29a4d...
# text     OK  {'bill_id': 1709744, 'change_hash': '1b07a1b11...
# text     OK  {'bill_id': 1711952, 'change_hash': '6db38492e...
# text     OK  {'bill_id': 1711977, 'change_hash': '8d9bef99e...
# text     OK  {'bill_id': 1693952, 'change_hash': '921c5f46a...
# text     OK  {'bill_id': 1714485, 'change_hash': 'a15947213...
# text     OK  {'bill_id': 1714521, 'change_hash': 'b42a94762...
# text     OK  {'bill_id': 1709872, 'change_hash': '325a7c834...
# text     OK  {'bill_id': 1707654, 'change_hash': 'f39c94658...
# text     OK  {'bill_id': 1731372, 'change_hash': 'f81a84a14...
# text     OK  {'bill_id': 1711904, 'change_hash': 'bfecfedd7...
# text     OK  {'bill_id': 1724789, 'change_hash': '049dc8121...
# text     OK  {'bill_id': 1691346, 'change_hash': '9bc238120...
# text     OK  {'bill_id': 1712204, 'change_hash': '51e644266...
# text     OK  {'bill_id': 1712049, 'change_hash': 'db9ff52a4...
# text     OK  {'bill_id': 1714818, 'change_hash': 'f5f177fee...
# text     OK  {'bill_id': 1712180, 'change_hash': 'ab3296bf5...
# text     OK  {'bill_id': 1659519, 'change_hash': 'b43f4c4dd...
# text     OK  {'bill_id': 1702767, 'change_hash': '837ce31bb...
# text     OK  {'bill_id': 1649739, 'change_hash': 'a5e2e7863...
# text     OK  {'bill_id': 1712004, 'change_hash': '9d396eef7...
# text     OK  {'bill_id': 1667855, 'change_hash': 'b0fa57373...
# text     OK  {'bill_id': 1714317, 'change_hash': '671f2d892...
# text     OK  {'bill_id': 1702772, 'change_hash': '9f3f0543e...
# text     OK  {'bill_id': 1636426, 'change_hash': 'e0a89e2bd...
# text     OK  {'bill_id': 1709864, 'change_hash': '3c71d76fe...
# text     OK  {'bill_id': 1701039, 'change_hash': '93d11e603...
# text     OK  {'bill_id': 1772423, 'change_hash': '364d09f2d...
# text     OK  {'bill_id': 1707500, 'change_hash': '8a6f05636...
# text     OK  {'bill_id': 1714491, 'change_hash': '6769455b3...
# text     OK  {'bill_id': 1714547, 'change_hash': '69a7ee3ba...
# text     OK  {'bill_id': 1649612, 'change_hash': 'c7f3264e8...
# text     OK  {'bill_id': 1714422, 'change_hash': '3052c3425...
# text     OK  {'bill_id': 1649634, 'change_hash': '251768e06...
# text     OK  {'bill_id': 1714633, 'change_hash': 'ce7358fa7...
# text     OK  {'bill_id': 1709708, 'change_hash': 'e4bac41ab...
# text     OK  {'bill_id': 1714407, 'change_hash': 'ab106d9bf...
# text     OK  {'bill_id': 1691357, 'change_hash': 'aa61d08fc...
# text     OK  {'bill_id': 1759484, 'change_hash': '40cf0ed85...
# text     OK  {'bill_id': 1705874, 'change_hash': '64c223f33...
# text     OK  {'bill_id': 1649639, 'change_hash': 'd8377c0bb...
# text     OK  {'bill_id': 1667833, 'change_hash': '2a0631621...
# text     OK  {'bill_id': 1705803, 'change_hash': '101eab091...
# text     OK  {'bill_id': 1714533, 'change_hash': 'a488ecdef...
# text     OK  {'bill_id': 1698897, 'change_hash': 'eb90c8961...
# text     OK  {'bill_id': 1667860, 'change_hash': '27e4475ee...
# text     OK  {'bill_id': 1702786, 'change_hash': '957ffc61f...
# text     OK  {'bill_id': 1693927, 'change_hash': '8eaae548d...
# text     OK  {'bill_id': 1712034, 'change_hash': '79ed129d8...
# text     OK  {'bill_id': 1707538, 'change_hash': 'c049e28f8...
# text     OK  {'bill_id': 1714704, 'change_hash': 'fb197014f...
# text     OK  {'bill_id': 1649738, 'change_hash': 'a8728aab3...
# text     OK  {'bill_id': 1714551, 'change_hash': '277b9a7cd...
# text     OK  {'bill_id': 1714412, 'change_hash': '137a126bb...
# text     OK  {'bill_id': 1705898, 'change_hash': '732887395...
# text     OK  {'bill_id': 1714709, 'change_hash': 'be43fc426...
# text     OK  {'bill_id': 1691375, 'change_hash': '56cc90bf5...
# text     OK  {'bill_id': 1644455, 'change_hash': '75e63a1c6...
# text     OK  {'bill_id': 1707543, 'change_hash': 'c1a561814...
# text     OK  {'bill_id': 1707490, 'change_hash': '03d1b05b0...
# text     OK  {'bill_id': 1705903, 'change_hash': '9c13a807d...
# text     OK  {'bill_id': 1705902, 'change_hash': 'b1c8090bf...
# text     OK  {'bill_id': 1709774, 'change_hash': '5a3487223...
# text     OK  {'bill_id': 1714532, 'change_hash': 'bb19ee6d0...
# text     OK  {'bill_id': 1702700, 'change_hash': 'c4e66cc00...
# text     OK  {'bill_id': 1714773, 'change_hash': '9fc6a826a...
# text     OK  {'bill_id': 1649614, 'change_hash': 'b382e16ec...
# text     OK  {'bill_id': 1726105, 'change_hash': 'd69ef12e7...
# text     OK  {'bill_id': 1697071, 'change_hash': '36f81c6b9...
# text     OK  {'bill_id': 1667835, 'change_hash': '8879f7a19...
# text     OK  {'bill_id': 1667828, 'change_hash': '09de74990...
# text     OK  {'bill_id': 1702745, 'change_hash': '93a12f3c5...
# text     OK  {'bill_id': 1714319, 'change_hash': 'c35cced74...
# text     OK  {'bill_id': 1771715, 'change_hash': '5d54d92d6...
# text     OK  {'bill_id': 1667847, 'change_hash': '75f22d12a...
# text     OK  {'bill_id': 1702748, 'change_hash': '874e77afc...
# text     OK  {'bill_id': 1698914, 'change_hash': 'f8ccf3508...
# text     OK  {'bill_id': 1714562, 'change_hash': 'd40e5e852...
# text     OK  {'bill_id': 1714634, 'change_hash': 'a265d1588...
# text     OK  {'bill_id': 1649626, 'change_hash': 'd51c3ff53...
# text     OK  {'bill_id': 1731369, 'change_hash': '16546fc93...
# text     OK  {'bill_id': 1667834, 'change_hash': '022fe7499...
# text     OK  {'bill_id': 1652083, 'change_hash': 'e85361333...
# text     OK  {'bill_id': 1652088, 'change_hash': 'a97b642ed...
# text     OK  {'bill_id': 1707695, 'change_hash': '2b2226970...
# text     OK  {'bill_id': 1714444, 'change_hash': 'fc02d80a3...
# text     OK  {'bill_id': 1755204, 'change_hash': '6994b27d1...
# text     OK  {'bill_id': 1649613, 'change_hash': '92d588e4b...
# text     OK  {'bill_id': 1649615, 'change_hash': '37f9dc7ed...
# text     OK  {'bill_id': 1714449, 'change_hash': '050279eab...
# text     OK  {'bill_id': 1705827, 'change_hash': '22ac81092...
# text     OK  {'bill_id': 1714621, 'change_hash': '47303d89f...
# text     OK  {'bill_id': 1714683, 'change_hash': '6a98dbe0f...
# text     OK  {'bill_id': 1712152, 'change_hash': '49df7bb80...
# text     OK  {'bill_id': 1712188, 'change_hash': '328c4a4b7...
# text     OK  {'bill_id': 1691348, 'change_hash': '78f038d6e...
# text     OK  {'bill_id': 1705905, 'change_hash': '0b2d5128d...
# text     OK  {'bill_id': 1667861, 'change_hash': '2ba229342...
# text     OK  {'bill_id': 1709927, 'change_hash': '522e27c83...
# text     OK  {'bill_id': 1705843, 'change_hash': '33585e9a4...
# text     OK  {'bill_id': 1667836, 'change_hash': '8883727ed...
# text     OK  {'bill_id': 1731371, 'change_hash': '03a3e0c4a...
# text     OK  {'bill_id': 1667953, 'change_hash': 'ca2aeab03...
# text     OK  {'bill_id': 1686434, 'change_hash': '3dbdf3756...
# text     OK  {'bill_id': 1667857, 'change_hash': '50bc51977...
# text     OK  {'bill_id': 1772090, 'change_hash': 'e56933e52...
# text     OK  {'bill_id': 1709738, 'change_hash': '792a58ccd...
# text     OK  {'bill_id': 1707647, 'change_hash': '9d03f553f...
# text     OK  {'bill_id': 1705988, 'change_hash': 'f85721e19...
# text     OK  {'bill_id': 1714767, 'change_hash': '33d220426...
# text     OK  {'bill_id': 1707671, 'change_hash': '79c18218b...
# text     OK  {'bill_id': 1649636, 'change_hash': 'd7f1b0dc5...
# text     OK  {'bill_id': 1705844, 'change_hash': 'f0159cdd4...
# text     OK  {'bill_id': 1709925, 'change_hash': '0965b4b99...
# text     OK  {'bill_id': 1759810, 'change_hash': '8cc87d32d...
# text     OK  {'bill_id': 1657752, 'change_hash': '649de8a02...
# text     OK  {'bill_id': 1637884, 'change_hash': 'fd10ffcd3...
# text     OK  {'bill_id': 1705952, 'change_hash': '08d9c317b...
# text     OK  {'bill_id': 1714508, 'change_hash': 'e24390e48...
# text     OK  {'bill_id': 1649640, 'change_hash': '7cd361c3f...
# text     OK  {'bill_id': 1714453, 'change_hash': '90cab0798...
# text     OK  {'bill_id': 1707631, 'change_hash': 'fbdc14b88...
# text     OK  {'bill_id': 1711982, 'change_hash': '2b74383ca...
# text     OK  {'bill_id': 1702834, 'change_hash': '8b2626088...
# text     OK  {'bill_id': 1698948, 'change_hash': 'be07c109b...
# text     OK  {'bill_id': 1709848, 'change_hash': '38050c9b8...
# text     OK  {'bill_id': 1689325, 'change_hash': '1afe77894...
# text     OK  {'bill_id': 1697014, 'change_hash': '12b4db961...
# text     OK  {'bill_id': 1749145, 'change_hash': 'a7cb40f36...
# text     OK  {'bill_id': 1649628, 'change_hash': 'f95bf81f8...
# text     OK  {'bill_id': 1706006, 'change_hash': 'a71151914...
# text     OK  {'bill_id': 1773123, 'change_hash': '03f610642...
# text     OK  {'bill_id': 1667853, 'change_hash': 'ac0007f84...
# text     OK  {'bill_id': 1649632, 'change_hash': '5646aa597...
# text     OK  {'bill_id': 1709901, 'change_hash': '9d1e34a32...
# text     OK  {'bill_id': 1667849, 'change_hash': 'f6646284a...
# text     OK  {'bill_id': 1667850, 'change_hash': 'a53200c24...
# text     OK  {'bill_id': 1649629, 'change_hash': '50b7be8e5...
# text     OK  {'bill_id': 1649630, 'change_hash': 'f59dee709...
# text     OK  {'bill_id': 1667851, 'change_hash': '511075920...
